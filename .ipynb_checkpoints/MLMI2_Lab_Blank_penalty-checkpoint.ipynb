# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in c:\users\msadi\anaconda3\lib\site-packages (1.12.1+cu113)
# Requirement already satisfied: torchvision in c:\users\msadi\anaconda3\lib\site-packages (0.13.1+cu113)
# Requirement already satisfied: torchaudio in c:\users\msadi\anaconda3\lib\site-packages (0.12.1+cu113)
# Requirement already satisfied: typing-extensions in c:\users\msadi\anaconda3\lib\site-packages (from torch) (3.10.0.2)
# Requirement already satisfied: numpy in c:\users\msadi\anaconda3\lib\site-packages (from torchvision) (1.20.3)
# Requirement already satisfied: requests in c:\users\msadi\anaconda3\lib\site-packages (from torchvision) (2.26.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\msadi\anaconda3\lib\site-packages (from torchvision) (8.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\msadi\anaconda3\lib\site-packages (from requests->torchvision) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\msadi\anaconda3\lib\site-packages (from requests->torchvision) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\msadi\anaconda3\lib\site-packages (from requests->torchvision) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\msadi\anaconda3\lib\site-packages (from requests->torchvision) (2.0.4)

# %%
import torchaudio
import torch
import json
import os
# import librosa
from scipy.io import wavfile
import random
import sklearn
random.seed(10)

# %%
mapping_vocab = {}

with open('phone_map','r') as file:
    for i in file:
        splits=i.split(':')
        mapping_vocab[splits[0].strip()]=splits[1].strip()
        
mapping_vocab['']='_'

# %%
mapping_vocab
# Out:
# {'sil': 'sil',
#  'aa': 'aa',
#  'ae': 'ae',
#  'ah': 'ah',
#  'ao': 'aa',
#  'aw': 'aw',
#  'ax': 'ah',
#  'ax-h': 'ah',
#  'axr': 'er',
#  'ay': 'ay',
#  'b': 'b',
#  'bcl': 'sil',
#  'ch': 'ch',
#  'd': 'd',
#  'dcl': 'sil',
#  'dh': 'dh',
#  'dx': 'dx',
#  'eh': 'eh',
#  'el': 'l',
#  'em': 'm',
#  'en': 'n',
#  'eng': 'ng',
#  'epi': 'sil',
#  'er': 'er',
#  'ey': 'ey',
#  'f': 'f',
#  'g': 'g',
#  'gcl': 'sil',
#  'h#': 'sil',
#  'hh': 'hh',
#  'hv': 'hh',
#  'ih': 'ih',
#  'ix': 'ih',
#  'iy': 'iy',
#  'jh': 'jh',
#  'k': 'k',
#  'kcl': 'sil',
#  'l': 'l',
#  'm': 'm',
#  'ng': 'ng',
#  'n': 'n',
#  'nx': 'n',
#  'ow': 'ow',
#  'oy': 'oy',
#  'p': 'p',
#  'pau': 'sil',
#  'pcl': 'sil',
#  'q': '',
#  'r': 'r',
#  's': 's',
#  'sh': 'sh',
#  't': 't',
#  'tcl': 'sil',
#  'th': 'th',
#  'uh': 'uh',
#  'uw': 'uw',
#  'ux': 'uw',
#  'v': 'v',
#  'w': 'w',
#  'y': 'y',
#  'z': 'z',
#  'zh': 'sh',
#  '': '_'}

# %%
# DATA_PREFIX = 'D:/SR_dataset/'

# with open('train.json') as f:

#     train_json = json.load(f)

# # for i in train_json: 
#     # print(i,train_json[i])
# for i in train_json:
#     splits = train_json[i]['wav'].split('/')
# #     print(splits)
#     split_index = splits.index('data')
#     splits = splits[split_index:]
#     new_file = DATA_PREFIX + '/'.join(splits)
#     train_json[i]['wav'] = new_file
#     print(train_json[i]['wav'])

# %%
str(torchaudio.get_audio_backend())
# Out:
# 'soundfile'

# %%
# train_fbank_json={}

# import wave

# for i in train_json:
#     train_fbank_json[i]={}
#     location = train_json[i]['wav']
#     train_fbank_json[i]['spk_id']=train_json[i]['spk_id']
#     train_fbank_json[i]['duration']=train_json[i]['duration']
    
#     phns = train_json[i]['phn']
    
# #     print(phns)
# #     t=input()
#     phns = phns.split()
    
#     for j in range(len(phns)):
#         phns[j] = mapping_vocab[phns[j]]
#     phns = ' '.join(phns)
# #     print(phns)
# #     t=input()
#     train_fbank_json[i]['phn']=phns
#     splits = location.split('/')
#     split_index = splits.index('TRAIN')
#     splits2 = splits[split_index+1:-1]
#     new_location = DATA_PREFIX + 'data/fbank/train/' + '/'.join(splits2)
#     os.makedirs(new_location,exist_ok=True)
# #     print(location)
# #     t=input()
#     waveform,sample_rate = torchaudio.load(location)
# #     t=input()
#     fbank = torchaudio.compliance.kaldi.fbank(waveform,sample_rate)
# #     print(fbank.shape)
# #     print(new_location+'/'+splits[-1]+'.pt')
# #     t=input()
#     pt_loc = new_location+'/'+splits[-1]+'.pt'
#     train_fbank_json[i]['fbank'] = pt_loc
#     torch.save(fbank,pt_loc)

    
# with open('train_fbank.json', 'w') as outfile:
#     json.dump(train_fbank_json, outfile)

# %%
# DATA_PREFIX = 'D:/SR_dataset/'

# with open('dev.json') as f:

#     dev_json = json.load(f)

# # for i in train_json: 
#     # print(i,train_json[i])
# for i in dev_json:
#     splits = dev_json[i]['wav'].split('/')
# #     print(splits)
#     split_index = splits.index('data')
#     splits = splits[split_index:]
#     new_file = DATA_PREFIX + '/'.join(splits)
#     dev_json[i]['wav'] = new_file
#     print(dev_json[i]['wav'])

# %%
# dev_json

# %%
# dev_fbank_json={}

# import wave

# for i in dev_json:
#     dev_fbank_json[i]={}
#     location = dev_json[i]['wav']
#     dev_fbank_json[i]['spk_id']=dev_json[i]['spk_id']
#     dev_fbank_json[i]['duration']=dev_json[i]['duration']

#     phns = dev_json[i]['phn']
    
# #     print(phns)
# #     t=input()
#     phns = phns.split()
    
#     for j in range(len(phns)):
#         phns[j] = mapping_vocab[phns[j]]
#     phns = ' '.join(phns)
# #     print(phns)
# #     t=input()
#     dev_fbank_json[i]['phn']=phns
    
#     splits = location.split('/')
#     split_index = splits.index('TEST')
#     splits2 = splits[split_index+1:-1]
#     new_location = DATA_PREFIX + 'data/fbank/dev/' + '/'.join(splits2)
#     os.makedirs(new_location,exist_ok=True)
# #     print(location)
# #     t=input()
#     waveform,sample_rate = torchaudio.load(location)
# #     t=input()
#     fbank = torchaudio.compliance.kaldi.fbank(waveform,sample_rate)
# #     print(new_location+'/'+splits[-1]+'.pt')
# #     t=input()
#     pt_loc = new_location+'/'+splits[-1]+'.pt'
#     dev_fbank_json[i]['fbank'] = pt_loc
#     torch.save(fbank,pt_loc)

    
# with open('dev_fbank.json', 'w') as outfile:
#     json.dump(dev_fbank_json, outfile)

# %%
# DATA_PREFIX = 'D:/SR_dataset/'

# with open('test.json') as f:

#     test_json = json.load(f)

# # for i in train_json: 
#     # print(i,train_json[i])
# for i in test_json:
#     splits = test_json[i]['wav'].split('/')
# #     print(splits)
#     split_index = splits.index('data')
#     splits = splits[split_index:]
#     new_file = DATA_PREFIX + '/'.join(splits)
#     test_json[i]['wav'] = new_file
#     print(test_json[i]['wav'])



# test_fbank_json={}

# import wave

# for i in test_json:
#     test_fbank_json[i]={}
#     location = test_json[i]['wav']
#     test_fbank_json[i]['spk_id']=test_json[i]['spk_id']
#     test_fbank_json[i]['duration']=test_json[i]['duration']
#     phns = test_json[i]['phn']
    
# #     print(phns)
# #     t=input()
#     phns = phns.split()
    
#     for j in range(len(phns)):
#         phns[j] = mapping_vocab[phns[j]]
#     phns = ' '.join(phns)
# #     print(phns)
# #     t=input()
#     test_fbank_json[i]['phn']=phns
#     splits = location.split('/')
#     split_index = splits.index('TEST')
#     splits2 = splits[split_index+1:-1]
#     new_location = DATA_PREFIX + 'data/fbank/test/' + '/'.join(splits2)
#     os.makedirs(new_location,exist_ok=True)
# #     print(location)
# #     t=input()
#     waveform,sample_rate = torchaudio.load(location)
# #     t=input()
#     fbank = torchaudio.compliance.kaldi.fbank(waveform,sample_rate)
# #     print(fbank.shape)
# #     print(new_location+'/'+splits[-1]+'.pt')
# #     t=input()
#     pt_loc = new_location+'/'+splits[-1]+'.pt'
#     test_fbank_json[i]['fbank'] = pt_loc
#     torch.save(fbank,pt_loc)
    

# with open('test_fbank.json', 'w') as outfile:
#     json.dump(test_fbank_json, outfile)

# %%
with open('train_fbank.json') as file:
    t_json = json.load(file)
    
t_json
# Out:
# {'FVFB0_SX312.WAV': {'spk_id': 'FVFB0',
#   'duration': 3.79525,
#   'phn': 'sil dh ah z ae n sil s er z l sil b ih s sil t r ey f aa r w er sil d ih f y uw sil th ih ng sil dh ah m sil th r uw sil k eh r f ah l ih f er s sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FVFB0/SX312.WAV.pt'},
#  'FVFB0_SX222.WAV': {'spk_id': 'FVFB0',
#   'duration': 2.5344375,
#   'phn': 'sil y aa w ih z sil k ih m ah sil w ah th sil p ae th sil l aa sil jh ih sil k l ih sil g z ae m sil p l sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FVFB0/SX222.WAV.wav.pt'},
#  'FVFB0_SX42.WAV': {'spk_id': 'FVFB0',
#   'duration': 1.913625,
#   'phn': 'sil b ih v l sil k l s sil k aa l er z aa r sil y uw hh ih s sh er iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FVFB0/SX42.WAV.pt'},
#  'FVFB0_SI1032.WAV': {'spk_id': 'FVFB0',
#   'duration': 2.8224375,
#   'phn': 'sil ih w ih z ih s sil t aa r iy ah dh ah r ay n aa s r ih s f ay dx aa l ow v er ih sil g ae n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FVFB0/SI1032.WAV.wav.pt'},
#  'FVFB0_SI1510.WAV': {'spk_id': 'FVFB0',
#   'duration': 4.0448125,
#   'phn': 'sil ah f l ae sh ih l uw m ih n dh ih sil t r iy z ah z ih sil k er sil k ih sil b ow l sil t w ih sil d ih n s eh v r l sil d er eh sil sh sil n sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FVFB0/SI1510.WAV.pt'},
#  'FVFB0_SI2292.WAV': {'spk_id': 'FVFB0',
#   'duration': 1.753625,
#   'phn': 'sil z ih dx eh n iy th ih ng l ay sil k uh sil d ow v er ow sil m iy l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FVFB0/SI2292.WAV.pt'},
#  'FVFB0_SX402.WAV': {'spk_id': 'FVFB0',
#   'duration': 2.2848125,
#   'phn': 'sil w ah l s er v r uw sil b aa sil p ay ae f sil t er r ey sil ch l z sil t aa sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FVFB0/SX402.WAV.pt'},
#  'FVFB0_SX132.WAV': {'spk_id': 'FVFB0',
#   'duration': 2.489625,
#   'phn': 'sil p ah sil b l ih s ah dx iy ih n ow dx er ay eh sil d iy sil g ow hh ae n sil d ih n hh ae n sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FVFB0/SX132.WAV.wav.pt'},
#  'MKLW0_SX41.WAV': {'spk_id': 'MKLW0',
#   'duration': 3.4688125,
#   'phn': 'sil eh dx ih sil k ih sil m ae n sil d ey sil t s sil k m sil p l ay n sil s hh w ah th ih sil g z ih s sil t ih ng r eh sil y ih l ey sh ih n s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MKLW0/SX41.WAV.wav.pt'},
#  'MKLW0_SX221.WAV': {'spk_id': 'MKLW0',
#   'duration': 3.09125,
#   'phn': 'sil k aa r iy ih sil t ae sil k sil dh ah sil p r aa sil jh ih sil k sil w ih th eh sil sh r ih dx ih sil t er m ih n ey sh n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MKLW0/SX221.WAV.pt'},
#  'MKLW0_SX401.WAV': {'spk_id': 'MKLW0',
#   'duration': 2.9888125,
#   'phn': 'sil dh ih sil t ae sil s ih sil k ae sil b r ow sil k sil d aw n ih ng sil k aa z sil d ih sil t r ae f ih sil jh ae m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MKLW0/SX401.WAV.pt'},
#  'MKLW0_SI1571.WAV': {'spk_id': 'MKLW0',
#   'duration': 5.145625,
#   'phn': 'sil ay s sil b ae s sil l eh sil t r ih sil k sh aa sil k s sil l ae sh iy ng z sil w ay l sil d aa sil z sil t eh s sil t ih sil k l sil k r aa sh er s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MKLW0/SI1571.WAV.wav.pt'},
#  'MKLW0_SI2201.WAV': {'spk_id': 'MKLW0',
#   'duration': 1.9008125,
#   'phn': 'sil jh ah s sil l eh sil m iy sil d ay ih n sil p iy s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MKLW0/SI2201.WAV.pt'},
#  'MKLW0_SI1844.WAV': {'spk_id': 'MKLW0',
#   'duration': 1.536,
#   'phn': 'sil hh eh l ow eh n iy w ah n ae hh ow m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MKLW0/SI1844.WAV.wav.pt'},
#  'MKLW0_SX131.WAV': {'spk_id': 'MKLW0',
#   'duration': 2.5664375,
#   'phn': 'sil ah sil p l ae n sil t ih sil b ih l sil d n uw sil b eh v r ih sil jh sil p l ae n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MKLW0/SX131.WAV.pt'},
#  'MKLW0_SX311.WAV': {'spk_id': 'MKLW0',
#   'duration': 4.6208125,
#   'phn': 'sil m ay sil d ih z ay er r z ah s ih m sil p l sil g ih v sil m iy w ah n ih n sil f aa r m ih dx ih v sil p ae er sil g r ae f aa n ih s ah sil jh eh sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MKLW0/SX311.WAV.wav.pt'},
#  'MTJS0_SX382.WAV': {'spk_id': 'MTJS0',
#   'duration': 4.064,
#   'phn': 'sil jh aa r sil jh ih z sil p eh er n oy sil d ih sil b aw dx ah f uw sil ch er sil g ae sh aa dx ih sil jh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MTJS0/SX382.WAV.pt'},
#  'MTJS0_SI1192.WAV': {'spk_id': 'MTJS0',
#   'duration': 2.361625,
#   'phn': 'sil s ow ah v sil k aa s hh iy s sil t ey sil p uh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MTJS0/SI1192.WAV.wav.pt'},
#  'MTJS0_SX22.WAV': {'spk_id': 'MTJS0',
#   'duration': 2.144,
#   'phn': 'sil w ah n aa l eh l s f ey l z y uw z f aa s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MTJS0/SX22.WAV.wav.pt'},
#  'MTJS0_SX292.WAV': {'spk_id': 'MTJS0',
#   'duration': 3.7568125,
#   'phn': 'sil dh iy z ih sil k s sil k l uw s ah v sil d aa sil k ah m ih n s sil m ah s sil b iy l aa sil d ah sil p ih sil aa l sil t ay m z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MTJS0/SX292.WAV.wav.pt'},
#  'MTJS0_SI1822.WAV': {'spk_id': 'MTJS0',
#   'duration': 5.81125,
#   'phn': 'sil b ah sil t ih dh iy ih n f y er r iy ey sh ih n ah v s ay ih n sil t ih s sil f er n ow n ow n r iy z ih n sil n aa sil aa l ah dh eh m sil d ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MTJS0/SI1822.WAV.pt'},
#  'MTJS0_SX112.WAV': {'spk_id': 'MTJS0',
#   'duration': 3.353625,
#   'phn': 'sil t ah sil b ow sil s ih sil k ey sil p ah sil b ah l ah v hh aa l iy ng hh uw sil jh l ow sil z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MTJS0/SX112.WAV.wav.pt'},
#  'MTJS0_SX202.WAV': {'spk_id': 'MTJS0',
#   'duration': 2.1824375,
#   'phn': 'sil hh ah m ah sil ch ah l aw ah n s sil d ih y uw sil g eh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MTJS0/SX202.WAV.pt'},
#  'MTJS0_SI562.WAV': {'spk_id': 'MTJS0',
#   'duration': 4.8768125,
#   'phn': 'sil f ae m l iy l oy l sil t iy z ih ng sil k ah w aa sil p er sil t ih f w er sil k hh ih v sil b ih n ah n sil b r ow sil k ih n f er sil jh eh n er ey sh ih n s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MTJS0/SI562.WAV.pt'},
#  'MKLS0_SI2067.WAV': {'spk_id': 'MKLS0',
#   'duration': 4.2624375,
#   'phn': 'sil y ae sil s ih m s ow sil d ow n ih sil dh ah sil b oy l ae f sil t sil hh ah sil ih ng hh er sil k l ow s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MKLS0/SI2067.WAV.wav.pt'},
#  'MKLS0_SX447.WAV': {'spk_id': 'MKLS0',
#   'duration': 2.70725,
#   'phn': 'sil f er s sil t ae sil m ih l sil t ah dh ih sh r eh dx ih sil ch iy s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MKLS0/SX447.WAV.wav.pt'},
#  'MKLS0_SI1437.WAV': {'spk_id': 'MKLS0',
#   'duration': 5.625625,
#   'phn': 'sil ey sil k er n sil k er n eh f er sil ih z n iy dx ih sil t ah m ey sil k ow sh n ih sil g r ae f ih sil d ae dx ah sil y uw s f l sil aa n dh ih s sil p aa sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MKLS0/SI1437.WAV.pt'},
#  'MKLS0_SX177.WAV': {'spk_id': 'MKLS0',
#   'duration': 2.0544375,
#   'phn': 'sil d ah z sil k r iy ow l sil k uh sil k iy ng y uw z sil k er iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MKLS0/SX177.WAV.wav.pt'},
#  'MKLS0_SX267.WAV': {'spk_id': 'MKLS0',
#   'duration': 3.76325,
#   'phn': 'sil d r aa eh v r iy aw dx er l ay n f er s sil t sil dh eh n f ih l ih n dh iy ih n sil t ih r iy er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MKLS0/SX267.WAV.pt'},
#  'MKLS0_SI1533.WAV': {'spk_id': 'MKLS0',
#   'duration': 1.9328125,
#   'phn': 'sil ae sil hh ow m y eh s dh ey aa r sil g uw sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MKLS0/SI1533.WAV.pt'},
#  'MKLS0_SX87.WAV': {'spk_id': 'MKLS0',
#   'duration': 2.6688125,
#   'phn': 'sil p er m ah dx ih v sil t r ay sil b z hh ae v ah n ah sil b iy sil ae dx ah sil t uw sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MKLS0/SX87.WAV.pt'},
#  'MKLS0_SX357.WAV': {'spk_id': 'MKLS0',
#   'duration': 3.673625,
#   'phn': 'sil dh ah m oy sh ch er m ay ay z ah z f r ah m ay sil d r aa sil p s sil n aa sil t f r m sil t ih er s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MKLS0/SX357.WAV.wav.pt'},
#  'FETB0_SI1778.WAV': {'spk_id': 'FETB0',
#   'duration': 3.5264375,
#   'phn': 'sil w ih m ih n sil d ih sil n y uw z sil w ay sil f ey s sil p aw dx er n aw ah sil d ey z hh ih r ih sil k aa l sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FETB0/SI1778.WAV.wav.pt'},
#  'FETB0_SX338.WAV': {'spk_id': 'FETB0',
#   'duration': 3.18725,
#   'phn': 'sil dh ah sil d aa sil k sil m er sil k ih l ah sil g uw n sil w aw n sil d ah r aw n sil f er m ay l s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FETB0/SX338.WAV.wav.pt'},
#  'FETB0_SI518.WAV': {'spk_id': 'FETB0',
#   'duration': 3.481625,
#   'phn': 'sil hh ay er sil t ow l r ey sil t s aa l s ow aa r hh eh l sil p ih ng sil b uw s sil t r eh v eh n uw s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FETB0/SI518.WAV.wav.pt'},
#  'FETB0_SX248.WAV': {'spk_id': 'FETB0',
#   'duration': 2.6368125,
#   'phn': 'sil r iy dx ih ng ih n sil p aa ah l ay sil t sil g ih v z y uw ay s sil t r ey n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FETB0/SX248.WAV.wav.pt'},
#  'FETB0_SX68.WAV': {'spk_id': 'FETB0',
#   'duration': 2.681625,
#   'phn': 'sil ah sil p sil g r ey sil y er s sil t ae dx ih s sil t ah r ih f l eh sil t y er w eh l th sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FETB0/SX68.WAV.wav.pt'},
#  'FETB0_SI1148.WAV': {'spk_id': 'FETB0',
#   'duration': 2.5664375,
#   'phn': 'sil ch ey n sil jh n v aa l v s dh ah sil d ih s sil p l ey s sil m ah n ah f aa m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FETB0/SI1148.WAV.pt'},
#  'FETB0_SX158.WAV': {'spk_id': 'FETB0',
#   'duration': 2.24,
#   'phn': 'sil dh ah sil d r ah ng sil k er dx ih z ey s ow sh ah l aw sil k ae s sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FETB0/SX158.WAV.wav.pt'},
#  'FETB0_SX428.WAV': {'spk_id': 'FETB0',
#   'duration': 3.4304375,
#   'phn': 'sil ey sil k r ae sil ch ae l eh n sh sil m iy sil b ah dx ey sil k w ih sil k s sil t ae sil v ae ng sil k w ih sh sil t ih m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FETB0/SX428.WAV.wav.pt'},
#  'FJSP0_SX264.WAV': {'spk_id': 'FJSP0',
#   'duration': 2.8864375,
#   'phn': 'sil w iy s aa ey sil t ay n iy ay s ih sil k l z sil b l l ow w aa r uw f sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FJSP0/SX264.WAV.pt'},
#  'FJSP0_SX84.WAV': {'spk_id': 'FJSP0',
#   'duration': 3.4624375,
#   'phn': 'sil k ah w aa sil p er ey sh ih n ah l aa ng w ah dh ah n d ih s sil t ae n ih ng sil g l l iy v iy ey sil d ih s sil p y uw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FJSP0/SX84.WAV.wav.pt'},
#  'FJSP0_SI1434.WAV': {'spk_id': 'FJSP0',
#   'duration': 4.384,
#   'phn': 'sil k ih n s iy v ah sil b l iy dh ih s ah sil m er r iy n sil d ih f eh n s sil p r aa sil l ah m sil k eh n b iy s aa l v sil b ay s ih f ih sh ih n f aa r s ih z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FJSP0/SI1434.WAV.wav.pt'},
#  'FJSP0_SX174.WAV': {'spk_id': 'FJSP0',
#   'duration': 3.8208125,
#   'phn': 'sil dh ah hh aa n ih sil d hh aw s sil w ah z ih hh ih sil d uw dx uw aw s sil t ae n ih ng aa dx ih y ow v ih sh uw w l ah f eh sil k s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FJSP0/SX174.WAV.wav.pt'},
#  'FJSP0_SI804.WAV': {'spk_id': 'FJSP0',
#   'duration': 2.5024375,
#   'phn': 'sil dh ih s ih z sil p ih sil t ih k y l l iy sil t r uw w ih n s ay s l eh sil k sh n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FJSP0/SI804.WAV.pt'},
#  'FJSP0_SX354.WAV': {'spk_id': 'FJSP0',
#   'duration': 2.73925,
#   'phn': 'sil ah l oy y er w ah z ah sil p oy n ih sil t uw eh sil s ih sil k y uw sil hh er w ih l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FJSP0/SX354.WAV.wav.pt'},
#  'FJSP0_SX444.WAV': {'spk_id': 'FJSP0',
#   'duration': 2.8864375,
#   'phn': 'sil dh ih sil t aa sil d l er f aw n ah sil k l ae m sh eh l n ih er dh ih sil k ae m sil p s ay sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FJSP0/SX444.WAV.pt'},
#  'FJSP0_SI1763.WAV': {'spk_id': 'FJSP0',
#   'duration': 1.23525,
#   'phn': 'sil dh ae sil t s y er hh eh dx ey sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FJSP0/SI1763.WAV.wav.pt'},
#  'MPGR0_SX330.WAV': {'spk_id': 'MPGR0',
#   'duration': 3.0528125,
#   'phn': 'sil k aw n sil dh ah n ah m er ah v sil t iy s sil p uw n z ah v s oy s aa s dh eh sil ch uw ae sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MPGR0/SX330.WAV.wav.pt'},
#  'MPGR0_SX240.WAV': {'spk_id': 'MPGR0',
#   'duration': 2.6368125,
#   'phn': 'sil ih sil s sil n aa dx iy z iy sil t ih sil k r iy ey sil ah l uw m ih n ey dx ih n eh sil g z ae m sil p l s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MPGR0/SX240.WAV.pt'},
#  'MPGR0_SI2040.WAV': {'spk_id': 'MPGR0',
#   'duration': 1.7088125,
#   'phn': 'sil hh ih z sil k aa m r ae sil z w er aa l sil d eh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MPGR0/SI2040.WAV.pt'},
#  'MPGR0_SX60.WAV': {'spk_id': 'MPGR0',
#   'duration': 3.097625,
#   'phn': 'sil dh ah l eh sil jh ih s l ey sil ch er m eh sil t ih sil jh ah z ah s sil t ey dx ah sil p ah sil b l ih sil k ih sil jh ih sil k ey sh ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MPGR0/SX60.WAV.pt'},
#  'MPGR0_SX150.WAV': {'spk_id': 'MPGR0',
#   'duration': 1.7088125,
#   'phn': 'sil v iy ih sil n ah m iy z sil k uh z iy n ih z eh sil k s sil k w ih z ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MPGR0/SX150.WAV.wav.pt'},
#  'MPGR0_SI780.WAV': {'spk_id': 'MPGR0',
#   'duration': 2.304,
#   'phn': 'sil dh ah s ay sil d w ah n z aa hh ae f ih n ch sil n ae r ow er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MPGR0/SI780.WAV.wav.pt'},
#  'MPGR0_SI1410.WAV': {'spk_id': 'MPGR0',
#   'duration': 4.1024375,
#   'phn': 'sil w ih w l ih sil ch iy v ey m aa v ih v ih sil d s eh n s ah v w ah dx ih sil ih z sil b ay r ih l ay z iy n w ah dx ih dx ih z sil n aa sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MPGR0/SI1410.WAV.pt'},
#  'MPGR0_SX420.WAV': {'spk_id': 'MPGR0',
#   'duration': 3.705625,
#   'phn': 'sil s iy m s er s ih z sil ah sil t ae sil ch z ih sil p r ih z sil w ih dh ah th ih m b l n iy dx l ih n sil th r eh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MPGR0/SX420.WAV.pt'},
#  'MCPM0_SX204.WAV': {'spk_id': 'MCPM0',
#   'duration': 2.425625,
#   'phn': 'sil iy v ih n ay ow sil k ey sh l ih sil g eh sil t dh m ah n d ey sil b l uw z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MCPM0/SX204.WAV.wav.pt'},
#  'MCPM0_SI564.WAV': {'spk_id': 'MCPM0',
#   'duration': 3.833625,
#   'phn': 'sil w ay ng sil g l ae s hh iy l z sil ah sil t ah sil b iy f aw n ih m sil b ow th hh ay sil ih n s eh m ay hh ay sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MCPM0/SI564.WAV.wav.pt'},
#  'MCPM0_SX114.WAV': {'spk_id': 'MCPM0',
#   'duration': 2.681625,
#   'phn': 'sil dh ah sil k aa r sil t uw n f iy sil ch ih z ih m ah s sil k r ae sil ah n ah sil t ae sil p ow l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MCPM0/SX114.WAV.pt'},
#  'MCPM0_SI1824.WAV': {'spk_id': 'MCPM0',
#   'duration': 4.1984375,
#   'phn': 'sil p aa z ah v r iy z ah l sil s sil t aa r sil w ah n ih sil g ow z sil t aa er sil z dh ih hh ae n y ih y uw z sil t ih m ey sil k y er m aa sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MCPM0/SI1824.WAV.pt'},
#  'MCPM0_SI1194.WAV': {'spk_id': 'MCPM0',
#   'duration': 2.7968125,
#   'phn': 'sil w ow sil b iy sil t ay sil dh iy ih n sil t ih v y uw iy sil hh ih f hh iy ae n s ih sil d v ey sil g l iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MCPM0/SI1194.WAV.pt'},
#  'MCPM0_SX24.WAV': {'spk_id': 'MCPM0',
#   'duration': 2.1568125,
#   'phn': 'sil aa l dh ow aa l w ey z ah l ow n w iy s ah v ay v sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MCPM0/SX24.WAV.pt'},
#  'MCPM0_SX384.WAV': {'spk_id': 'MCPM0',
#   'duration': 1.9648125,
#   'phn': 'sil p l iy sh aa n dh ih s sil k er sil f ih sil jh oy s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MCPM0/SX384.WAV.wav.pt'},
#  'MCPM0_SX294.WAV': {'spk_id': 'MCPM0',
#   'duration': 2.137625,
#   'phn': 'sil sh ih sil jh er ae s sil b ih sil k eh sil t n s sil m aa l z uw z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MCPM0/SX294.WAV.pt'},
#  'MMGG0_SX269.WAV': {'spk_id': 'MMGG0',
#   'duration': 2.1184375,
#   'phn': 'sil d uw ey sil t ih sil p ih sil k l f aa r m er z sil g r ow ow sil t s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MMGG0/SX269.WAV.pt'},
#  'MMGG0_SX359.WAV': {'spk_id': 'MMGG0',
#   'duration': 3.385625,
#   'phn': 'sil dh ih s ih s sil t ih m ey sil b r ey sil d aw n s uw n sil s ah s ey v y er f ay l z f r iy sil k w ah n l ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MMGG0/SX359.WAV.pt'},
#  'MMGG0_SI2339.WAV': {'spk_id': 'MMGG0',
#   'duration': 2.3168125,
#   'phn': 'sil g aa sh sil dh ah hh aw s sil d ah z th uh sil k l ay sil k ah m aa r sil g ah sil dh ow sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MMGG0/SI2339.WAV.pt'},
#  'MMGG0_SX449.WAV': {'spk_id': 'MMGG0',
#   'duration': 4.27525,
#   'phn': 'sil r aa l f sil p r ih sil p eh r sil r eh sil d s sil n ae sil p er w ih th f r eh sh sil l eh m ih n s aa s f er sil d ih n er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MMGG0/SX449.WAV.pt'},
#  'MMGG0_SI1079.WAV': {'spk_id': 'MMGG0',
#   'duration': 4.633625,
#   'phn': 'sil b oy z ih n m eh n sil g ow ah l aa ng n ih r ih v er sil b ae ng sil k aa r sil t uw sil d iy ae l sil k ow v z ih n dh ih sil t aa sil p aa r sil k ey sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MMGG0/SI1079.WAV.wav.pt'},
#  'MMGG0_SX179.WAV': {'spk_id': 'MMGG0',
#   'duration': 3.0208125,
#   'phn': 'sil w ih sil k ih sil b eh r l iy s iy dh ih f iy aa r sil z sil th r uw dh ih s sil n ow f l er ih s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MMGG0/SX179.WAV.pt'},
#  'MMGG0_SI1709.WAV': {'spk_id': 'MMGG0',
#   'duration': 2.073625,
#   'phn': 'sil dh ow z sil l ah v l iy w aa r ah l z hh iy sil ch aa r sil l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MMGG0/SI1709.WAV.wav.pt'},
#  'MMGG0_SX89.WAV': {'spk_id': 'MMGG0',
#   'duration': 2.361625,
#   'phn': 'sil ih sil s hh aa r sil t ih sil t eh l ah n ah r ih sil jh ih n ah l sil f er m ah f aa r sil jh er ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MMGG0/SX89.WAV.pt'},
#  'FSAH0_SI1874.WAV': {'spk_id': 'FSAH0',
#   'duration': 2.592,
#   'phn': 'sil hh iy m ay sil s ey er sil d uw s ah m th ih ng f uw l ih sh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FSAH0/SI1874.WAV.wav.pt'},
#  'FSAH0_SX74.WAV': {'spk_id': 'FSAH0',
#   'duration': 2.656,
#   'phn': 'sil eh n ih f ih sh l sil d eh sil d l ay n sil k ih n aa sil b iy sil p ow s sil p ow n sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FSAH0/SX74.WAV.wav.pt'},
#  'FSAH0_SI1244.WAV': {'spk_id': 'FSAH0',
#   'duration': 3.53925,
#   'phn': 'sil dh ah s sil k ah l sil t ah l uh sil t ih sil hh ih m sil b ah sil g ay sil d ae n sil ih m ey z sil d sil ae ng sil g r iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FSAH0/SI1244.WAV.wav.pt'},
#  'FSAH0_SX434.WAV': {'spk_id': 'FSAH0',
#   'duration': 2.6368125,
#   'phn': 'sil iy sil ch s sil t ae sil g sh er l iy f ay n sil z ey sil b ih sil g f aa n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FSAH0/SX434.WAV.wav.pt'},
#  'FSAH0_SX344.WAV': {'spk_id': 'FSAH0',
#   'duration': 2.0544375,
#   'phn': 'sil ay n ow ay sil d ih dx n sil m iy hh er er l iy ih n ah f sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FSAH0/SX344.WAV.wav.pt'},
#  'FSAH0_SI614.WAV': {'spk_id': 'FSAH0',
#   'duration': 4.6848125,
#   'phn': 'sil dh ih s sil b ih sil g f l eh sil k s sil b l v oy s w ih th ah n sil k aa m ah n r ey n sil jh hh eh z sil b ih n s ah sil p er sil b l iy sil d ih s ih sil p l ih n sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FSAH0/SI614.WAV.pt'},
#  'FSAH0_SX327.WAV': {'spk_id': 'FSAH0',
#   'duration': 4.9984375,
#   'phn': 'sil ae l r iy s iy v sil d ey sil jh oy n ah sil p oy n m ih n sil ih n dh ah sil b ay aa l ah sil jh iy ih n eh n sil jh ih n ih r iy ng sil d ih sil p aa m ih n sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FSAH0/SX327.WAV.pt'},
#  'FSAH0_SX164.WAV': {'spk_id': 'FSAH0',
#   'duration': 2.93125,
#   'phn': 'sil k er iy aa s ih dx iy ih m iy dx iy aa sil k r ih dx iy s eh l sil d ah m sil k ow ah sil g z ih s sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FSAH0/SX164.WAV.wav.pt'},
#  'FSJK1_SX305.WAV': {'spk_id': 'FSJK1',
#   'duration': 2.4768125,
#   'phn': 'sil k aa sil d ih sil jh sil ch iy z sil w ih dh sil ch ay v z ih z sil d ah l ih sh ih s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FSJK1/SX305.WAV.pt'},
#  'FSJK1_SI696.WAV': {'spk_id': 'FSJK1',
#   'duration': 3.5328125,
#   'phn': 'sil s ah m hh eh v w aa sil th r uw sil p ey n ih n sil s aa r ih dx ih sil b r ih ng y uw dh eh r m eh sil s ih sil jh ih v sil hh ow sil p sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FSJK1/SI696.WAV.wav.pt'},
#  'FSJK1_SX125.WAV': {'spk_id': 'FSJK1',
#   'duration': 2.265625,
#   'phn': 'sil w eh s sil ch eh s sil t ih ih z ih sil k aw n iy ih n uw y aa r sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FSJK1/SX125.WAV.wav.pt'},
#  'FSJK1_SX395.WAV': {'spk_id': 'FSJK1',
#   'duration': 2.7008125,
#   'phn': 'sil ay sil t uh sil k hh er w er sil f aa r ih sil b ah dx ih sh ih r ih l ih sil g ow n w ih th y uw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FSJK1/SX395.WAV.pt'},
#  'FSJK1_SI1025.WAV': {'spk_id': 'FSJK1',
#   'duration': 3.12325,
#   'phn': 'sil n ay s sil k ah n sil t r iy sil t ah m iy dx ih l ay ih n ih n f ey s sil t ih f ey s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FSJK1/SI1025.WAV.wav.pt'},
#  'FSJK1_SX35.WAV': {'spk_id': 'FSJK1',
#   'duration': 2.3424375,
#   'phn': 'sil hh eh l sil p s eh l ah sil b r ey sil y ih sil b r ah dh ih s ah sil k s eh s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FSJK1/SX35.WAV.wav.pt'},
#  'FSJK1_SI2285.WAV': {'spk_id': 'FSJK1',
#   'duration': 1.9904375,
#   'phn': 'sil dh ih sil g er l n aa sil d ih sil d ah n sil d er s sil t ae n sil d iy ng l iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FSJK1/SI2285.WAV.pt'},
#  'FSJK1_SX215.WAV': {'spk_id': 'FSJK1',
#   'duration': 3.001625,
#   'phn': 'sil dh ah s er m ih n eh m sil f ih s ay z sil dh ih n iy sil d f er f er m ih sil t ih v ae sil k sh ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FSJK1/SX215.WAV.wav.pt'},
#  'MPGH0_SX204.WAV': {'spk_id': 'MPGH0',
#   'duration': 2.1504375,
#   'phn': 'sil iy v ih n ay ih sil k ey sh n l iy sil g eh sil dh ah m ah n d ey sil b l uw z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MPGH0/SX204.WAV.wav.pt'},
#  'MPGH0_SX114.WAV': {'spk_id': 'MPGH0',
#   'duration': 2.297625,
#   'phn': 'sil k aa sil t uw n f iy sil ch ih z ah m ah s sil k r ae sil ah n ah sil t ae sil p l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MPGH0/SX114.WAV.pt'},
#  'MPGH0_SI675.WAV': {'spk_id': 'MPGH0',
#   'duration': 4.1088125,
#   'phn': 'sil b ow th ah v eh n ch uh aa l ih dx iy z ah sil p aa s sil b l l aa sil jh ih sil k l iy sil b ah sil p r ae sil t sil k l iy dh eh aa er m sil p aa s ah sil b l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MPGH0/SI675.WAV.pt'},
#  'MPGH0_SX24.WAV': {'spk_id': 'MPGH0',
#   'duration': 1.92,
#   'phn': 'sil hh ah dh ow ah w ih z ah l ow ng w iy s ah v ay v sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MPGH0/SX24.WAV.pt'},
#  'MPGH0_SI1554.WAV': {'spk_id': 'MPGH0',
#   'duration': 3.8848125,
#   'phn': 'sil dh ey aa f ih sil n ow sil p ih n y ih n sil d z sil v aa l ah n sil t ih r sil n ah th iy ng sil b iy sil t r ey sil n ow m ow sh n sil z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MPGH0/SI1554.WAV.pt'},
#  'MPGH0_SX384.WAV': {'spk_id': 'MPGH0',
#   'duration': 2.06725,
#   'phn': 'sil p l iy sh aa n dh ih s sil k er f ih sil jh oy s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MPGH0/SX384.WAV.wav.pt'},
#  'MPGH0_SI924.WAV': {'spk_id': 'MPGH0',
#   'duration': 2.4064375,
#   'phn': 'sil dh ey sil k n s ih dx er ih sil s ih m sil p l iy s ay n ah v aa r sil t ay m sil z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MPGH0/SI924.WAV.pt'},
#  'MPGH0_SX294.WAV': {'spk_id': 'MPGH0',
#   'duration': 2.048,
#   'phn': 'sil sh ih sil jh er ae s sil b iy sil k eh sil p sil t n s sil m aa l z uw z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MPGH0/SX294.WAV.pt'},
#  'MRDD0_SX330.WAV': {'spk_id': 'MRDD0',
#   'duration': 3.15525,
#   'phn': 'sil k aw n sil dh ih n ah m sil b er ih v sil t iy s sil p uw n z ah v s ow iy s aa s dh eh sil ch uw ae sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRDD0/SX330.WAV.wav.pt'},
#  'MRDD0_SX240.WAV': {'spk_id': 'MRDD0',
#   'duration': 2.77125,
#   'phn': 'sil ih sil s sil n aa dx iy z iy sil t ah sil k r ey dx eh l uw m ih n ey dx iy ng ih sil g z ae m sil p l s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRDD0/SX240.WAV.pt'},
#  'MRDD0_SX60.WAV': {'spk_id': 'MRDD0',
#   'duration': 3.328,
#   'phn': 'sil dh ah l eh sil jh ih s l ey sil ch er m eh sil t ih sil jh ah sil jh sil dh ih s sil t ey dx ah v sil p ah sil b l ih sil k eh sil jh ih sil k ey sh n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRDD0/SX60.WAV.pt'},
#  'MRDD0_SI2310.WAV': {'spk_id': 'MRDD0',
#   'duration': 2.496,
#   'phn': 'sil ih n aw n aa r er sil d ow n sil ch uw ih ng sil k er ih sil jh hh ih m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRDD0/SI2310.WAV.pt'},
#  'MRDD0_SX150.WAV': {'spk_id': 'MRDD0',
#   'duration': 2.0224375,
#   'phn': 'sil v y eh sil n ih m iy s sil k w ih s iy n ih z ih sil k s sil k w ih z ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRDD0/SX150.WAV.wav.pt'},
#  'MRDD0_SI1050.WAV': {'spk_id': 'MRDD0',
#   'duration': 3.9488125,
#   'phn': 'sil b ow th ih sil k ih n sil d ih sh sil ih n z eh n dh eh sil k ah m sil p l ih s ih dx iy aa r sil d aa sil k m eh n ih dx ih n sil k ah n sil s ih dx er v l sil d iy sil t ey l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRDD0/SI1050.WAV.wav.pt'},
#  'MRDD0_SI1680.WAV': {'spk_id': 'MRDD0',
#   'duration': 2.89925,
#   'phn': 'sil hh ih sil ch eh sil d ih n sil t uw ah m ow sil t eh l ah n sil d r ow v sil d aw n sil t aw n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRDD0/SI1680.WAV.pt'},
#  'MRDD0_SX277.WAV': {'spk_id': 'MRDD0',
#   'duration': 2.265625,
#   'phn': 'sil dh ah r ow z sil k ah r s aa r sil jh s sil m eh l sil s sil w iy sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRDD0/SX277.WAV.pt'},
#  'MJWT0_SI751.WAV': {'spk_id': 'MJWT0',
#   'duration': 3.0784375,
#   'phn': 'sil s er v ih n f r ae ng sil k f er dx er sil b ah n s sil er ih z ah m iy sil d ih sh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MJWT0/SI751.WAV.pt'},
#  'MJWT0_SX391.WAV': {'spk_id': 'MJWT0',
#   'duration': 2.3104375,
#   'phn': 'sil dh ey aa l ay sil k l aa ng hh aa sil sh aw er s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MJWT0/SX391.WAV.wav.pt'},
#  'MJWT0_SX211.WAV': {'spk_id': 'MJWT0',
#   'duration': 3.161625,
#   'phn': 'sil ow n l ih dh ah sil b eh s sil p l ey er z ih n sil jh oy sil p aa sil p ih l eh er dx iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MJWT0/SX211.WAV.pt'},
#  'MJWT0_SX301.WAV': {'spk_id': 'MJWT0',
#   'duration': 3.584,
#   'phn': 'sil w iy l ay sil b l uw sil ch iy z sil b ah sil t v ih sil t er sil p er f er s sil w ih s sil ch iy s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MJWT0/SX301.WAV.wav.pt'},
#  'MJWT0_SX121.WAV': {'spk_id': 'MJWT0',
#   'duration': 3.129625,
#   'phn': 'sil t r eh s sil p ae s ih ng ih z f uh sil b ih dx n ah n s ah sil jh eh sil t ih sil p eh n l sil t iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MJWT0/SX121.WAV.wav.pt'},
#  'MJWT0_SI1291.WAV': {'spk_id': 'MJWT0',
#   'duration': 4.729625,
#   'phn': 'sil dh ey sh uh sil d l ih v ih n m aa dx ah s er sil k m s sil t ae n s ih z sil ah v oy dx ih ng aa l sil k ih n s sil p ih sil k y uw ah s sil k ih n s ah m sil p sh n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MJWT0/SI1291.WAV.pt'},
#  'MJWT0_SX31.WAV': {'spk_id': 'MJWT0',
#   'duration': 2.336,
#   'phn': 'sil ah sil g uh sil ae dx ah sil t uw sil ih z sil ah n sil b iy dx ah sil b l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MJWT0/SX31.WAV.wav.pt'},
#  'MJWT0_SI1381.WAV': {'spk_id': 'MJWT0',
#   'duration': 4.64,
#   'phn': 'sil b ah sil b r iy f sil l iy sil dh ah sil t aa sil p iy ng sil k ih n f ih sil g y er ey sh n m ah s sil b iy ih sil g z ae m ih n f aa er sil s ih n f er ih n s ih s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MJWT0/SI1381.WAV.wav.pt'},
#  'MRWS0_SI1732.WAV': {'spk_id': 'MRWS0',
#   'duration': 1.721625,
#   'phn': 'sil b ih dx er ah n r iy z n iy ng sil jh eh l ah s iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRWS0/SI1732.WAV.wav.pt'},
#  'MRWS0_SX382.WAV': {'spk_id': 'MRWS0',
#   'duration': 2.8544375,
#   'phn': 'sil jh aa r sil jh ih z sil p eh r ih n oy dx ah sil b aw dx ah f y uw sil ch er sil g ae s sh aa r dx ih sil jh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRWS0/SX382.WAV.pt'},
#  'MRWS0_SX22.WAV': {'spk_id': 'MRWS0',
#   'duration': 2.13125,
#   'phn': 'sil w ih n aa l eh l s f ey l z y uw z f aa r s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRWS0/SX22.WAV.wav.pt'},
#  'MRWS0_SX292.WAV': {'spk_id': 'MRWS0',
#   'duration': 3.2,
#   'phn': 'sil dh iy z ih sil s sil k l uw s ih v sil d aa sil ah m ih n sil s sil m ah s sil b iy l aa sil t ah sil p ih dx aa l sil t ay m z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRWS0/SX292.WAV.wav.pt'},
#  'MRWS0_SI472.WAV': {'spk_id': 'MRWS0',
#   'duration': 2.841625,
#   'phn': 'sil hh iy sil p l ey sil b ae s sil k ih sil aa l dh eh r w ay l w er sil iy ng sil t aa r dx ah l aa sil d ih sil g r iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRWS0/SI472.WAV.wav.pt'},
#  'MRWS0_SX112.WAV': {'spk_id': 'MRWS0',
#   'duration': 2.656,
#   'phn': 'sil t ah sil b ow sil s er sil k ey sil ah sil b l ah v hh aa l ih ng hh y uw sil jh l ow sil z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRWS0/SX112.WAV.wav.pt'},
#  'MRWS0_SX202.WAV': {'spk_id': 'MRWS0',
#   'duration': 1.408,
#   'phn': 'sil hh ah m ah sil ch ah l aw ah n s sil d uw y uw sil g eh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRWS0/SX202.WAV.pt'},
#  'MRWS0_SI1102.WAV': {'spk_id': 'MRWS0',
#   'duration': 4.249625,
#   'phn': 'sil dh ih sil b iy n ih sil k s sil k r ey v ih s eh sil sh l ah sil s sil p ih r iy ih n s ih n w ih sil ch dh eh r hh ow l sil b iy ih ng sil p er sil t ih s sil p ey sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRWS0/SI1102.WAV.pt'},
#  'FVMH0_SX296.WAV': {'spk_id': 'FVMH0',
#   'duration': 2.265625,
#   'phn': 'sil dh ih sil t uw aa dx ih s ih sil s sh ey n sh aa dx ih sil g r ae f s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FVMH0/SX296.WAV.pt'},
#  'FVMH0_SX116.WAV': {'spk_id': 'FVMH0',
#   'duration': 2.009625,
#   'phn': 'sil k l ae s sil p dh ah s sil k r uw ih n y ah l eh f sil t hh ae n sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FVMH0/SX116.WAV.wav.pt'},
#  'FVMH0_SX206.WAV': {'spk_id': 'FVMH0',
#   'duration': 2.99525,
#   'phn': 'sil w ah n sil p iy l iy ng ih n aa r ih n jh ih dx ih z hh aa sil n aa sil t ah s sil p r ey sil jh uw s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FVMH0/SX206.WAV.wav.pt'},
#  'FVMH0_SX386.WAV': {'spk_id': 'FVMH0',
#   'duration': 2.03525,
#   'phn': 'sil w ih sil ch sil ch er ch z ih dh ih s m ih s sil w er sh ih sil p ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FVMH0/SX386.WAV.wav.pt'},
#  'FVMH0_SI836.WAV': {'spk_id': 'FVMH0',
#   'duration': 4.3008125,
#   'phn': 'sil n ow m eh n y ih f ae sil sh er ah hh z sil t ey sil k ih n iy ih n ih sh ah sil t ih v ih n sil p oy n sil t iy aw sil dh ih sil k aa s sil ih n v aa l v sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FVMH0/SI836.WAV.wav.pt'},
#  'FVMH0_SI1466.WAV': {'spk_id': 'FVMH0',
#   'duration': 4.21125,
#   'phn': 'sil ih n s ih m sil p l ih sil t er m z ih dx ah m aw n s sil t ih sil p oy n sil t iy ng dh ah sil p l ae sil f aa m ah n ah sil p r aa sil p ah sil d ih r eh sil sh ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FVMH0/SI1466.WAV.wav.pt'},
#  'FVMH0_SX26.WAV': {'spk_id': 'FVMH0',
#   'duration': 2.06725,
#   'phn': 'sil m ow s y ah ng r ay z er l iy eh v r iy m aa n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FVMH0/SX26.WAV.pt'},
#  'FVMH0_SI2096.WAV': {'spk_id': 'FVMH0',
#   'duration': 2.752,
#   'phn': 'sil r ae n ih w ey ih n ah sil b l ae sil n ay w ih th ah l aa f l w eh dx ih sil m ae n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FVMH0/SI2096.WAV.pt'},
#  'MRCG0_SX78.WAV': {'spk_id': 'MRCG0',
#   'duration': 3.4688125,
#   'phn': 'sil d aa sil t er z sil p er s sil k r ay sil d r ah sil g z sil t uw f r ih l ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRCG0/SX78.WAV.pt'},
#  'MRCG0_SX168.WAV': {'spk_id': 'MRCG0',
#   'duration': 2.64325,
#   'phn': 'sil hh uw sil t uh sil k dh ih sil k ay y ae sil d aw n dh ah sil b ay y uw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRCG0/SX168.WAV.pt'},
#  'MRCG0_SX438.WAV': {'spk_id': 'MRCG0',
#   'duration': 4.601625,
#   'phn': 'sil sh eh l sh aa sil k aa z sil b ay sh r ae sil n ah l ih s ah m sil t ay m z sil k y er sil th r uw sil g r uw sil th eh er sil p iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRCG0/SX438.WAV.pt'},
#  'MRCG0_SX258.WAV': {'spk_id': 'MRCG0',
#   'duration': 3.5904375,
#   'phn': 'sil dh iy eh s ey ah n sil d ih n ay ah sil b l iy r iy f l eh sil k s aa r v y uw ey sil b l ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRCG0/SX258.WAV.wav.pt'},
#  'MRCG0_SI2058.WAV': {'spk_id': 'MRCG0',
#   'duration': 2.6624375,
#   'phn': 'sil w ay ey n sil ch uw sil p l ey ih n sil b aa l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRCG0/SI2058.WAV.pt'},
#  'MRCG0_SI798.WAV': {'spk_id': 'MRCG0',
#   'duration': 3.76325,
#   'phn': 'sil w ih n y er l eh s f ih sil t iy sil d sil th ih ng sh uh s n ae sil ch r l ih l uh sil b r ay dx er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRCG0/SI798.WAV.pt'},
#  'MRCG0_SX348.WAV': {'spk_id': 'MRCG0',
#   'duration': 4.0768125,
#   'phn': 'sil ah l ah v ah s sil k uw sil p ah v dh ae dx eh sil z aa dx ih sil p er sil p l ih n sil t er sil k oy sh er sil b er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRCG0/SX348.WAV.pt'},
#  'MRCG0_SI1428.WAV': {'spk_id': 'MRCG0',
#   'duration': 4.81925,
#   'phn': 'sil ih n d eh sil k s w er sil d z ih n ah l eh sil t r aa n ih sil k s sil w ih sil ch ih z sil m ey sil b iy r uw z er v sil d ih n dh ah f aa l ow iy ng w ey sil z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MRCG0/SI1428.WAV.pt'},
#  'FDAW0_SI1271.WAV': {'spk_id': 'FDAW0',
#   'duration': 4.864,
#   'phn': 'sil dh ih s hh eh z sil b eh n ih sil ch ih sil b uw dx ih sil t uw hh ih l iy ih m f ih l m f l ow ah n dh ih v ey sil p ah sil p r eh sh er th ah m aa m ih dx er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FDAW0/SI1271.WAV.wav.pt'},
#  'FDAW0_SX326.WAV': {'spk_id': 'FDAW0',
#   'duration': 2.873625,
#   'phn': 'sil s sil t iy v sil k ah l eh sil s r eh r ih n aa v l sil k oy n s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FDAW0/SX326.WAV.wav.pt'},
#  'FDAW0_SX146.WAV': {'spk_id': 'FDAW0',
#   'duration': 2.6304375,
#   'phn': 'sil s ih sil k l ih sil k l sil p r ow sil g r ae m z sil w l n eh v er sil k ah m sil p aa l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FDAW0/SX146.WAV.wav.pt'},
#  'FDAW0_SX56.WAV': {'spk_id': 'FDAW0',
#   'duration': 3.02725,
#   'phn': 'sil ae sil k ih sil d eh m ih sil ae sil t ah sil t uw sil g eh er n sil t iy z er sil d ih sil p l ow m ah sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FDAW0/SX56.WAV.pt'},
#  'FDAW0_SI1406.WAV': {'spk_id': 'FDAW0',
#   'duration': 2.5408125,
#   'phn': 'sil r iy s iy v ih ng n ow ae n s er dh ey s eh dh ih f ay er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FDAW0/SI1406.WAV.wav.pt'},
#  'FDAW0_SX236.WAV': {'spk_id': 'FDAW0',
#   'duration': 2.5088125,
#   'phn': 'sil k l ih r sil p ih n aw n s iy ey sh ih n ih z ih sil p r iy sh iy ey dx ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FDAW0/SX236.WAV.pt'},
#  'FDAW0_SI2036.WAV': {'spk_id': 'FDAW0',
#   'duration': 4.793625,
#   'phn': 'sil ae z ih z f iy sil s l ow sil hh iy f eh l sil t ih sh ey m ah v dh ah sil p ae n ih sil k ih n r ih z aa l v sil t ih m ey sil k ey s sil t ae n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FDAW0/SI2036.WAV.wav.pt'},
#  'FDAW0_SX416.WAV': {'spk_id': 'FDAW0',
#   'duration': 2.61125,
#   'phn': 'sil ey y uw sil jh sil p aw er aw dx ih sil jh r eh r l iy ah sil k er s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FDAW0/SX416.WAV.wav.pt'},
#  'MTRR0_SI918.WAV': {'spk_id': 'MTRR0',
#   'duration': 4.128,
#   'phn': 'sil w iy n ow dh ah dx ae sil t er z sil k ah n l er n sil t ih sil p ih sil t r ey ah w ay sil d v er ay ih dx iy ih v sil k eh er sil t er r ow l z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MTRR0/SI918.WAV.wav.pt'},
#  'MTRR0_SI2178.WAV': {'spk_id': 'MTRR0',
#   'duration': 2.70725,
#   'phn': 'sil hh er sil k aa f s aw n d ah sil l ay sil k l aa th r ih sil p ih ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MTRR0/SI2178.WAV.pt'},
#  'MTRR0_SX378.WAV': {'spk_id': 'MTRR0',
#   'duration': 3.4688125,
#   'phn': 'sil ay sil jh uh s aa sil jh ih m n ih ih dh ah n uw aa sil k iy ih l aa sil jh sil k l m y uw z iy ih m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MTRR0/SX378.WAV.pt'},
#  'MTRR0_SX108.WAV': {'spk_id': 'MTRR0',
#   'duration': 2.7968125,
#   'phn': 'sil hh ih s sil k ae l sil p w ah z sil b l ih s sil t ih sil d f r ah m sil t ah dx ey z hh aa sil s ah n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MTRR0/SX108.WAV.pt'},
#  'MTRR0_SX198.WAV': {'spk_id': 'MTRR0',
#   'duration': 2.5664375,
#   'phn': 'sil n ow w iy sil jh ih n s sil w eh dx ih z ah m ey sil d ah v l ae m z sil w uh l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MTRR0/SX198.WAV.pt'},
#  'MTRR0_SX18.WAV': {'spk_id': 'MTRR0',
#   'duration': 2.777625,
#   'phn': 'sil ae l m ow n ih hh aa m z ah sil d ih v aa s sil m ae n z w eh l sil th sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MTRR0/SX18.WAV.wav.pt'},
#  'MTRR0_SI1548.WAV': {'spk_id': 'MTRR0',
#   'duration': 2.35525,
#   'phn': 'sil y aa l w aa n ah w aa sil w aa sil k iy s eh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MTRR0/SI1548.WAV.wav.pt'},
#  'MTRR0_SX288.WAV': {'spk_id': 'MTRR0',
#   'duration': 3.328,
#   'phn': 'sil b r ah sh f ay er z ah sil k aa m ah n ah n dh ah sil d r ay ah n sil d ah sil b r ah sh ah v n ah v aa dx ah sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MTRR0/SX288.WAV.wav.pt'},
#  'FECD0_SX338.WAV': {'spk_id': 'FECD0',
#   'duration': 3.321625,
#   'phn': 'sil dh ih sil d aa r sil k m er sil k iy l uh sil g uw n w aw n sil d er r aw n d f er m ay l s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FECD0/SX338.WAV.wav.pt'},
#  'FECD0_SI1418.WAV': {'spk_id': 'FECD0',
#   'duration': 5.5744375,
#   'phn': 'sil p er s n l sil p r iy sil d ih s sil p ih z ih sh ih n s sil t eh n sil t ih sil b l ah n sil dh ih ey ah sil eh n ih n sil t er n ah v oy s ih z sil w eh l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FECD0/SI1418.WAV.pt'},
#  'FECD0_SX248.WAV': {'spk_id': 'FECD0',
#   'duration': 3.0528125,
#   'phn': 'sil r iy dx iy ng ih n sil p aa r l ay sil g ih v sh uw ay s sil t r ey n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FECD0/SX248.WAV.wav.pt'},
#  'FECD0_SX68.WAV': {'spk_id': 'FECD0',
#   'duration': 2.9504375,
#   'phn': 'sil ah f sil g r ey sil jh er s sil t ae dx ih s sil t er r iy f l eh sil ch er sil w eh l sil th sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FECD0/SX68.WAV.wav.pt'},
#  'FECD0_SI2048.WAV': {'spk_id': 'FECD0',
#   'duration': 2.6048125,
#   'phn': 'sil dh eh sil k ih sil d hh ae s n ow m ae n er s sil b oy s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FECD0/SI2048.WAV.wav.pt'},
#  'FECD0_SI788.WAV': {'spk_id': 'FECD0',
#   'duration': 5.1584375,
#   'phn': 'sil w iy eh v sil b iy sil k ah m ae m er sil ch er ih n ch er ih n sil s eh sil s sil p er sil t s sil eh n f ay n f eh dh er sil d y aa r sil b er sil d s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FECD0/SI788.WAV.pt'},
#  'FECD0_SX158.WAV': {'spk_id': 'FECD0',
#   'duration': 2.5728125,
#   'phn': 'sil dh ih sil d r ah ng sil k er sil ih z ih s ow sh l aw sil k ey ae s sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FECD0/SX158.WAV.wav.pt'},
#  'FECD0_SX428.WAV': {'spk_id': 'FECD0',
#   'duration': 3.66725,
#   'phn': 'sil ey sil k r ae sil ch ae l ah n sil jh sil d m iy sil b ah sil ey sil k w ih sil k s sil t ae sil b v ae ng sil k w ih sh sil t hh ih m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FECD0/SX428.WAV.wav.pt'},
#  'MDPK0_SX153.WAV': {'spk_id': 'MDPK0',
#   'duration': 2.937625,
#   'phn': 'sil s sil k ah l ae s sil t ih sil d ae sil t ih sil t uw sil d ih z sil jh ah sh sil b ay s sil t ae n er dx ay z sil t eh s sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MDPK0/SX153.WAV.wav.pt'},
#  'MDPK0_SX423.WAV': {'spk_id': 'MDPK0',
#   'duration': 3.1424375,
#   'phn': 'sil s sil m ae sh sil l ay sil b ah l sil z ih n ih sil k ae s sil v ae y uw w l sil d ah m ih n ih sh sil t ih n ah th ih ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MDPK0/SX423.WAV.pt'},
#  'MDPK0_SI1683.WAV': {'spk_id': 'MDPK0',
#   'duration': 1.93925,
#   'phn': 'sil hh ae v dh ey ih n hh ae r ih dx ih sil s ah m ah n iy er s ah m sil th ih ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MDPK0/SI1683.WAV.pt'},
#  'MDPK0_SX243.WAV': {'spk_id': 'MDPK0',
#   'duration': 2.7008125,
#   'phn': 'sil dh ey aa l ah sil g r iy dh ih sil dh iy eh s ey ih z sil b eh r l iy ih n sil t eh l ah sil jh ah sil b l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MDPK0/SX243.WAV.wav.pt'},
#  'MDPK0_SX333.WAV': {'spk_id': 'MDPK0',
#   'duration': 3.481625,
#   'phn': 'sil eh n ih sil d ah l sil m ey l sil b ae sil b uw n z sil t iy th er n aa sil s uh dx ah sil b l f er iy dx ih ng sil sh eh l f ih sh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MDPK0/SX333.WAV.pt'},
#  'MDPK0_SI1053.WAV': {'spk_id': 'MDPK0',
#   'duration': 3.616,
#   'phn': 'sil w ah dx eh v er dh eh r f aa l sil t s dh ey er n aa hh ih sil p ih sil k r ih sil t s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MDPK0/SI1053.WAV.wav.pt'},
#  'MDPK0_SX63.WAV': {'spk_id': 'MDPK0',
#   'duration': 2.3744375,
#   'phn': 'sil k aa n sil t ih n eh n l sil d r ih f sil t ih z ih sil jh iy ih l aa sil jh ih sil k l th ih r iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MDPK0/SX63.WAV.wav.pt'},
#  'MDPK0_SI552.WAV': {'spk_id': 'MDPK0',
#   'duration': 1.657625,
#   'phn': 'sil w iy th ih ng sil d ih f r ih n l iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MDPK0/SI552.WAV.pt'},
#  'MMRP0_SX414.WAV': {'spk_id': 'MMRP0',
#   'duration': 3.424,
#   'phn': 'sil ay r ih sh y ah ng sil g s sil t ih z iy sil t f r eh sh sil k ih sil p ih z f ah sil b r eh sil f ih s sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MMRP0/SX414.WAV.pt'},
#  'MMRP0_SI774.WAV': {'spk_id': 'MMRP0',
#   'duration': 3.50725,
#   'phn': 'sil p l ey s sil w er sil k aa n ey f l ae sil t s er f ih s sil ae n sil s sil m uw dh aw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MMRP0/SI774.WAV.pt'},
#  'MMRP0_SX234.WAV': {'spk_id': 'MMRP0',
#   'duration': 3.481625,
#   'phn': 'sil dh ah sil p ey sil p er sil b oy sil b aa sil t uw ae sil p l z ae n sil th r iy ay s ih z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MMRP0/SX234.WAV.wav.pt'},
#  'MMRP0_SX324.WAV': {'spk_id': 'MMRP0',
#   'duration': 4.6208125,
#   'phn': 'sil dh ah l ow sil k l sil d r ah sil g s sil t aa ah w ah z sil ch aa r z sil d w ih th ih l iy sil l iy sil d ih s sil p eh n sil s ih ng sil t r ae ng sil k w l ay z ih z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MMRP0/SX324.WAV.pt'},
#  'MMRP0_SI2034.WAV': {'spk_id': 'MMRP0',
#   'duration': 1.568,
#   'phn': 'sil m ey sil k ih sil t sil k ah m aa f aa l r ay sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MMRP0/SI2034.WAV.pt'},
#  'MMRP0_SX144.WAV': {'spk_id': 'MMRP0',
#   'duration': 3.168,
#   'phn': 'sil dh ah w ih l ah w iy w uh m ih n w aa ey m ah s sil k r ae sil k ow sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MMRP0/SX144.WAV.pt'},
#  'MMRP0_SI717.WAV': {'spk_id': 'MMRP0',
#   'duration': 2.489625,
#   'phn': 'sil n aw hh ih r ih z sil t r uw l ih ey m aa r v l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MMRP0/SI717.WAV.wav.pt'},
#  'MMRP0_SX54.WAV': {'spk_id': 'MMRP0',
#   'duration': 3.872,
#   'phn': 'sil dh ih iy s sil t ih n sil k ow s sil t ih z ey sil p l ey s f ah sil p y uh sil p l eh sh er ih n ih sil k s ay sil m ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/MMRP0/SX54.WAV.wav.pt'},
#  'FMEM0_SI747.WAV': {'spk_id': 'FMEM0',
#   'duration': 3.02725,
#   'phn': 'sil ae sil d r iy m ey n iy ng ih n sil g r iy dx iy ih n sil s sil ih n sil b r ih ng sil t uw ah sil b oy l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FMEM0/SI747.WAV.wav.pt'},
#  'FMEM0_SI1377.WAV': {'spk_id': 'FMEM0',
#   'duration': 3.865625,
#   'phn': 'sil eh z dh iy z sil m ae l ah sil d iy z ow v ah l ae sil s ow m ah s dh ih sil k y uh ah sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FMEM0/SI1377.WAV.wav.pt'},
#  'FMEM0_SX333.WAV': {'spk_id': 'FMEM0',
#   'duration': 5.13925,
#   'phn': 'sil ae n ae dx ah l sil m ey l sil b ae sil b uw n z sil t iy th sil ah r n aa sil s uw dx ah sil b l f er iy dx iy ng sh eh l f ih sh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FMEM0/SX333.WAV.pt'},
#  'FMEM0_SX387.WAV': {'spk_id': 'FMEM0',
#   'duration': 3.79525,
#   'phn': 'sil dh ih sil jh ay y ih n sil r eh sil w uh sil z sil sh ih m ih sil d sil ih n dh ah sil g l ih s sil n ih ng sil s ah n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FMEM0/SX387.WAV.pt'},
#  'FMEM0_SX207.WAV': {'spk_id': 'FMEM0',
#   'duration': 2.06725,
#   'phn': 'sil d uw y uw hh ih r dh ah s l ey sil b eh l z r ih ng iy ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FMEM0/SX207.WAV.pt'},
#  'FMEM0_SI2007.WAV': {'spk_id': 'FMEM0',
#   'duration': 3.545625,
#   'phn': 'sil t uw hh ih z sil p ah z l m eh n sil t sil dh eh s ah sil n l iy w uh z sil n ow hh ey z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FMEM0/SI2007.WAV.pt'},
#  'FMEM0_SX117.WAV': {'spk_id': 'FMEM0',
#   'duration': 3.232,
#   'phn': 'sil dh ah m ae ng sil g ow sil ih n dh ih sil p ah sil p ay y ah sil aa r ih n ah sil b ow l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FMEM0/SX117.WAV.pt'},
#  'FMEM0_SX297.WAV': {'spk_id': 'FMEM0',
#   'duration': 2.6944375,
#   'phn': 'sil r aa sil k eh n r ow l m y uw z ih sil k hh eh z ih sil g r ey sil r ih dh ih m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FMEM0/SX297.WAV.wav.pt'},
#  'FDML0_SX429.WAV': {'spk_id': 'FDML0',
#   'duration': 2.7648125,
#   'phn': 'sil ey sil t uw th sil p ey s sil t uw sil b sil sh uh sil b iy s sil k w iy z f m dh ah sil b aa dx ah m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FDML0/SX429.WAV.pt'},
#  'FDML0_SI1779.WAV': {'spk_id': 'FDML0',
#   'duration': 2.5344375,
#   'phn': 'sil dh ey y uw z sil p iy ng sil t ae n aa sil k r iy m sil p aw sil d er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FDML0/SI1779.WAV.pt'},
#  'FDML0_SX249.WAV': {'spk_id': 'FDML0',
#   'duration': 1.9968125,
#   'phn': 'sil ay ey eh v r iy oy s sil t ah aa n aa r ih z sil p l ey sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FDML0/SX249.WAV.wav.pt'},
#  'FDML0_SX159.WAV': {'spk_id': 'FDML0',
#   'duration': 2.86725,
#   'phn': 'sil dh ah sil g ah v m ih n sil s aa aa th r ih z ey sh ih n ah v hh ih s ih dx ih z n sh ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FDML0/SX159.WAV.pt'},
#  'FDML0_SI1149.WAV': {'spk_id': 'FDML0',
#   'duration': 3.6224375,
#   'phn': 'sil dh ih r iy s sil p aa n sil s ih r iy ae sil sh n z sil d aa m ih n ey ih sil d sil b ay ih sil k ah n s er n f uh w ah dx ih z v ae n ih sh ih ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FDML0/SI1149.WAV.pt'},
#  'FDML0_SX339.WAV': {'spk_id': 'FDML0',
#   'duration': 2.56,
#   'phn': 'sil d ih sil sh aa n sil k ae sil ch dh ah sil b ih sil g uw s sil w ah dh aw sil hh eh l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR1/FDML0/SX339.WAV.pt'},
# ...
#   'phn': 'sil dh eh n s ih m er f ih f sil t iy m ih n ih s l aa ng sil g er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MMEB0/SI727.WAV.pt'},
#  'MMEB0_SX97.WAV': {'spk_id': 'MMEB0',
#   'duration': 2.7328125,
#   'phn': 'sil p eh ng w ih n z l ih v n ih er dh ah ay s iy ae n aa r dx ih sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MMEB0/SX97.WAV.wav.pt'},
#  'MMEB0_SX7.WAV': {'spk_id': 'MMEB0',
#   'duration': 2.32325,
#   'phn': 'sil n ah th iy ng ih z ae z ah f eh n s ih v ae z ih n ih s n s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MMEB0/SX7.WAV.pt'},
#  'MMEB0_SX327.WAV': {'spk_id': 'MMEB0',
#   'duration': 4.441625,
#   'phn': 'sil aw w iy s iy v sil d ih sil jh oy n ah sil p oy n m ih n ih n iy sil b ay aa l ah sil jh iy eh n dh iy eh n sil jh ih n er ih ng sil d ih sil p aa r m ih n sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MMEB0/SX327.WAV.pt'},
#  'MMEB0_SX187.WAV': {'spk_id': 'MMEB0',
#   'duration': 1.8048125,
#   'phn': 'sil dh ey aa f sil t n sil g ow aw sil n iy iy v n iy n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MMEB0/SX187.WAV.wav.pt'},
#  'MMEB0_SI1987.WAV': {'spk_id': 'MMEB0',
#   'duration': 2.112,
#   'phn': 'sil eh n iy w ey ih w ah z eh v ih dx eh n w ah dx hh iy hh ae dx ih m ay n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MMEB0/SI1987.WAV.pt'},
#  'MMEB0_SI1357.WAV': {'spk_id': 'MMEB0',
#   'duration': 3.89125,
#   'phn': 'sil dh ah sil p aa sil p ih l ey sh ih n sil k ih n dh eh r sil b ay r uw sil p l eh n ih sh ih s eh l f ih n ae sil sh uw sil r ow l aa r sil jh er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MMEB0/SI1357.WAV.pt'},
#  'MMEB0_SX367.WAV': {'spk_id': 'MMEB0',
#   'duration': 2.61125,
#   'phn': 'sil dh ah s er sil p l ah sh uw z uh s ow l dx eh dx ih sil d ih s sil k aw n sil p r ay s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MMEB0/SX367.WAV.wav.pt'},
#  'FNTB0_SX33.WAV': {'spk_id': 'FNTB0',
#   'duration': 2.6944375,
#   'phn': 'sil k ow sil k ih n ah sil k r iy m sil p ay m ey sil k s ah n ay s sil d ih z er sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/FNTB0/SX33.WAV.wav.pt'},
#  'FNTB0_SX303.WAV': {'spk_id': 'FNTB0',
#   'duration': 2.1504375,
#   'phn': 'sil dh ah sil b l uw sil jh ey f l uw ow v er dh ah hh ay sil b ih l sil d ih ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/FNTB0/SX303.WAV.pt'},
#  'FNTB0_SI1203.WAV': {'spk_id': 'FNTB0',
#   'duration': 2.432,
#   'phn': 'sil n s sil t eh dx ah v dh ae sil hh iy w ih z ih ng sil g ah l f sil t sil b ay sil b eh sil d l ah m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/FNTB0/SI1203.WAV.wav.pt'},
#  'FNTB0_SI573.WAV': {'spk_id': 'FNTB0',
#   'duration': 2.592,
#   'phn': 'sil t iy sil ch ih ng g ay sil z er ng sil k l uw dx ih sil w ih th iy sil ch sil r eh sil k er sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/FNTB0/SI573.WAV.pt'},
#  'FNTB0_SX393.WAV': {'spk_id': 'FNTB0',
#   'duration': 2.41925,
#   'phn': 'sil sh iy y uw z ih z sil b ow th n ey m z ih n sil t er sil ch ey n sil jh ih sil b l ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/FNTB0/SX393.WAV.wav.pt'},
#  'FNTB0_SI679.WAV': {'spk_id': 'FNTB0',
#   'duration': 4.97925,
#   'phn': 'sil hh iy ih z sil n aa sil t aa sil k ih ng ih n dh ah m ey n ah sil b aw sil p r aa sil b ah sil b ih l ih dx iy z sil r ih s sil k s ih n sil d ey n sil jh er ih n sil jh eh n er l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/FNTB0/SI679.WAV.wav.pt'},
#  'FNTB0_SX123.WAV': {'spk_id': 'FNTB0',
#   'duration': 2.9888125,
#   'phn': 'sil ah s sil k r uw sil d r aa v er ih z sil m ey sil d f r m v aa sil k ah ih n aa r n sil ch sil jh uw s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/FNTB0/SX123.WAV.wav.pt'},
#  'FNTB0_SX213.WAV': {'spk_id': 'FNTB0',
#   'duration': 2.54725,
#   'phn': 'sil dh ih n uw z ey sil jh ih n s iy hh ay er sil d er sil g r ey sil jh er n ah l ih s sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/FNTB0/SX213.WAV.pt'},
#  'MBEF0_SX201.WAV': {'spk_id': 'MBEF0',
#   'duration': 2.3424375,
#   'phn': 'sil hh ah sil p r ow sil ch er ih n er v y uw w ih s sil t ae sil ch uw eh s sil k m sil p ow sh er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MBEF0/SX201.WAV.pt'},
#  'MBEF0_SX381.WAV': {'spk_id': 'MBEF0',
#   'duration': 1.913625,
#   'phn': 'sil w uw w ah l sil k m eh n iy n uw s sil t uw sil n t s iy sil ch y ih er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MBEF0/SX381.WAV.wav.pt'},
#  'MBEF0_SX291.WAV': {'spk_id': 'MBEF0',
#   'duration': 2.144,
#   'phn': 'sil dh iy ae v ah l ae n ch sil t r ih sil er dx ah m ay n er er th sil k w ey sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MBEF0/SX291.WAV.wav.pt'},
#  'MBEF0_SI651.WAV': {'spk_id': 'MBEF0',
#   'duration': 3.872,
#   'phn': 'sil f aa r m aa r f r iy sil k w ah n l iy ow v er iy dx iy ng ih z er iy z ah l ah v ah s ay sil k ah l aa sh ih sil k l sil k m sil p l sh n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MBEF0/SI651.WAV.wav.pt'},
#  'MBEF0_SI1911.WAV': {'spk_id': 'MBEF0',
#   'duration': 2.3488125,
#   'phn': 'sil t eh n y ih r z ih sil g ow dh ey sil b l uw ah sil p s ah m ah v aa r sil d ih sil ch ih s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MBEF0/SI1911.WAV.wav.pt'},
#  'MBEF0_SI1281.WAV': {'spk_id': 'MBEF0',
#   'duration': 3.2704375,
#   'phn': 'sil dh ah s ey m sh eh l dx er sil k uh sil b iy sil b ih l ih n sil t uw ih n ih m sil b ey ng sil m ah n aa sil b ah l ow sil g r aw n sil l eh v l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MBEF0/SI1281.WAV.wav.pt'},
#  'MBEF0_SX21.WAV': {'spk_id': 'MBEF0',
#   'duration': 1.6384375,
#   'phn': 'sil aa l f ae l f ah ih z hh eh l th iy f aa y ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MBEF0/SX21.WAV.wav.pt'},
#  'MBEF0_SX111.WAV': {'spk_id': 'MBEF0',
#   'duration': 2.112,
#   'phn': 'sil hh ih s ah sil n sil d iy sil p aa r ch er sh aa sil dh ih sil k ae s sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MBEF0/SX111.WAV.pt'},
#  'MDWM0_SI2176.WAV': {'spk_id': 'MDWM0',
#   'duration': 2.656,
#   'phn': 'sil w aa sil ch ih sil b ih sil g sh aa sil ey hh aa r s sil v oy s y eh l sil b ae sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MDWM0/SI2176.WAV.wav.pt'},
#  'MDWM0_SI1546.WAV': {'spk_id': 'MDWM0',
#   'duration': 2.7008125,
#   'phn': 'sil ih n dh ih sil p ih dx iy f er dh eh m hh ih z l ow n l ih n eh s w ih z sil g aa n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MDWM0/SI1546.WAV.pt'},
#  'MDWM0_SX433.WAV': {'spk_id': 'MDWM0',
#   'duration': 3.02725,
#   'phn': 'sil dh iy ow v er w ey sil ch aa r m er sil k ih sil s l ih sil p oy z n ih n sil t uw eh n iy w ah n z sil t iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MDWM0/SX433.WAV.wav.pt'},
#  'MDWM0_SX106.WAV': {'spk_id': 'MDWM0',
#   'duration': 2.51525,
#   'phn': 'sil ey hh y uw sil jh sil t ae sil p ih s sil t r iy hh ah ng ih n er hh aa l w ey sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MDWM0/SX106.WAV.pt'},
#  'MDWM0_SI916.WAV': {'spk_id': 'MDWM0',
#   'duration': 4.377625,
#   'phn': 'sil s ah m ey sil b y uw dx ah f l sil ch eh er z sil k ae sil n ih sil t s sil ch eh s sil d aa l hh aw z ih z ih sil t s eh sil t r ah sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MDWM0/SI916.WAV.wav.pt'},
#  'MDWM0_SX376.WAV': {'spk_id': 'MDWM0',
#   'duration': 2.745625,
#   'phn': 'sil w ih m ih n m ey n eh v er sil iy sil k ah m sil k ah m sil p l iy sil l iy iy sil k w l sil t ih m eh n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MDWM0/SX376.WAV.wav.pt'},
#  'MDWM0_SX286.WAV': {'spk_id': 'MDWM0',
#   'duration': 3.6544375,
#   'phn': 'sil ih n eh v r ih m ey sil jh er sil k l ow v er l iy f sil t r ae f ih sil k s ah m sil t ay m z sil g ih sil t s sil b ae sil t ah sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MDWM0/SX286.WAV.pt'},
#  'MDWM0_SX16.WAV': {'spk_id': 'MDWM0',
#   'duration': 2.1888125,
#   'phn': 'sil ah r ow l ah v w ay er l ey n iy er dh ah w aa l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MDWM0/SX16.WAV.wav.pt'},
#  'MRJB1_SX120.WAV': {'spk_id': 'MRJB1',
#   'duration': 4.0768125,
#   'phn': 'sil dh ih sil k ay ow sil b aa sil k ae sil ih n ah hh ay iy n ah sil aa r w ay l sil d ae n ah m l sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MRJB1/SX120.WAV.pt'},
#  'MRJB1_SX30.WAV': {'spk_id': 'MRJB1',
#   'duration': 2.0928125,
#   'phn': 'sil g eh sil t ah sil k ae l ih sil k ow sil k ae sil t ih sil k iy sil p sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MRJB1/SX30.WAV.wav.pt'},
#  'MRJB1_SX210.WAV': {'spk_id': 'MRJB1',
#   'duration': 2.624,
#   'phn': 'sil jh eh f s sil t oy sil g ow sil k aa r sil n eh v er w er sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MRJB1/SX210.WAV.pt'},
#  'MRJB1_SX390.WAV': {'spk_id': 'MRJB1',
#   'duration': 3.6288125,
#   'phn': 'sil hh ih sil p ih sil t ah sil n ay n sil p eh r z ah v s aa sil k s f er iy sil ch sil b r ah dh er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MRJB1/SX390.WAV.pt'},
#  'MRJB1_SI1413.WAV': {'spk_id': 'MRJB1',
#   'duration': 5.1648125,
#   'phn': 'sil ih n m ow s sil d ih s sil k ah sh ih n z ah v dh ih s f ah n aa m ah n aa n sil dh ah f ih sil g y er z er s ah sil s sil t ae n sil sh l iy ih n f l ey sil d ih sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MRJB1/SI1413.WAV.pt'},
#  'MRJB1_SI2021.WAV': {'spk_id': 'MRJB1',
#   'duration': 4.7424375,
#   'phn': 'sil dh eh n hh iy w uh sil d r ih l ay z dh ey w er r ih l iy sil th ih ng z dh eh sil ow n l iy hh iy hh ih m s eh l f sil k uh sil th ih ng sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MRJB1/SI2021.WAV.wav.pt'},
#  'MRJB1_SX300.WAV': {'spk_id': 'MRJB1',
#   'duration': 2.56,
#   'phn': 'sil ah m iy sil b uh z sil ch ey n sil sh ey sil k aa n sil s sil t n sil t l iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MRJB1/SX300.WAV.wav.pt'},
#  'MRJB1_SI1020.WAV': {'spk_id': 'MRJB1',
#   'duration': 3.609625,
#   'phn': 'sil dh ah sil k aw sil b oy sil k aa l sil dh ih s sil b r iy dx ih v sil k ae dx l m ae sil p ay sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MRJB1/SI1020.WAV.pt'},
#  'MPRD0_SX441.WAV': {'spk_id': 'MPRD0',
#   'duration': 2.8608125,
#   'phn': 'sil d ow l uh sil k f er sil g r uw sil v ae l y ih sil b l z ah n ah sil b ae ng sil k v aa l sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MPRD0/SX441.WAV.pt'},
#  'MPRD0_SI2061.WAV': {'spk_id': 'MPRD0',
#   'duration': 1.8048125,
#   'phn': 'sil m ey sil b iy s ah m ah dh uh sil d ey sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MPRD0/SI2061.WAV.pt'},
#  'MPRD0_SX351.WAV': {'spk_id': 'MPRD0',
#   'duration': 3.6928125,
#   'phn': 'sil dh ih n uw s ah sil b er v ah n ay sil s sil w er sil t hh aa r dx aa n r ih f er v r ih sh ih ng dh eh r ow l sil d er hh ow m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MPRD0/SX351.WAV.pt'},
#  'MPRD0_SI801.WAV': {'spk_id': 'MPRD0',
#   'duration': 5.5168125,
#   'phn': 'sil ih n ih n uw hh aw s sil jh eh n er ih s r uw f ow v er hh ae ng z er ah l aa sil jh ih sil k l ah n ah f eh sil t ih v s ah l uw sh ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MPRD0/SI801.WAV.pt'},
#  'MPRD0_SX261.WAV': {'spk_id': 'MPRD0',
#   'duration': 2.5024375,
#   'phn': 'sil d uw y uw hh ae v dh iy y eh l ow oy n m ih n r eh dx iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MPRD0/SX261.WAV.wav.pt'},
#  'MPRD0_SX171.WAV': {'spk_id': 'MPRD0',
#   'duration': 4.505625,
#   'phn': 'sil dh ih sil d ay sil n ow s ih s sil w ah z sil d ih s sil k er ih sil jh ih ng sil hh aw eh v er sil hh iy w uh z n aa dx ow v er l iy w er ih sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MPRD0/SX171.WAV.pt'},
#  'MPRD0_SI1431.WAV': {'spk_id': 'MPRD0',
#   'duration': 3.8848125,
#   'phn': 'sil dh ah sil b ae sil t ih r iy ih f aa r m d ih sil t ih sil p ah sil k l ae sil t ih v ey dx ih sil d s l ah sil jh f l aa sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MPRD0/SI1431.WAV.wav.pt'},
#  'MPRD0_SX81.WAV': {'spk_id': 'MPRD0',
#   'duration': 2.5664375,
#   'phn': 'sil ih sil t s ih m sil p aa s sil b l sil t ih sil d iy l w ah th sil b y er aa sil k er s ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MPRD0/SX81.WAV.pt'},
#  'MAKR0_SX362.WAV': {'spk_id': 'MAKR0',
#   'duration': 2.73925,
#   'phn': 'sil dh iy ih n oy ih n r ae sil k uw n s sil l ih sil t ih n sil t uw f ih l z sil g aa r dx n eh v r ih n ay sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MAKR0/SX362.WAV.pt'},
#  'MAKR0_SX92.WAV': {'spk_id': 'MAKR0',
#   'duration': 2.13125,
#   'phn': 'sil ah l aa r sh hh aw s hh ow l n iy sil z l aa sil s ah v ah sil p l ay ih n s ah s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MAKR0/SX92.WAV.pt'},
#  'MAKR0_SI722.WAV': {'spk_id': 'MAKR0',
#   'duration': 2.0544375,
#   'phn': 'sil dh ih s sil ch ey n jh ih z dh ih f aa r m y ih l ih sil t ih n ah sil k w ey sh ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MAKR0/SI722.WAV.pt'},
#  'MAKR0_SI1982.WAV': {'spk_id': 'MAKR0',
#   'duration': 2.9824375,
#   'phn': 'sil t uw sil k aa r z sil k eh m ow v er sil k r eh s sil dh ih er sil k r ow m ah n sil g l ae s f l ae sh ih ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MAKR0/SI1982.WAV.pt'},
#  'MAKR0_SX182.WAV': {'spk_id': 'MAKR0',
#   'duration': 1.76,
#   'phn': 'sil th ih sil g l uw z sil aw dx ah v dh ah sil t uw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MAKR0/SX182.WAV.wav.pt'},
#  'MAKR0_SI1352.WAV': {'spk_id': 'MAKR0',
#   'duration': 2.1568125,
#   'phn': 'sil ae s ah sil ch ih ae sil k s eh z ih n ey n sil k er f er dh ih sil p iy sil p l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MAKR0/SI1352.WAV.pt'},
#  'MAKR0_SX452.WAV': {'spk_id': 'MAKR0',
#   'duration': 2.64325,
#   'phn': 'sil ih n d ih v eh l sil p ih ng f ih l m eh n iy sil t aa sil k s ih sil k eh m ah sil k l z er y uw z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MAKR0/SX452.WAV.wav.pt'},
#  'MAKR0_SX272.WAV': {'spk_id': 'MAKR0',
#   'duration': 1.6384375,
#   'phn': 'sil ah l aw iy sh sil ch ay l sil d ih hh ae v ih n ay s sil p aa sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/MAKR0/SX272.WAV.pt'},
#  'FGRW0_SI1152.WAV': {'spk_id': 'FGRW0',
#   'duration': 5.23525,
#   'phn': 'sil y uw sil k uh sil d aa s ow s ey dh ae ih n dh iy z sil p ae m f l eh sil s ih z ah r ih l iy v ih ng sil k w aa l ah sil t iy ah v m ih sil ch er ih sil t iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/FGRW0/SI1152.WAV.wav.pt'},
#  'FGRW0_SX252.WAV': {'spk_id': 'FGRW0',
#   'duration': 2.681625,
#   'phn': 'sil dh ih sil g aa r sil jh ih s sil b ah dx er f l ay ey dx ah l aa dx ah v n eh sil t er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/FGRW0/SX252.WAV.pt'},
#  'FGRW0_SI1782.WAV': {'spk_id': 'FGRW0',
#   'duration': 3.6608125,
#   'phn': 'sil dh eh r er z ih th ih sil k sil s sil k w aa sh iy sil k r ae sil k ih v f ih s sil t aa n f l eh sh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/FGRW0/SI1782.WAV.wav.pt'},
#  'FGRW0_SX72.WAV': {'spk_id': 'FGRW0',
#   'duration': 2.41925,
#   'phn': 'sil s sil p r ih ng s sil t r iy ih s sil t r ey sil t ih hh eh sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/FGRW0/SX72.WAV.pt'},
#  'FGRW0_SI1990.WAV': {'spk_id': 'FGRW0',
#   'duration': 2.297625,
#   'phn': 'sil hh aw w l w iy w er sil k ih sil t aw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/FGRW0/SI1990.WAV.wav.pt'},
#  'FGRW0_SX162.WAV': {'spk_id': 'FGRW0',
#   'duration': 4.4224375,
#   'phn': 'sil hh er aa r sil b er n hh eh r iy m ay n d ih sil d hh ih m ah v aa dx ah m l iy v z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/FGRW0/SX162.WAV.wav.pt'},
#  'FGRW0_SX432.WAV': {'spk_id': 'FGRW0',
#   'duration': 4.448,
#   'phn': 'sil k aa f iy ih z sil g r ow n aa n s sil t iy sil jh ah ng sil g l l ay sil s l ow sil p s ih n sil t eh m sil p er ih z ow n z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/FGRW0/SX432.WAV.wav.pt'},
#  'FGRW0_SX342.WAV': {'spk_id': 'FGRW0',
#   'duration': 3.21925,
#   'phn': 'sil t ey sil ch aa r sil jh ah v sil ch uw z iy ng hh er sil b r ay sil s m ey sil z sil g aw n z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/train/DR3/FGRW0/SX342.WAV.wav.pt'},
#  ...}

# %%
with open('test_fbank.json') as file:
    t_json = json.load(file)
    
t_json
# Out:
# {'MDAB0_SI1039.WAV': {'spk_id': 'MDAB0',
#   'duration': 3.9424375,
#   'phn': 'sil hh iy hh eh z n eh v er hh ih m s eh l f sil d ah n ey hh ih ng f ow w ih sil ch sil t ah sil b iy hh ey dx ih sil w ih sil ch ih v ah s hh ae z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/MDAB0/SI1039.WAV.pt'},
#  'MDAB0_SI1669.WAV': {'spk_id': 'MDAB0',
#   'duration': 2.0608125,
#   'phn': 'sil b iy ih sil k s ay dx ih sil d ih n sil d ow n ah sil d eh n ah f ay er s eh l f sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/MDAB0/SI1669.WAV.pt'},
#  'MDAB0_SX49.WAV': {'spk_id': 'MDAB0',
#   'duration': 2.201625,
#   'phn': 'sil ae sil t sil w aa l ay sil t ah m ah sil t sil w eh l th sil d ey w l hh ae v sh ah sil b l iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/MDAB0/SX49.WAV.wav.pt'},
#  'MDAB0_SI2299.WAV': {'spk_id': 'MDAB0',
#   'duration': 2.5984375,
#   'phn': 'sil s ah m sil t ay m s iy sil k ow ah n s ay dx ah w ah th m ay f aa dh ih z sil b iy ng eh sil t hh ow m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/MDAB0/SI2299.WAV.pt'},
#  'MDAB0_SX409.WAV': {'spk_id': 'MDAB0',
#   'duration': 2.88,
#   'phn': 'sil iy dx iy ng s sil p ih n eh sil ch sil n ay sil l iy ih ng sil k r iy s ih s sil t r eh n sil th sil m er ae sil k y ah l ih s l iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/MDAB0/SX409.WAV.wav.pt'},
#  'MDAB0_SX319.WAV': {'spk_id': 'MDAB0',
#   'duration': 2.4384375,
#   'phn': 'sil ey sil b iy sil g ow sil ay dx ah l iy ae m sil b l sil th uw dh ih f aa r m y aa r sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/MDAB0/SX319.WAV.wav.pt'},
#  'MDAB0_SX139.WAV': {'spk_id': 'MDAB0',
#   'duration': 2.361625,
#   'phn': 'sil dh ah sil b ah ng sil g l ow w ah z sil p l ah z n l ih s ih sil ch ah w ih dx ih sil n ih dh ih sh aa r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/MDAB0/SX139.WAV.wav.pt'},
#  'MDAB0_SX229.WAV': {'spk_id': 'MDAB0',
#   'duration': 1.305625,
#   'phn': 'sil aa r y ih l uh sil k iy n f r ow m sil p l oy m ih sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/MDAB0/SX229.WAV.pt'},
#  'MWBT0_SX383.WAV': {'spk_id': 'MWBT0',
#   'duration': 3.904,
#   'phn': 'sil dh ih sil k aa sil p ih sil k l iy n er z sil sh ae m sil p uw sil d aa r aa r iy eh n sil t l r ah sil g sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/MWBT0/SX383.WAV.wav.pt'},
#  'MWBT0_SI1553.WAV': {'spk_id': 'MWBT0',
#   'duration': 4.75525,
#   'phn': 'sil hh aw eh v ah dh ah l ih dx er r iy m ey n sil d aa sil m eh n sil t ih sil b ay s eh v r l sil d ah z ih n l ah n sil ch r uw m sil s ah sil p er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/MWBT0/SI1553.WAV.pt'},
#  'MWBT0_SI2183.WAV': {'spk_id': 'MWBT0',
#   'duration': 1.8944375,
#   'phn': 'sil b uh sil k s ah f ah sh sil n uh sil k s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/MWBT0/SI2183.WAV.pt'},
#  'MWBT0_SX203.WAV': {'spk_id': 'MWBT0',
#   'duration': 3.129625,
#   'phn': 'sil dh ih sil k aa z sil w ey ih n sil d ih sil d ah sil b r ah sil p l iy sil eh sil dh ah sh aa r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/MWBT0/SX203.WAV.pt'},
#  'MWBT0_SX113.WAV': {'spk_id': 'MWBT0',
#   'duration': 3.328,
#   'phn': 'sil ey m ah s sil k ih l ah ae sil d ah m eh n sil ih z sil g uh sil f aa y ih sil b ae sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/MWBT0/SX113.WAV.wav.pt'},
#  'MWBT0_SI923.WAV': {'spk_id': 'MWBT0',
#   'duration': 2.96325,
#   'phn': 'sil t uh m eh n iy eh sil k s sil p er sil t s dh ih s sil t r eh n sil w ah z ih n eh v ah dx ah sil b l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/MWBT0/SI923.WAV.wav.pt'},
#  'MWBT0_SX23.WAV': {'spk_id': 'MWBT0',
#   'duration': 3.168,
#   'phn': 'sil dh ow z sil m y uw z ih sh ih n z hh aa m ah n ay z sil m aa v l l ah s l ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/MWBT0/SX23.WAV.wav.pt'},
#  'MWBT0_SX293.WAV': {'spk_id': 'MWBT0',
#   'duration': 3.6224375,
#   'phn': 'sil p l iy z sil t ey sil dh ih s sil d er dx iy sil t ey sil b uh sil k l aa th sil t ih dh ih sil k l iy n ih z f ah m ey sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/MWBT0/SX293.WAV.wav.pt'},
#  'FELC0_SX126.WAV': {'spk_id': 'FELC0',
#   'duration': 2.912,
#   'phn': 'sil aa r dx ih f ih sh l ih n sil t eh l ih sil jh ih n s ih z f er r iy l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/FELC0/SX126.WAV.wav.pt'},
#  'FELC0_SI1386.WAV': {'spk_id': 'FELC0',
#   'duration': 5.52325,
#   'phn': 'sil ih n w ey sil jh n ih sil g ow sh iy ey sh ih n s sil dh iy ih n sil d ih s sil t r iy sil b aa r sil g ih n z eh z ey y uw n ih w ih dh ih s ih ng sil g l y uw n y ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/FELC0/SI1386.WAV.wav.pt'},
#  'FELC0_SX216.WAV': {'spk_id': 'FELC0',
#   'duration': 2.19525,
#   'phn': 'sil dh ah s sil m aa l sil b oy sil p uh sil dh ah w er m ah n dh ah hh uh sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/FELC0/SX216.WAV.wav.pt'},
#  'FELC0_SX396.WAV': {'spk_id': 'FELC0',
#   'duration': 3.8208125,
#   'phn': 'sil dh ih f ih sh sil b ih sil g ae n sil t ih l iy sil f r ae n sil t ih sil k l iy ah n dh ah s er f ah s ah v dh ih s m aa l ey sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/FELC0/SX396.WAV.pt'},
#  'FELC0_SX306.WAV': {'spk_id': 'FELC0',
#   'duration': 2.496,
#   'phn': 'sil ah sil ch ow z ih n f y uw w l sil b iy sil k ah m sil jh eh n er l s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/FELC0/SX306.WAV.pt'},
#  'FELC0_SI2016.WAV': {'spk_id': 'FELC0',
#   'duration': 3.4048125,
#   'phn': 'sil hh iy v aa n ow z r ow sil p s sil dh ih sil b ow sil s sil k ah m ah n s sil t ah sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/FELC0/SI2016.WAV.pt'},
#  'FELC0_SI756.WAV': {'spk_id': 'FELC0',
#   'duration': 4.192,
#   'phn': 'sil m ih sil t ih r iy ih l s sil s er r ae m ih sil m aa dx l ih ng sil k l ey sil r eh sil d w ay sil aa r sil b aa f sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/FELC0/SI756.WAV.pt'},
#  'FELC0_SX36.WAV': {'spk_id': 'FELC0',
#   'duration': 3.52,
#   'phn': 'sil ow n l ih dh ih m ow s sil t ih sil k aa m sil p l ih sh sil aa r dx ih s ah sil t ey n sil p aa sil p ih l eh er dx iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR1/FELC0/SX36.WAV.wav.pt'},
#  'MBPM0_SI1577.WAV': {'spk_id': 'MBPM0',
#   'duration': 1.97125,
#   'phn': 'sil b r aw n ay z ay sil b r aw m ah s sil t ae sh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/MBPM0/SI1577.WAV.wav.pt'},
#  'MBPM0_SX47.WAV': {'spk_id': 'MBPM0',
#   'duration': 2.1568125,
#   'phn': 'sil m aa m s sil t r ah ng l iy sil d ih s l ay sil k s ae sil p ah sil t ay z er s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/MBPM0/SX47.WAV.wav.pt'},
#  'MBPM0_SI947.WAV': {'spk_id': 'MBPM0',
#   'duration': 3.09125,
#   'phn': 'sil f y uw r er ah l eh r iy ih z er sil p er sil t eh sil t ih sil b ay z ow n ih ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/MBPM0/SI947.WAV.wav.pt'},
#  'MBPM0_SX227.WAV': {'spk_id': 'MBPM0',
#   'duration': 1.7728125,
#   'phn': 'sil ih sil t s hh eh l th y er sil d ih sil k uh sil k w ih th aw sil sh uh sil er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/MBPM0/SX227.WAV.wav.pt'},
#  'MBPM0_SX407.WAV': {'spk_id': 'MBPM0',
#   'duration': 2.54725,
#   'phn': 'sil l ae f sil d ae n sil t s n s ih ng ih f aa r sil ch ih n s sil m ay l z ah sil p aa n y uw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/MBPM0/SX407.WAV.pt'},
#  'MBPM0_SX317.WAV': {'spk_id': 'MBPM0',
#   'duration': 2.329625,
#   'phn': 'sil dh ih sil k r eh n sil b er iy sil b aa sil g ih sil t s sil v er r iy sil p r ih dx iy eh n aa dx ah m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/MBPM0/SX317.WAV.pt'},
#  'MBPM0_SI1584.WAV': {'spk_id': 'MBPM0',
#   'duration': 3.79525,
#   'phn': 'sil r eh sil k sil t er w ih z aa f ih n sil k y er iy ih s sil aa f ih n sil t eh m sil t ih sil t ae s sil k w eh s sil ch ih n z sil b ih dx iy n eh v er sil d ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/MBPM0/SI1584.WAV.pt'},
#  'MBPM0_SX137.WAV': {'spk_id': 'MBPM0',
#   'duration': 3.7248125,
#   'phn': 'sil t r ih sil d ih sh ih n r er sil k w aa er z sil f er eh n l ah sil p r uw v l f r ah ah n sil d er ey sil jh sil m ae r ih sil jh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/MBPM0/SX137.WAV.wav.pt'},
#  'MKLT0_SX133.WAV': {'spk_id': 'MKLT0',
#   'duration': 2.64325,
#   'phn': 'sil p iy sil s er iy er z er sil k n v iy n y ih sil f aa r sil k w ih sil k l ah n sil ch sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/MKLT0/SX133.WAV.wav.pt'},
#  'MKLT0_SX403.WAV': {'spk_id': 'MKLT0',
#   'duration': 2.752,
#   'phn': 'sil hh ah w aa r sil d r ow sil k n s ih s sil s ah v ow n l iy s sil k er sil s ah n sil b l aw z ih z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/MKLT0/SX403.WAV.wav.pt'},
#  'MKLT0_SI1213.WAV': {'spk_id': 'MKLT0',
#   'duration': 2.4768125,
#   'phn': 'sil m aa ow n ih sil k s sil p ih er n s ih z f aa l ow sil s ih m sil p l er l aa n z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/MKLT0/SI1213.WAV.wav.pt'},
#  'MKLT0_SX43.WAV': {'spk_id': 'MKLT0',
#   'duration': 2.016,
#   'phn': 'sil eh l sil er l iy sil p iy sil p l er aa f ih n ih sil k s sil k l uw dx ih sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/MKLT0/SX43.WAV.pt'},
#  'MKLT0_SI1843.WAV': {'spk_id': 'MKLT0',
#   'duration': 3.2448125,
#   'phn': 'sil sh iy w ah z r eh dx iy f aa r hh er sil g r ey dx ih sil v eh n sil ch er z ah n dh iy er r aa v l ah v er m ow sil l sil p aa r sil n er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/MKLT0/SI1843.WAV.pt'},
#  'MKLT0_SX313.WAV': {'spk_id': 'MKLT0',
#   'duration': 3.21925,
#   'phn': 'sil d r aa sil f ay f aa m z n dh ah sil b aa sil k s sil b ah f aa y uw sil g ow aw sil hh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/MKLT0/SX313.WAV.pt'},
#  'MKLT0_SI583.WAV': {'spk_id': 'MKLT0',
#   'duration': 2.2848125,
#   'phn': 'sil dh ih s w iy sil k ih n s ih m sil p ih th eh dx ih sil k l iy ah n d ah s sil t ae n sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/MKLT0/SI583.WAV.pt'},
#  'MKLT0_SX223.WAV': {'spk_id': 'MKLT0',
#   'duration': 2.19525,
#   'phn': 'sil p uh sil dh ah sil b uh sil ch er sil b l aa sil t ey sil b l ih n dh ih sil g er r aa sil jh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/MKLT0/SX223.WAV.pt'},
#  'FNLP0_SX48.WAV': {'spk_id': 'FNLP0',
#   'duration': 3.5008125,
#   'phn': 'sil g r ae m ah dh er aw g r uw hh er ah sil b r ih ng ih n ih m sil p eh dx iy sil k ow sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/FNLP0/SX48.WAV.pt'},
#  'FNLP0_SI1938.WAV': {'spk_id': 'FNLP0',
#   'duration': 3.2384375,
#   'phn': 'sil l ay dx ih sil w ih n sil d ow z sil g l ow sil jh uw l sil b r ay sil th r uw dh ih sil d aw n sil p aa r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/FNLP0/SI1938.WAV.pt'},
#  'FNLP0_SI1308.WAV': {'spk_id': 'FNLP0',
#   'duration': 5.77925,
#   'phn': 'sil ih n sil d iy sil ih dx ih z sil p aa s ah sil b l sil t ih s eh sil p er ey iy l eh sil t r aa n sil p eh er m ae ng n eh dx ih sil f r ah m n uw sil k l iy er ih f eh sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/FNLP0/SI1308.WAV.pt'},
#  'FNLP0_SX228.WAV': {'spk_id': 'FNLP0',
#   'duration': 2.29125,
#   'phn': 'sil dh ah v y uw sil p oy n sil ow v er l uh sil dh iy ow sh ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/FNLP0/SX228.WAV.pt'},
#  'FNLP0_SX408.WAV': {'spk_id': 'FNLP0',
#   'duration': 3.104,
#   'phn': 'sil ay sil d r ay sil dh ih s ah sil b w ey sil b ih dx ay hh ae v ih n iy n ah f sil ch ey n sil jh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/FNLP0/SX408.WAV.wav.pt'},
#  'FNLP0_SX138.WAV': {'spk_id': 'FNLP0',
#   'duration': 3.616,
#   'phn': 'sil dh ih sil k l ah m z iy sil k ah s sil t ih m er s sil p ih l sil s ah m ih sil s sil p ih n s ih v sil p er f y uw m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/FNLP0/SX138.WAV.pt'},
#  'FNLP0_SI678.WAV': {'spk_id': 'FNLP0',
#   'duration': 2.048,
#   'phn': 'sil s ae l v ey sh ih n r iy sil k ih n s ih dx er sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/FNLP0/SI678.WAV.wav.pt'},
#  'FNLP0_SX318.WAV': {'spk_id': 'FNLP0',
#   'duration': 3.73125,
#   'phn': 'sil p l iy z sil d ih sil m aa m sil p ih sil t ey dx ah z ah sil b ah f aa r f r aa s sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR5/FNLP0/SX318.WAV.pt'},
#  'MLNT0_SX102.WAV': {'spk_id': 'MLNT0',
#   'duration': 3.673625,
#   'phn': 'sil s sil p eh sh l sil t ae s sil f aa r s ih z r eh s sil k y uw hh aa s sil t ih sil jh ih z f r ah m sil k ih sil n ae sil p er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/MLNT0/SX102.WAV.wav.pt'},
#  'MLNT0_SX282.WAV': {'spk_id': 'MLNT0',
#   'duration': 3.193625,
#   'phn': 'sil dh ih sil t uw th f er iy f ah sil g aa sil t ah sil k ah m w ih n r aa sil jh er z sil t uw th f eh l aw sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/MLNT0/SX282.WAV.pt'},
#  'MLNT0_SI642.WAV': {'spk_id': 'MLNT0',
#   'duration': 4.089625,
#   'phn': 'sil dh eh r sil p r aa sil p s sil w er sil t uw s sil t eh sil p l ae dx er z sil ah sil ch eh er ae n ah sil p aa m f ae n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/MLNT0/SI642.WAV.pt'},
#  'MLNT0_SI1902.WAV': {'spk_id': 'MLNT0',
#   'duration': 1.8688125,
#   'phn': 'sil dh ah sil p ah l s ih ng sil g l ow ah v ah s ih sil er r eh sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/MLNT0/SI1902.WAV.wav.pt'},
#  'MLNT0_SX372.WAV': {'spk_id': 'MLNT0',
#   'duration': 3.1104375,
#   'phn': 'sil dh eh sil d ay ih sil g r ae m ey sil k s eh n s sil ow n l iy sil ae f sil t er m ah sil sh sil t ah dx iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/MLNT0/SX372.WAV.wav.pt'},
#  'MLNT0_SX192.WAV': {'spk_id': 'MLNT0',
#   'duration': 2.329625,
#   'phn': 'sil s sil t r aa hh ae sil s er aw dx ah f ae sh ih n dh ih s y ih er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/MLNT0/SX192.WAV.pt'},
#  'MLNT0_SI1574.WAV': {'spk_id': 'MLNT0',
#   'duration': 4.7808125,
#   'phn': 'sil f l ay s sil w aa r m sil ih r aw n dh ih sil b ow l ah v l eh n sil t l z ih n w ih sil ch hh iy m aa sil th ih sil b l ae sil b r eh sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/MLNT0/SI1574.WAV.wav.pt'},
#  'MLNT0_SX12.WAV': {'spk_id': 'MLNT0',
#   'duration': 2.3168125,
#   'phn': 'sil w uh l r aa sil b ih n w eh er ey y eh l ow l ih l iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/MLNT0/SX12.WAV.pt'},
#  'MJMP0_SX185.WAV': {'spk_id': 'MJMP0',
#   'duration': 2.1248125,
#   'phn': 'sil d ih sil jh uw sil b ay ih n iy sil k aa r dx er oy ow v er aa l s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/MJMP0/SX185.WAV.wav.pt'},
#  'MJMP0_SX275.WAV': {'spk_id': 'MJMP0',
#   'duration': 2.77125,
#   'phn': 'sil s sil t iy v w aa r ah sil b r ay sil r eh sil k ae sh m er s sil w eh dx er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/MJMP0/SX275.WAV.pt'},
#  'MJMP0_SI1791.WAV': {'spk_id': 'MJMP0',
#   'duration': 4.6784375,
#   'phn': 'sil n ow dh ah m ae n w ah z sil n aa sil d r ah ng sil k sil hh iy w ah n sil d er sil d hh aw iy sil g aa sil t ay dx ah sil w ih th ih s sil t r ey n jh er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/MJMP0/SI1791.WAV.wav.pt'},
#  'MJMP0_SX95.WAV': {'spk_id': 'MJMP0',
#   'duration': 3.09125,
#   'phn': 'sil ih sil g w aa n eh z eh n ae l ih sil g ey dx er z er sil t r aa sil p ah sil k l r eh sil t ay l z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/MJMP0/SX95.WAV.wav.pt'},
#  'MJMP0_SI1535.WAV': {'spk_id': 'MJMP0',
#   'duration': 2.3488125,
#   'phn': 'sil hh iy sil t r eh m sil b l sil l eh s sil t hh ih z sil p iy sh ih sil f ey l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/MJMP0/SI1535.WAV.wav.pt'},
#  'MJMP0_SX5.WAV': {'spk_id': 'MJMP0',
#   'duration': 1.6,
#   'phn': 'sil sh iy ih z th ih n er dh ih n ay ae m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/MJMP0/SX5.WAV.wav.pt'},
#  'MJMP0_SI905.WAV': {'spk_id': 'MJMP0',
#   'duration': 2.688,
#   'phn': 'sil hh ih z w er sil b iy sil g ae n jh ih s ih sil k s sil d ey z ae f sil t ah dh ah f l ah sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/MJMP0/SI905.WAV.pt'},
#  'MJMP0_SX365.WAV': {'spk_id': 'MJMP0',
#   'duration': 3.89125,
#   'phn': 'sil dh ih sil g ah n m ih n sil k eh sil t ih z v ih sil t ih m sil k aa n er sil eh sil g ah n sil p oy n sil f er th r iy aw er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/MJMP0/SX365.WAV.pt'},
#  'FPKT0_SI1538.WAV': {'spk_id': 'FPKT0',
#   'duration': 3.129625,
#   'phn': 'sil ah sil k eh r ih sil jh sil k r ah n ch sil b ay ih sil s sil d ih m l ay sil t s f ih l sil t r ih ng th uw dh ih sil g l uw m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/FPKT0/SI1538.WAV.wav.pt'},
#  'FPKT0_SI908.WAV': {'spk_id': 'FPKT0',
#   'duration': 2.272,
#   'phn': 'sil w iy ow w ih z th aa w ih w uh sil d ay w ih th aa r sil b uw sil t s aa n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/FPKT0/SI908.WAV.pt'},
#  'FPKT0_SX8.WAV': {'spk_id': 'FPKT0',
#   'duration': 2.816,
#   'phn': 'sil w ay y eh l er w er iy ow v er s ih l iy ay dx ih m z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/FPKT0/SX8.WAV.wav.pt'},
#  'FPKT0_SI2168.WAV': {'spk_id': 'FPKT0',
#   'duration': 1.977625,
#   'phn': 'sil dh ey m ey sil k ah s sil k n f aa r m ih s l uh sil g uh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/FPKT0/SI2168.WAV.pt'},
#  'FPKT0_SX188.WAV': {'spk_id': 'FPKT0',
#   'duration': 2.2208125,
#   'phn': 'sil hh uw aa th er ay z dh iy ih n l ih m ih dx ih dx ih sil k s sil p eh n s ih sil k aw n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/FPKT0/SX188.WAV.pt'},
#  'FPKT0_SX368.WAV': {'spk_id': 'FPKT0',
#   'duration': 3.09125,
#   'phn': 'sil l aa r iy z sil k aa s sil t uw m n iy dx ih sil b l ae sil g l ah z ih sil b iy sil k ah m sil p l iy sil l iy eh l ih sil g eh n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/FPKT0/SX368.WAV.pt'},
#  'FPKT0_SX278.WAV': {'spk_id': 'FPKT0',
#   'duration': 3.2128125,
#   'phn': 'sil t uw f er dh er hh ih z sil p r ih s sil t iy sil jh hh iy sil k ey sh n l ih r iy sil z dh ah w aa l s sil t r iy sil jh er n ah l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/FPKT0/SX278.WAV.wav.pt'},
#  'FPKT0_SX98.WAV': {'spk_id': 'FPKT0',
#   'duration': 1.849625,
#   'phn': 'sil g eh s dh ih sil k w eh sh ah n f r ah m dh iy ae n s er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR3/FPKT0/SX98.WAV.pt'},
#  'MJLN0_SX9.WAV': {'spk_id': 'MJLN0',
#   'duration': 2.489625,
#   'phn': 'sil w eh ah w er y uw w aa l w iy w er ah w ey sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/MJLN0/SX9.WAV.pt'},
#  'MJLN0_SI2079.WAV': {'spk_id': 'MJLN0',
#   'duration': 2.1184375,
#   'phn': 'sil dh ey hh eh sil s l ae sil dh eh r th ay z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/MJLN0/SI2079.WAV.pt'},
#  'MJLN0_SX369.WAV': {'spk_id': 'MJLN0',
#   'duration': 2.8864375,
#   'phn': 'sil b aa sil p ey sil p er sil ow v ih dh ah l ih v ih ng r uw m ih r l z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/MJLN0/SX369.WAV.pt'},
#  'MJLN0_SX279.WAV': {'spk_id': 'MJLN0',
#   'duration': 3.5904375,
#   'phn': 'sil ae l ah s ih z ih sil b ih l ah dx iy sil t uw w er sil k w ih dh aw sil s uw sil p er v ih sh ih n sil ih z n ow sil w er dh iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/MJLN0/SX279.WAV.wav.pt'},
#  'MJLN0_SI1449.WAV': {'spk_id': 'MJLN0',
#   'duration': 4.3328125,
#   'phn': 'sil ch iy f ih n sil t er s sil t ih n r ey dx iy uh s sil t eh er l ah z ey sh ih n r ih z ay sil z ih n dh ih m ih l ih sil t eh r ih s er v er s ih z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/MJLN0/SI1449.WAV.wav.pt'},
#  'MJLN0_SX99.WAV': {'spk_id': 'MJLN0',
#   'duration': 3.15525,
#   'phn': 'sil m ih sil d iy v l s ih s ay ih dx iy w ih z sil b ey s sil t aa n hh ay er aa r sil k iy s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/MJLN0/SX99.WAV.pt'},
#  'MJLN0_SX189.WAV': {'spk_id': 'MJLN0',
#   'duration': 2.969625,
#   'phn': 'sil d ih s sil t r oy eh v r iy f ay l r ah l ey dx ih sil t ih m ay aa dx ih sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/MJLN0/SX189.WAV.pt'},
#  'MJLN0_SI819.WAV': {'spk_id': 'MJLN0',
#   'duration': 4.537625,
#   'phn': 'sil dh eh er f aa r s ih z ah m aa r l ey sil n sil dh eh n ih n l eh sil t r ih s ih sil d iy sil ae n l eh s dh ih n ih n m ae sil n ih sil t ih z m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/MJLN0/SI819.WAV.pt'},
#  'MPAM0_SI1189.WAV': {'spk_id': 'MPAM0',
#   'duration': 2.553625,
#   'phn': 'sil ey sil f iy l sil g ah n z w er sil k ae sil ch er dx ih n sil p ah z ih sh n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/MPAM0/SI1189.WAV.wav.pt'},
#  'MPAM0_SI1961.WAV': {'spk_id': 'MPAM0',
#   'duration': 4.416,
#   'phn': 'sil ah s eh sil k ih n sil t w ih sil ch sil t hh ih sh er sil s l iy v sil ih n iy f eh l sil t ah sil b r iy f sil b er n ah n ah z ah sil p er aa r m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/MPAM0/SI1961.WAV.wav.pt'},
#  'MPAM0_SX379.WAV': {'spk_id': 'MPAM0',
#   'duration': 2.51525,
#   'phn': 'sil p ae m sil g ih v z sil d r ay v ih ng l eh s n z aa n th er z sil d ey z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/MPAM0/SX379.WAV.pt'},
#  'MPAM0_SX199.WAV': {'spk_id': 'MPAM0',
#   'duration': 3.52,
#   'phn': 'sil y ah ng sil ch ih l sil er n sh uh dx ah v oy sil d ih sil k s sil p ow sh er sil t ah sil k ih n sil t ey sil jh ah s sil d ih z iy z ih z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/MPAM0/SX199.WAV.wav.pt'},
#  'MPAM0_SX109.WAV': {'spk_id': 'MPAM0',
#   'duration': 2.937625,
#   'phn': 'sil sh iy s l ih sil t n s sil p r ey n d er ae ng sil k l aa n ah s sil t iy sil s l ow sil p sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/MPAM0/SX109.WAV.wav.pt'},
#  'MPAM0_SX289.WAV': {'spk_id': 'MPAM0',
#   'duration': 2.70725,
#   'phn': 'sil w eh dh er sil p r uw f sil g l aa sh ih z er v er iy y uw s f l n s iy ae dx l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/MPAM0/SX289.WAV.pt'},
#  'MPAM0_SX19.WAV': {'spk_id': 'MPAM0',
#   'duration': 2.3744375,
#   'phn': 'sil ah l uw m ah n ih m s ih l v ah w er sil k ih n aa f n sil b iy f l ih m z iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/MPAM0/SX19.WAV.wav.pt'},
#  'MPAM0_SI1819.WAV': {'spk_id': 'MPAM0',
#   'duration': 2.8608125,
#   'phn': 'sil hh iy r ah sil d ih z ay s l iy sil p l iy w ih th w ah n hh y uw sil jh sil p aa sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/MPAM0/SI1819.WAV.wav.pt'},
#  'FMLD0_SX25.WAV': {'spk_id': 'FMLD0',
#   'duration': 1.90725,
#   'phn': 'sil ow n l ih l oy er z l ah v m ih y ih n ih r s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/FMLD0/SX25.WAV.pt'},
#  'FMLD0_SX385.WAV': {'spk_id': 'FMLD0',
#   'duration': 1.90725,
#   'phn': 'sil hh ih z sh ow l sil d er f eh l sil t ih z ih f ih sil w er sil b r ow sil k ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/FMLD0/SX385.WAV.pt'},
#  'FMLD0_SX205.WAV': {'spk_id': 'FMLD0',
#   'duration': 3.072,
#   'phn': 'sil b ih l ih sil t eh er sil p er s n eh l aa r er sil k s sil p eh sil t ih sil t uw ow sil b ey sil g ah v er m eh n aa r dx er s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/FMLD0/SX205.WAV.pt'},
#  'FMLD0_SI822.WAV': {'spk_id': 'FMLD0',
#   'duration': 3.6544375,
#   'phn': 'sil m ih l sil p er sil d ah sil k sh ih n m ey sil b iy ih ng sil k r iy s sil b ay dh iy ae n sil t ay ih n t f eh sil t ih v sil p r aa sil p r iy z ah v dh ih s sil d r ah sil g sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/FMLD0/SI822.WAV.wav.pt'},
#  'FMLD0_SI2185.WAV': {'spk_id': 'FMLD0',
#   'duration': 3.584,
#   'phn': 'sil sh iy s eh sil sh aa r sil k s eh v n ow sil b ow n d z ih n sil t sh r ih m sil p s sil w ae m sil b ae sil k w er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/FMLD0/SI2185.WAV.wav.pt'},
#  'FMLD0_SX295.WAV': {'spk_id': 'FMLD0',
#   'duration': 3.097625,
#   'phn': 'sil ih f sil k eh r l sil k ah m z sil t ah m aa r ah hh ae v er r ey n jh f er m iy dx iy ng ih sil t uw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/FMLD0/SX295.WAV.wav.pt'},
#  'FMLD0_SX115.WAV': {'spk_id': 'FMLD0',
#   'duration': 2.38725,
#   'phn': 'sil dh iy eh m l ah m sil d ah sil p ih sil k s sil dh iy ih sil k r aa sil p l ah s aa l ah sil g l ow sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/FMLD0/SX115.WAV.wav.pt'},
#  'FMLD0_SI925.WAV': {'spk_id': 'FMLD0',
#   'duration': 2.1184375,
#   'phn': 'sil w ah hh iy w ih z ih n sil k ah s sil t ih sil d iy ih z sil w ay f sil d ih v aa r s sil t ih m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR8/FMLD0/SI925.WAV.pt'},
#  'FJLM0_SX143.WAV': {'spk_id': 'FJLM0',
#   'duration': 3.4048125,
#   'phn': 'sil dh ah s aw n sil d ih v sil jh ih n ih f er z sil b y uw sil g l s sil k eh r sil dh eh ae n ah l ow sil p sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/FJLM0/SX143.WAV.pt'},
#  'FJLM0_SX413.WAV': {'spk_id': 'FJLM0',
#   'duration': 3.4048125,
#   'phn': 'sil d ae f sil n iy s w ih dx ih sh sil n iy sil d l sil p oy n sil t s sil k aa r f sil m ae sil ch sil t hh er s sil k er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/FJLM0/SX413.WAV.pt'},
#  'FJLM0_SI1043.WAV': {'spk_id': 'FJLM0',
#   'duration': 3.417625,
#   'phn': 'sil n aa sil s ih sil p r aa z ih ng l iy sil dh ih s ah sil p r ow sil ch sil d ih sil d n aa w er sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/FJLM0/SI1043.WAV.pt'},
#  'FJLM0_SI2303.WAV': {'spk_id': 'FJLM0',
#   'duration': 4.057625,
#   'phn': 'sil ih n sh aa r sil eh n sil t ih sil b aa r ah n aa r sil b er l f r ey z sil s l ae sh sil t ih m sil b er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/FJLM0/SI2303.WAV.pt'},
#  'FJLM0_SX53.WAV': {'spk_id': 'FJLM0',
#   'duration': 3.097625,
#   'phn': 'sil iy v ih n ah s ih m sil p l v ah sil k ae sil b y ih l eh r iy sil k ah n sil t ey n sil t s ih m sil b l z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/FJLM0/SX53.WAV.wav.pt'},
#  'FJLM0_SI1673.WAV': {'spk_id': 'FJLM0',
#   'duration': 3.161625,
#   'phn': 'sil w ah n th ih ng sil k hh ih th aa sil n ow sil b ah dx iy n ow z ah sil b aw dx ih y eh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/FJLM0/SI1673.WAV.wav.pt'},
#  'FJLM0_SX323.WAV': {'spk_id': 'FJLM0',
#   'duration': 2.841625,
#   'phn': 'sil dh ah f aa sil p r ih v ih n ih sil dh ih m f r ah m er r aa v ih ng aa n sil t aa m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/FJLM0/SX323.WAV.wav.pt'},
#  'FJLM0_SX233.WAV': {'spk_id': 'FJLM0',
#   'duration': 2.51525,
#   'phn': 'sil hh aa w ey ih n sil f r iy w ey m iy n ih s ey m sil th ae ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/FJLM0/SX233.WAV.wav.pt'},
#  'MTLS0_SX290.WAV': {'spk_id': 'MTLS0',
#   'duration': 3.18725,
#   'phn': 'sil dh ih s sil b r ow sh er ih s sil p ah sil t ih sil k l ih n f ow m sil t ih f er sil p er s sil p ah sil t ih v sil b ay er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/MTLS0/SX290.WAV.pt'},
#  'MTLS0_SX20.WAV': {'spk_id': 'MTLS0',
#   'duration': 3.008,
#   'phn': 'sil sh iy w aa r w aa r m f l iy s iy w uh l ah n ow f er aa l z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/MTLS0/SX20.WAV.pt'},
#  'MTLS0_SX200.WAV': {'spk_id': 'MTLS0',
#   'duration': 2.5408125,
#   'phn': 'sil r aw f sil k ah n sil t r ow sil dh ih s sil t aa sil p w aa sil ch f er m dh ah sil b l iy sil ch er s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/MTLS0/SX200.WAV.pt'},
#  'MTLS0_SI740.WAV': {'spk_id': 'MTLS0',
#   'duration': 2.1824375,
#   'phn': 'sil d uw w ih th aw sil f ae n sil s iy sil t ey sil b l sil k l aa dh s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/MTLS0/SI740.WAV.pt'},
#  'MTLS0_SX380.WAV': {'spk_id': 'MTLS0',
#   'duration': 2.2144375,
#   'phn': 'sil w ay sil ch aa r sil jh m ah n iy f er s ah sil ch sil g aa r sil b ih sil jh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/MTLS0/SX380.WAV.pt'},
#  'MTLS0_SI2000.WAV': {'spk_id': 'MTLS0',
#   'duration': 2.86725,
#   'phn': 'sil w iy sil k ih ng sil g eh dx ih sil ih f w ih sil d ih ih sil g sil hh iy s eh sil p ey sh n sil t l iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/MTLS0/SI2000.WAV.wav.pt'},
#  'MTLS0_SI1370.WAV': {'spk_id': 'MTLS0',
#   'duration': 4.096,
#   'phn': 'sil w ih m ey s ey dh eh sil hh ih z sil p r aa sil l ah m w ah z sil d ay sil n ow s sil t sil b ah sil dh ae sil t hh iy r uw f uw z sil t r iy sil m ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/MTLS0/SI1370.WAV.pt'},
#  'MTLS0_SX110.WAV': {'spk_id': 'MTLS0',
#   'duration': 3.4048125,
#   'phn': 'sil dh ah sil b eh s sil t w ey sil t ah l er n sil ih z sil t ih s aa l v eh sil k s sil t er sil p r aa sil b l ah m s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/MTLS0/SX110.WAV.wav.pt'},
#  'MLLL0_SX103.WAV': {'spk_id': 'MLLL0',
#   'duration': 2.3424375,
#   'phn': 'sil k aa l ah n ae m b uw l ih n sil s f er m eh dx ih sil k l ah s ih s sil t n sil t s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/MLLL0/SX103.WAV.wav.pt'},
#  'MLLL0_SI1993.WAV': {'spk_id': 'MLLL0',
#   'duration': 2.48325,
#   'phn': 'sil sh uh sil sh iy w ey sil k ih m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/MLLL0/SI1993.WAV.pt'},
#  'MLLL0_SX13.WAV': {'spk_id': 'MLLL0',
#   'duration': 2.7328125,
#   'phn': 'sil s sil w iy ng y er aa r m ih z hh ay ih z ih sil k ae ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/MLLL0/SX13.WAV.pt'},
#  'MLLL0_SX373.WAV': {'spk_id': 'MLLL0',
#   'duration': 2.80325,
#   'phn': 'sil ah sil b aa r iy n aa v l ih z ih s ah sil p er sil s l iy sil p iy n sil p ih l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/MLLL0/SX373.WAV.pt'},
#  'MLLL0_SI1363.WAV': {'spk_id': 'MLLL0',
#   'duration': 4.985625,
#   'phn': 'sil s ah m ih dh iy s sil p eh sil k ih l ey sh n z sil m ey eh v s ah m eh r ih sil ah dh er z er s ah m w ah dx ah m sil b ih sil g y uw ah s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/MLLL0/SI1363.WAV.pt'},
#  'MLLL0_SI733.WAV': {'spk_id': 'MLLL0',
#   'duration': 4.345625,
#   'phn': 'sil d uw ah v oy sil p ah ng sil sh er iy n er sil k ah dx iy n ih n sil t ih m iy sil s sil t eh s dh ah m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/MLLL0/SI733.WAV.wav.pt'},
#  'MLLL0_SX193.WAV': {'spk_id': 'MLLL0',
#   'duration': 3.488,
#   'phn': 'sil w ay sil b ay oy l sil w ah n y ih aa w ih sh uw z sil m ay n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/MLLL0/SX193.WAV.wav.pt'},
#  'MLLL0_SX283.WAV': {'spk_id': 'MLLL0',
#   'duration': 3.8208125,
#   'phn': 'sil p l ae n sil d sil p eh er n sil t hh uh sil ah aa r sil g ih n ih z ey sh ih n s sil p m ow sil b er th sil k n sil t r ow l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR4/MLLL0/SX283.WAV.pt'},
#  'FDHC0_SI929.WAV': {'spk_id': 'FDHC0',
#   'duration': 2.8608125,
#   'phn': 'sil b ah sil t s ah sil ch sil k ey s ih z sil w er ih n dh ah sil p ae s sil t ah n y uw sh uw l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/FDHC0/SI929.WAV.wav.pt'},
#  'FDHC0_SI2189.WAV': {'spk_id': 'FDHC0',
#   'duration': 2.2528125,
#   'phn': 'sil y uw s aa dh ah m aa w iy z sil t ih sil g eh dh er sil dh ow z y ih er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/FDHC0/SI2189.WAV.pt'},
#  'FDHC0_SI1559.WAV': {'spk_id': 'FDHC0',
#   'duration': 3.3984375,
#   'phn': 'sil v ih sh uw ah l iy dh iy z ih sil p r aa sil k s ih m ey dx ih sil w ah dx iy w ih s f iy l iy n w ih sil th ih n ih m s eh l f sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/FDHC0/SI1559.WAV.pt'},
#  'FDHC0_SX119.WAV': {'spk_id': 'FDHC0',
#   'duration': 3.02725,
#   'phn': 'sil dh ih m ih s sil k w ow w ih z r iy sil t r ae sil t ih sil d w ih sil th ih n ah sil p aa l ih sil jh iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/FDHC0/SX119.WAV.wav.pt'},
#  'FDHC0_SX299.WAV': {'spk_id': 'FDHC0',
#   'duration': 3.2064375,
#   'phn': 'sil sh ey v iy n sil k r iy m ih z ih sil p aa sil p y uw l er ay dx eh m aa n hh aa l ah w iy n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/FDHC0/SX299.WAV.pt'},
#  'FDHC0_SX29.WAV': {'spk_id': 'FDHC0',
#   'duration': 2.5408125,
#   'phn': 'sil hh eh l sil p sil g r ey sil t ih sil p ih sil k ih sil p eh sil k ih v sil p ih sil t ey dx ow z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/FDHC0/SX29.WAV.pt'},
#  'FDHC0_SX389.WAV': {'spk_id': 'FDHC0',
#   'duration': 2.457625,
#   'phn': 'sil dh ey ow n ah sil b ih sil hh aw s ih n dh ah r er m ow sil k ah n sil t r iy s ay sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/FDHC0/SX389.WAV.wav.pt'},
#  'FDHC0_SX209.WAV': {'spk_id': 'FDHC0',
#   'duration': 2.5664375,
#   'phn': 'sil m ay sil k l sil k ah l er sil dh ih sil b eh sil d r uw m w aa l w ih th sil k r ey aa n s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/FDHC0/SX209.WAV.wav.pt'},
#  'MNJM0_SX140.WAV': {'spk_id': 'MNJM0',
#   'duration': 2.89925,
#   'phn': 'sil ae sil r ih sil k ah l sil ch er l sil p r aa dx ah sil s aa r ah n iy v l iy sil d ih sh r ih v ih dx ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/MNJM0/SX140.WAV.wav.pt'},
#  'MNJM0_SX230.WAV': {'spk_id': 'MNJM0',
#   'duration': 3.552,
#   'phn': 'sil eh l aw l iy w ey hh ih er sil b ah r ae sh n ah l ay z aa l er er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/MNJM0/SX230.WAV.pt'},
#  'MNJM0_SX320.WAV': {'spk_id': 'MNJM0',
#   'duration': 3.808,
#   'phn': 'sil dh eh n eh r ih s ah n ah sil g aa sil g sil m ey n aa sil b ih w uh th ih m w aa sil k ih ng sil d ih s sil t ih n sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/MNJM0/SX320.WAV.pt'},
#  'MNJM0_SX410.WAV': {'spk_id': 'MNJM0',
#   'duration': 2.752,
#   'phn': 'sil g r eh sil b ay z f r eh sh sil m ih l sil k iy sil ch sil w iy sil d ey m aa r n ih ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/MNJM0/SX410.WAV.pt'},
#  'MNJM0_SX50.WAV': {'spk_id': 'MNJM0',
#   'duration': 3.3984375,
#   'phn': 'sil k ae dx ah s sil t r aa f ih sil k eh sil k ah n aa m ih sil k ah sil b ae sil s sil n ih sil g l eh sil dh ah sil p aa r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/MNJM0/SX50.WAV.pt'},
#  'MNJM0_SI950.WAV': {'spk_id': 'MNJM0',
#   'duration': 5.472,
#   'phn': 'sil ae s ah sil ch sil ih w ah z sil b iy aa m sil p aa l ah sil t ih sil s ah n hh ae sil n ow n iy dx ah sil jh ah s ih v ah sil k ey sh n sil b ay ey m eh s ih sil jh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/MNJM0/SI950.WAV.wav.pt'},
#  'MNJM0_SI1580.WAV': {'spk_id': 'MNJM0',
#   'duration': 2.99525,
#   'phn': 'sil hh ih aa w iy s iy m sil t eh hh ae v m ah n iy ih hh sil hh ih n hh ih z sil p aa sil k ah sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/MNJM0/SI1580.WAV.wav.pt'},
#  'MNJM0_SI2210.WAV': {'spk_id': 'MNJM0',
#   'duration': 2.03525,
#   'phn': 'sil n ow r iy sil t er n ae sil d r eh s sil w ah sil s ow w eh v er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/MNJM0/SI2210.WAV.wav.pt'},
#  'MGRT0_SI820.WAV': {'spk_id': 'MGRT0',
#   'duration': 6.1248125,
#   'phn': 'sil b ay dh ae sil t sil w ah n f iy l z ae sil m ae sil n eh dx ih sil f aa r s ah z sil aa er z sil jh eh n r l ae z ih l eh sil t er sil k l f aa r s ih s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/MGRT0/SI820.WAV.pt'},
#  'MGRT0_SX100.WAV': {'spk_id': 'MGRT0',
#   'duration': 4.9344375,
#   'phn': 'sil p r aa sil jh eh sil d ih v eh l m ah n sil w ah z sil p er s iy dx ih ng sil t uw s l ow l iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/MGRT0/SX100.WAV.wav.pt'},
#  'MGRT0_SI2080.WAV': {'spk_id': 'MGRT0',
#   'duration': 2.3104375,
#   'phn': 'sil hh iy w uh sil n aa sil k eh r iy ih sil b r iy f sil k ey s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/MGRT0/SI2080.WAV.pt'},
#  'MGRT0_SX190.WAV': {'spk_id': 'MGRT0',
#   'duration': 2.8928125,
#   'phn': 'sil s er v z ih sil k ow l s l aa ae f sh er ay ae sil dh iy oy l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/MGRT0/SX190.WAV.wav.pt'},
#  'MGRT0_SX10.WAV': {'spk_id': 'MGRT0',
#   'duration': 3.0144375,
#   'phn': 'sil aa r y er sil g r ey sil z hh ay er er l ow er dh eh n ae n s iy s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/MGRT0/SX10.WAV.pt'},
#  'MGRT0_SX280.WAV': {'spk_id': 'MGRT0',
#   'duration': 1.984,
#   'phn': 'sil dh iy ow ey s ah s sil w ah z ah m er aa sh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/MGRT0/SX280.WAV.wav.pt'},
#  'MGRT0_SX370.WAV': {'spk_id': 'MGRT0',
#   'duration': 3.36,
#   'phn': 'sil dh eh n oy z sil p r aa sil l m sil g r ow z sil m aa r ah n oy ih ng iy sil ch sil d ey sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/MGRT0/SX370.WAV.pt'},
#  'MGRT0_SI1450.WAV': {'spk_id': 'MGRT0',
#   'duration': 6.2144375,
#   'phn': 'sil m iy sil t s sil dh er r ey dx iy ey sh n sil p r aa s eh s ih ng ah v m iy sil t hh eh z r iy s iy v sil d ih sil k s sil t eh n s ih v ih n v eh s sil t ih sil g ey sh ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR7/MGRT0/SI1450.WAV.wav.pt'},
#  'MCMJ0_SX104.WAV': {'spk_id': 'MCMJ0',
#   'duration': 1.977625,
#   'phn': 'sil hh iy s sil t ow l ah sil d ay m f r ah m ah sil b eh sil g er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/MCMJ0/SX104.WAV.pt'},
#  'MCMJ0_SI602.WAV': {'spk_id': 'MCMJ0',
#   'duration': 3.89125,
#   'phn': 'sil b ih sil dh ih sh ih sil p s er v er ih s l ow n aw sil eh n w iy sil d ow n sil g eh sil s ow m eh n iy s ey l er z ih n ih m aa r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/MCMJ0/SI602.WAV.pt'},
#  'MCMJ0_SX284.WAV': {'spk_id': 'MCMJ0',
#   'duration': 3.648,
#   'phn': 'sil jh eh f th aa y uw aa r sil uw dx ih n f ey v er ih v ih s eh n sil t er f uw sil jh sil p er sil ch ih s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/MCMJ0/SX284.WAV.pt'},
#  'MCMJ0_SX374.WAV': {'spk_id': 'MCMJ0',
#   'duration': 2.2528125,
#   'phn': 'sil jh aa n sil k l iy n z sil sh eh l f ih sh f er ah l ih v ih ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/MCMJ0/SX374.WAV.wav.pt'},
#  'MCMJ0_SI1094.WAV': {'spk_id': 'MCMJ0',
#   'duration': 3.7568125,
#   'phn': 'sil m eh r ih sil k ih n uw s sil p ey sil p er r ih v y uw er z l ay sil t ih sil k aa l hh ih z sil p l ey s sil n iy ih l ih s sil t ah sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/MCMJ0/SI1094.WAV.wav.pt'},
#  'MCMJ0_SI464.WAV': {'spk_id': 'MCMJ0',
#   'duration': 3.89125,
#   'phn': 'sil dh ah sil p r aa s sil p eh sil t ih v sil k ah dx ih ng sil b ae sil k s sil eh n ih ng sil ih z n ah n sil p l eh z ih n w ah n f er eh n iy sil g ah v er n er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/MCMJ0/SI464.WAV.pt'},
#  'MCMJ0_SX14.WAV': {'spk_id': 'MCMJ0',
#   'duration': 2.944,
#   'phn': 'sil b ah f aa r th er z sil d ey z ih sil g z ae m r ih v y uw eh v r ih f aa r m y ih l ah sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/MCMJ0/SX14.WAV.wav.pt'},
#  'MCMJ0_SX194.WAV': {'spk_id': 'MCMJ0',
#   'duration': 1.945625,
#   'phn': 'sil dh ey ih n sil jh oy ih w eh n ay aa sil d ih sh ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/MCMJ0/SX194.WAV.pt'},
#  'FMGD0_SI934.WAV': {'spk_id': 'FMGD0',
#   'duration': 3.47525,
#   'phn': 'sil ah th aa r er dx iy s ey dh eh dx ow l sil s sil t er z aa r ey sil p r ay m sil t aa r sil g ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/FMGD0/SI934.WAV.wav.pt'},
#  'FMGD0_SX34.WAV': {'spk_id': 'FMGD0',
#   'duration': 2.361625,
#   'phn': 'sil d ow n sil d uw sil ch aa r l iy z sil d er dx iy sil d ih sh ih z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/FMGD0/SX34.WAV.wav.pt'},
#  'FMGD0_SX394.WAV': {'spk_id': 'FMGD0',
#   'duration': 2.361625,
#   'phn': 'sil k ae l s iy ih m ey sil s sil b ow n z n sil t iy th s sil t r aa ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/FMGD0/SX394.WAV.pt'},
#  'FMGD0_SI2194.WAV': {'spk_id': 'FMGD0',
#   'duration': 4.72325,
#   'phn': 'sil hh iy hh eh sil f aa l ih n sil t uw ih s aa f sil jh aa sil eh n aw dh ih sil jh aa sil w ah z sil g aa n ih n hh iy w uh s sil t r ae n sil d ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/FMGD0/SI2194.WAV.pt'},
#  'FMGD0_SX214.WAV': {'spk_id': 'FMGD0',
#   'duration': 3.02725,
#   'phn': 'sil dh ah m aa r n ih ng sil d uw aa n dh ah s sil p ay dx er w eh sil g l ih s eh n sil d ih n dh ah s ah n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/FMGD0/SX214.WAV.wav.pt'},
#  'FMGD0_SX124.WAV': {'spk_id': 'FMGD0',
#   'duration': 3.7504375,
#   'phn': 'sil aa sil jh ih sil k s sil m ey sil d ih v sil p y uw dx er er sil b y uw dx ih f l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/FMGD0/SX124.WAV.wav.pt'},
#  'FMGD0_SI1564.WAV': {'spk_id': 'FMGD0',
#   'duration': 4.441625,
#   'phn': 'sil hh ah z sil b uh n d r iy w ah z sil b aw n d ih sil b ay s sil n ey sil r eh l f eh n s ah z ae n dh eh r w er sil g r ey z ih ng sil k ae dx l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/FMGD0/SI1564.WAV.wav.pt'},
#  'FMGD0_SX304.WAV': {'spk_id': 'FMGD0',
#   'duration': 2.7968125,
#   'phn': 'sil ch iy sil s sil t aa sil k ih ng z r ah n dh ih f er s sil t ay m dh eh r w aa r n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/FMGD0/SX304.WAV.wav.pt'},
#  'MJDH0_SI724.WAV': {'spk_id': 'MJDH0',
#   'duration': 2.5664375,
#   'phn': 'sil ih sil s ih s sil t r iy m l ay n r ay f l f ae s sil t n w ah l m ey sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/MJDH0/SI724.WAV.wav.pt'},
#  'MJDH0_SI1354.WAV': {'spk_id': 'MJDH0',
#   'duration': 4.8128125,
#   'phn': 'sil w ih th ih n ah l aa r sil jh er s ow sh l s ih s sil t ah m aa r dh ih s sil t r ah sil k sh er l n f ah ng sil sh n l s ah sil s ih s sil t ah m s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/MJDH0/SI1354.WAV.wav.pt'},
#  'MJDH0_SX4.WAV': {'spk_id': 'MJDH0',
#   'duration': 2.32325,
#   'phn': 'sil jh ey n m ey er n m aa r m ah n iy sil b ay w er sil k ih ng hh aa r sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/MJDH0/SX4.WAV.pt'},
#  'MJDH0_SX364.WAV': {'spk_id': 'MJDH0',
#   'duration': 4.416,
#   'phn': 'sil iy sil ch ah n sil t ay m l iy ih n sil k ah m l aa s sil k ow ah n s ay dx ih w ih th ah sil b r ey sil d aw n ah v ih hh iy dx iy ng s ih s sil t m sil p aa r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/MJDH0/SX364.WAV.pt'},
#  'MJDH0_SX94.WAV': {'spk_id': 'MJDH0',
#   'duration': 2.7328125,
#   'phn': 'sil y ah ng s sil t uw z sil l ah v sil k aa m ih n sil k ae n sil d iy z sil t r iy sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/MJDH0/SX94.WAV.wav.pt'},
#  'MJDH0_SI1984.WAV': {'spk_id': 'MJDH0',
#   'duration': 1.33125,
#   'phn': 'sil eh n w ah dx ay z dh ey w er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/MJDH0/SI1984.WAV.pt'},
#  'MJDH0_SX274.WAV': {'spk_id': 'MJDH0',
#   'duration': 3.136,
#   'phn': 'sil k l ih f w ih s uw dh sil b ay dh ah l ih sil sh er r iy ih s sil m ih s aa sh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/MJDH0/SX274.WAV.pt'},
#  'MJDH0_SX184.WAV': {'spk_id': 'MJDH0',
#   'duration': 2.137625,
#   'phn': 'sil dh ih sil k ae sil s sil m iy aw oy z hh er sil s sil m ay ih er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR6/MJDH0/SX184.WAV.wav.pt'},
#  'FPAS0_SX44.WAV': {'spk_id': 'FPAS0',
#   'duration': 2.2464375,
#   'phn': 'sil b ae s sil k ih sil b aa l sil k ih n sil b iy ih n eh n sil t er sil ch ey n ih ng s sil p aa r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/FPAS0/SX44.WAV.pt'},
#  'FPAS0_SX224.WAV': {'spk_id': 'FPAS0',
#   'duration': 1.6128125,
#   'phn': 'sil hh aw sil g uh dx ih z y er ih n sil d er ih n s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/FPAS0/SX224.WAV.pt'},
#  'FPAS0_SI1272.WAV': {'spk_id': 'FPAS0',
#   'duration': 1.856,
#   'phn': 'sil l ae sil r ih sil t er iy ae s sil t r ah f ih z ih sil k s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/FPAS0/SI1272.WAV.wav.pt'},
#  'FPAS0_SX314.WAV': {'spk_id': 'FPAS0',
#   'duration': 2.937625,
#   'phn': 'sil ih f sil p iy sil p l w er m aa r sil jh eh n er ih s dh eh r sil b iy n ow n iy sil d f er w eh l f eh r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/FPAS0/SX314.WAV.wav.pt'},
#  'FPAS0_SX134.WAV': {'spk_id': 'FPAS0',
#   'duration': 2.944,
#   'phn': 'sil d ih s eh m sil b er ng sil jh y ae n y uw er ih n ay s sil m ah n th s sil t ih s sil p eh n ih n m ay ae m iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/FPAS0/SX134.WAV.pt'},
#  'FPAS0_SI944.WAV': {'spk_id': 'FPAS0',
#   'duration': 2.35525,
#   'phn': 'sil ih v dh ah f aa r m ih z r eh n sil t ih sil dh ah r eh n m ah s sil b iy sil p ey sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/FPAS0/SI944.WAV.pt'},
#  'FPAS0_SX404.WAV': {'spk_id': 'FPAS0',
#   'duration': 2.777625,
#   'phn': 'sil b aa r sil b er n sil p ey sil p er n l iy v z ih n ah sil b ih sil b aa n sil f ay er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/FPAS0/SX404.WAV.pt'},
#  'FPAS0_SI2204.WAV': {'spk_id': 'FPAS0',
#   'duration': 3.85925,
#   'phn': 'sil p r ih dx iy s uw n ah w uh m ih n sil k ey m ah l aa ng sil k ih r ih n ih f ow l sil d ih dx ah m sil b r ah l ih z ah w aa sil k ih ng s sil t ih sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/FPAS0/SI2204.WAV.pt'},
#  'MWEW0_SX371.WAV': {'spk_id': 'MWEW0',
#   'duration': 2.89925,
#   'phn': 'sil r ay sil n aw m ey n aa sil b iy dh ih sil b eh s sil t ay m f er sil b ih z n ih s sil m er sil jh er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/MWEW0/SX371.WAV.wav.pt'},
#  'MWEW0_SX101.WAV': {'spk_id': 'MWEW0',
#   'duration': 3.936,
#   'phn': 'sil k ih n er sil g ah r n sil ch ih l sil d er n sil d eh sil k er r ey sil dh er sil k l ae s r uw m z f er aa l hh aa l ah sil d ey z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/MWEW0/SX101.WAV.wav.pt'},
#  'MWEW0_SX11.WAV': {'spk_id': 'MWEW0',
#   'duration': 1.6768125,
#   'phn': 'sil hh iy w l ah l aw er r eh r l ay sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/MWEW0/SX11.WAV.pt'},
#  'MWEW0_SX191.WAV': {'spk_id': 'MWEW0',
#   'duration': 2.528,
#   'phn': 'sil w ih sil d r aa aa l f ow n iy ae sil k y ih z ey sh ih n z ih w ah n sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/MWEW0/SX191.WAV.wav.pt'},
#  'MWEW0_SI1361.WAV': {'spk_id': 'MWEW0',
#   'duration': 2.54725,
#   'phn': 'sil b ah dx ih n ih s sil w ah n s eh sil sh n w iy w eh l sil k ah m sil d ah aa dx ih dx er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/MWEW0/SI1361.WAV.wav.pt'},
#  'MWEW0_SX281.WAV': {'spk_id': 'MWEW0',
#   'duration': 3.3408125,
#   'phn': 'sil k aa r iy ih n sil t r ih sh sil p l ey sil t ae sil w ih sil b iy sil ch sil b aa l z f er aw er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/MWEW0/SX281.WAV.pt'},
#  'MWEW0_SI1991.WAV': {'spk_id': 'MWEW0',
#   'duration': 4.025625,
#   'phn': 'sil l aa dx ah v sil p iy sil p l w l r ow m dh ih s sil t r iy sil s ih n sil k aa s sil t uw m z ih n m ae s sil s sil ih n hh ae v ih ng ah sil b aa l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/MWEW0/SI1991.WAV.pt'},
#  'MWEW0_SI731.WAV': {'spk_id': 'MWEW0',
#   'duration': 1.9968125,
#   'phn': 'sil ah f uw y ih er z l ey dx er dh ih sil d ow m f eh l ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/MWEW0/SI731.WAV.wav.pt'},
#  'MTAS1_SI838.WAV': {'spk_id': 'MTAS1',
#   'duration': 2.649625,
#   'phn': 'sil ih n sil k r iy s iy ng sil t eh m sil p ow ah v n uw sil p r aa dx ih sil d ih v eh l ah sil m ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/MTAS1/SI838.WAV.pt'},
#  'MTAS1_SX388.WAV': {'spk_id': 'MTAS1',
#   'duration': 4.0384375,
#   'phn': 'sil hh er r ay sil hh ae n sil d sil ey sil k s sil w ih n eh v er dh ah sil b eh r ih m eh sil t er sil p r eh sh er sil ch ey n sil jh ih z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/MTAS1/SX388.WAV.wav.pt'},
#  'MTAS1_SX28.WAV': {'spk_id': 'MTAS1',
#   'duration': 2.4768125,
#   'phn': 'sil b ey sil dh ae sil g aa r sil d f er w ah n sil g ae l ah n sil ah v sil g ae s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/MTAS1/SX28.WAV.pt'},
#  'MTAS1_SX118.WAV': {'spk_id': 'MTAS1',
#   'duration': 2.816,
#   'phn': 'sil k ah m sil b ay n aa l dh iy ih ng sil g r iy dx iy ih n s sil ih n ah l aa r sil jh sil b ow l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/MTAS1/SX118.WAV.wav.pt'},
#  'MTAS1_SI2098.WAV': {'spk_id': 'MTAS1',
#   'duration': 3.1808125,
#   'phn': 'sil hh iy sil g ey v ey sh aa r sil hh aa r sil d l ae f ih n l uh sil t ih hh er n ow iy ng l iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/MTAS1/SI2098.WAV.wav.pt'},
#  'MTAS1_SX208.WAV': {'spk_id': 'MTAS1',
#   'duration': 3.513625,
#   'phn': 'sil r aa sil b s ae sil b ay dh ah sil p aa n sil d ih sil ih n s sil k eh sil ch sil dh ah s sil t r ey sil g iy s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/MTAS1/SX208.WAV.wav.pt'},
#  'MTAS1_SI1473.WAV': {'spk_id': 'MTAS1',
#   'duration': 1.472,
#   'phn': 'sil y ih dx ow n iy dx ah n ah f sil hh ah n iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/MTAS1/SI1473.WAV.wav.pt'},
#  'MTAS1_SX298.WAV': {'spk_id': 'MTAS1',
#   'duration': 3.1808125,
#   'phn': 'sil ay sil d r eh dh ah n aa sil b ay dh iy sh uw z dh ih n sil b iy ow v er sil ch aa r sil jh sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/test/DR2/MTAS1/SX298.WAV.pt'}}

# %%
with open('dev_fbank.json') as file:
    t_json = json.load(file)
    
t_json
# Out:
# {'MJSW0_SI1640.WAV': {'spk_id': 'MJSW0',
#   'duration': 1.632,
#   'phn': 'sil hh aw sil d ih sil w ah n sil jh oy n dh eh m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/MJSW0/SI1640.WAV.pt'},
#  'MJSW0_SX290.WAV': {'spk_id': 'MJSW0',
#   'duration': 3.609625,
#   'phn': 'sil dh ih s sil b r ow sh er ih z sil p er sil t ih sil k ih l iy ih n f aa r m ih sil t ih v f er sil p er s sil p eh sil t ih v sil b ay er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/MJSW0/SX290.WAV.pt'},
#  'MJSW0_SX20.WAV': {'spk_id': 'MJSW0',
#   'duration': 3.53925,
#   'phn': 'sil sh iy w aa r w aa r m f l iy s iy w uh l eh n ow v er aa l z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/MJSW0/SX20.WAV.pt'},
#  'MJSW0_SX200.WAV': {'spk_id': 'MJSW0',
#   'duration': 2.5344375,
#   'phn': 'sil r ae l f sil k ih n sil t r ow l dh ah s sil t aa sil w aa sil ch f r ah m ah sil b l iy sil ch er s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/MJSW0/SX200.WAV.pt'},
#  'MJSW0_SX380.WAV': {'spk_id': 'MJSW0',
#   'duration': 4.0768125,
#   'phn': 'sil w ay sil ch aa r sil jh sil m ah n iy f er s ah sil ch sil g aa r sil b ih sil jh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/MJSW0/SX380.WAV.pt'},
#  'MJSW0_SX110.WAV': {'spk_id': 'MJSW0',
#   'duration': 2.8864375,
#   'phn': 'sil dh ah sil b eh s sil w ey dx ih l er n ih s sil t ah s aa l v eh sil k s sil t r ih sil p r aa sil b l m sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/MJSW0/SX110.WAV.wav.pt'},
#  'MJSW0_SI1010.WAV': {'spk_id': 'MJSW0',
#   'duration': 4.6528125,
#   'phn': 'sil dh ih s ow sil k aa l sil v eh sil jh ih sil b l ay v r iy ih z dh ah hh aa r sil d eh n sil d ow s sil p er m ih v dh iy eh sil g s ay z sil t sil s iy sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/MJSW0/SI1010.WAV.pt'},
#  'MJSW0_SI2270.WAV': {'spk_id': 'MJSW0',
#   'duration': 2.4384375,
#   'phn': 'sil d aa sil g z sil d ih sil d s ah m th ih ng sil t ah w ah n z iy sil g ow sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/MJSW0/SI2270.WAV.pt'},
#  'FAKS0_SX133.WAV': {'spk_id': 'FAKS0',
#   'duration': 3.31525,
#   'phn': 'sil p iy sil s er r iy ih z aa r sil k ih n v iy n y ih n sil f er ih sil k w ih sil k l ah n sil ch sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FAKS0/SX133.WAV.wav.pt'},
#  'FAKS0_SX403.WAV': {'spk_id': 'FAKS0',
#   'duration': 3.36,
#   'phn': 'sil hh er w aa r sil d r ow sil k n s ih s ah v ow n l iy s sil k er sil t s ah n sil b l aw s ih s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FAKS0/SX403.WAV.wav.pt'},
#  'FAKS0_SX43.WAV': {'spk_id': 'FAKS0',
#   'duration': 2.45125,
#   'phn': 'sil eh l sil d er l iy sil p iy sil p l er aa f ih n ih sil k s sil k l uw sil d ih sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FAKS0/SX43.WAV.pt'},
#  'FAKS0_SI2203.WAV': {'spk_id': 'FAKS0',
#   'duration': 3.513625,
#   'phn': 'sil dh ih r iy z ah n z f er dh ih s sil d ay v s iy m sil d f uw l ih sh sil n aw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FAKS0/SI2203.WAV.wav.pt'},
#  'FAKS0_SX313.WAV': {'spk_id': 'FAKS0',
#   'duration': 3.53925,
#   'phn': 'sil d r aa sil f ay v f aa r m z ah n dh ah sil b aa sil k s sil b ah f aa r y ih sil g ow aw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FAKS0/SX313.WAV.pt'},
#  'FAKS0_SI943.WAV': {'spk_id': 'FAKS0',
#   'duration': 3.7568125,
#   'phn': 'sil p er sil d ah sil k sh ih n m ey f aa l f aa r sil b ah l ow ah sil k s sil p ih sil t ey sh n sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FAKS0/SI943.WAV.wav.pt'},
#  'FAKS0_SX223.WAV': {'spk_id': 'FAKS0',
#   'duration': 3.097625,
#   'phn': 'sil p uh sil dh ah sil b uh sil ch er sil b l aa sil t ey sil b l ah n dh ih sil g er aa sh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FAKS0/SX223.WAV.pt'},
#  'FAKS0_SI1573.WAV': {'spk_id': 'FAKS0',
#   'duration': 4.9728125,
#   'phn': 'sil hh ih z sil k ae sil t ih n w ah s th ih n ae n hh ae sil g er sil d ih n ih z sil b y uw dx uw f l sil b uw sil t s sil w er w aa r n ih n sil sh ae sil b iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FAKS0/SI1573.WAV.pt'},
#  'FJEM0_SI1894.WAV': {'spk_id': 'FJEM0',
#   'duration': 2.944,
#   'phn': 'sil m ay f aa dh er r ae n hh ih m aa f hh ih er s ih sil k s y ih er z ih sil g ow sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FJEM0/SI1894.WAV.pt'},
#  'FJEM0_SX4.WAV': {'spk_id': 'FJEM0',
#   'duration': 3.0144375,
#   'phn': 'sil jh ey n m ey er n m aa r m ah n iy sil b ay w er sil k ih ng hh aa r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FJEM0/SX4.WAV.pt'},
#  'FJEM0_SI1264.WAV': {'spk_id': 'FJEM0',
#   'duration': 3.449625,
#   'phn': 'sil d ae n s ih z aa l sil t er n ey sil ah sil w ah th s ah ng er s sil p ow sil k ih n v er s ah z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FJEM0/SI1264.WAV.pt'},
#  'FJEM0_SX364.WAV': {'spk_id': 'FJEM0',
#   'duration': 5.7984375,
#   'phn': 'sil iy sil ch ah n sil t ay m l iy ih ng sil k ah m l aa s sil k ow ih n s ay dx ih sil w ih th ih sil b r ey sil d aw n ih v ih hh iy sil t ih ng s ih s sil t ah m sil p aa r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FJEM0/SX364.WAV.pt'},
#  'FJEM0_SI634.WAV': {'spk_id': 'FJEM0',
#   'duration': 6.0864375,
#   'phn': 'sil hh iy r hh iy ih z sil k w ay sil p er s w ey s ih v l iy sil dh ih v eh r iy ih m sil b aa dx ih m ih ih v m iy n eh s n s l ay n ah s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FJEM0/SI634.WAV.wav.pt'},
#  'FJEM0_SX94.WAV': {'spk_id': 'FJEM0',
#   'duration': 3.2064375,
#   'phn': 'sil y ah ng s sil t er z l ah v sil k aa m ih n sil k ae n sil d iy eh z sil t r iy sil t s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FJEM0/SX94.WAV.wav.pt'},
#  'FJEM0_SX274.WAV': {'spk_id': 'FJEM0',
#   'duration': 3.92325,
#   'phn': 'sil k l ih f w ah s uw dh sil b ay dh ah l ah sil k sh er r iy ih s m ah s aa sh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FJEM0/SX274.WAV.pt'},
#  'FJEM0_SX184.WAV': {'spk_id': 'FJEM0',
#   'duration': 2.9184375,
#   'phn': 'sil dh ih sil k ae sil s m iy aw aa l w ey z hh er sil s m ay ih er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FJEM0/SX184.WAV.wav.pt'},
#  'FDAC1_SI844.WAV': {'spk_id': 'FDAC1',
#   'duration': 7.4368125,
#   'phn': 'sil dh ah s sil t eh sil n ih sil k l ah f ih sh ih n s iy ih z ah sil ch iy v sil ae sil dh iy ih sil k s sil p eh n sil t s ah v ae sil ch uw ah l ih sil k s sil p ih r iy ih n sil t s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FDAC1/SI844.WAV.wav.pt'},
#  'FDAC1_SX34.WAV': {'spk_id': 'FDAC1',
#   'duration': 4.025625,
#   'phn': 'sil d ow n d uw sil ch ae l iy z sil d er dx iy sil d ih sh ih z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FDAC1/SX34.WAV.wav.pt'},
#  'FDAC1_SX394.WAV': {'spk_id': 'FDAC1',
#   'duration': 3.8464375,
#   'phn': 'sil k ae l s iy ih m ey sil s sil b ow n z ih n sil t iy th s sil t r aa ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FDAC1/SX394.WAV.pt'},
#  'FDAC1_SI1474.WAV': {'spk_id': 'FDAC1',
#   'duration': 4.4224375,
#   'phn': 'sil hh ah s sil k iy y ah ng m ae n hh iy s eh sil w ih dh sil m aa sil d ih s sil t ey s sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FDAC1/SI1474.WAV.wav.pt'},
#  'FDAC1_SX214.WAV': {'spk_id': 'FDAC1',
#   'duration': 4.4288125,
#   'phn': 'sil dh ih m aa n iy ng sil d uw ah n dh uh s sil p ay dx ih w eh sil g l ih s ih n sil d ah sil ih n dh ah s ah n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FDAC1/SX214.WAV.wav.pt'},
#  'FDAC1_SX124.WAV': {'spk_id': 'FDAC1',
#   'duration': 2.7328125,
#   'phn': 'sil aa sil jh ih sil s sil m ey dx ah v sil p y uw dx er r er sil b y uw dx ah f uh l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FDAC1/SX124.WAV.wav.pt'},
#  'FDAC1_SX304.WAV': {'spk_id': 'FDAC1',
#   'duration': 4.21125,
#   'phn': 'sil ch iy sil s sil t aa sil k iy ng z sil r ah n dh ah f er s sil t ay m dh eh r w aa ah n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FDAC1/SX304.WAV.wav.pt'},
#  'FDAC1_SI2104.WAV': {'spk_id': 'FDAC1',
#   'duration': 4.601625,
#   'phn': 'sil aa hh aa hh iy th aa sil ey sil l ah sh sil d ih v aa r s iy sil ae l ae s sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/FDAC1/SI2104.WAV.pt'},
#  'MREB0_SX25.WAV': {'spk_id': 'MREB0',
#   'duration': 2.176,
#   'phn': 'sil ow n l iy l oy er z sil l ah v sil m ih y ih n eh er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/MREB0/SX25.WAV.pt'},
#  'MREB0_SX385.WAV': {'spk_id': 'MREB0',
#   'duration': 1.856,
#   'phn': 'sil hh ih sh ow l sil d er f eh l sil t eh z ih f ih w er sil b r ow sil k ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/MREB0/SX385.WAV.pt'},
#  'MREB0_SX205.WAV': {'spk_id': 'MREB0',
#   'duration': 3.04,
#   'phn': 'sil m ih l ih sil t eh er iy sil p er s n eh l er ih sil k s sil p eh sil t ih sil t uw ow sil b ey sil g ah v m ih n aa r dx er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/MREB0/SX205.WAV.pt'},
#  'MREB0_SI1375.WAV': {'spk_id': 'MREB0',
#   'duration': 4.40325,
#   'phn': 'sil aa f ih n sil d aa m ih n ih n sil s sil t r eh s ih m sil p l iy ih n d ih sil k ey sil s ih s eh n er ih ng ah v ih sil t eh n sil sh ih n aa r iy m ow sh ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/MREB0/SI1375.WAV.pt'},
#  'MREB0_SI745.WAV': {'spk_id': 'MREB0',
#   'duration': 1.792,
#   'phn': 'sil b r oy l aa r sil t ow s sil t ih z y uw sh uw l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/MREB0/SI745.WAV.pt'},
#  'MREB0_SX295.WAV': {'spk_id': 'MREB0',
#   'duration': 3.1488125,
#   'phn': 'sil ih f sil k eh r ah l sil k ah m z sil t ah m aa r ow sil hh ae v er er r ey n sil jh f er ah m iy dx iy ng ih sil t uw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/MREB0/SX295.WAV.wav.pt'},
#  'MREB0_SX115.WAV': {'spk_id': 'MREB0',
#   'duration': 2.521625,
#   'phn': 'sil dh iy eh m sil l ah m sil d ih sil p ih sil k s dh iy ih sil k r aa sil p l ih s aa l ah sil g l ow sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/MREB0/SX115.WAV.wav.pt'},
#  'MREB0_SI2005.WAV': {'spk_id': 'MREB0',
#   'duration': 4.97925,
#   'phn': 'sil hh iy hh eh sil d l eh f sil t hh er ih n v ay l ih sil th ih ng sil k iy ng f ah m ih l iy eh er dx iy w uh sil jh eh n sil t l hh er ih n sil t ay m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR1/MREB0/SI2005.WAV.wav.pt'},
#  'FMAH0_SI659.WAV': {'spk_id': 'FMAH0',
#   'duration': 4.4608125,
#   'phn': 'sil hh ih z hh ih s sil t r iy ih z hh ih z ah l ow n sil y eh dx iy sil ch sil m ae n m ah s r eh sil k ih n ay z hh ih z ow n hh ih s sil t r iy ih n ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/FMAH0/SI659.WAV.wav.pt'},
#  'FMAH0_SI1289.WAV': {'spk_id': 'FMAH0',
#   'duration': 1.856,
#   'phn': 'sil ah f l ey m w ih sil y uw z ah sil p eh er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/FMAH0/SI1289.WAV.pt'},
#  'FMAH0_SX119.WAV': {'spk_id': 'FMAH0',
#   'duration': 2.73925,
#   'phn': 'sil dh ih m ih s sil k w ow w ih z r iy sil t r ae sil t er sil d w ih th ae n ih sil p aa l ah sil jh iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/FMAH0/SX119.WAV.wav.pt'},
#  'FMAH0_SX299.WAV': {'spk_id': 'FMAH0',
#   'duration': 3.4304375,
#   'phn': 'sil sh ey v ih ng sil k r iy m ih z ih sil p aa sil p y ih l er ay dx ih m aa n hh aa l ah w iy n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/FMAH0/SX299.WAV.pt'},
#  'FMAH0_SX29.WAV': {'spk_id': 'FMAH0',
#   'duration': 2.3488125,
#   'phn': 'sil hh eh l sil g r eh sil t ih sil p ih sil k ih sil p eh sil k ah v sil p ih sil t ey dx ow z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/FMAH0/SX29.WAV.pt'},
#  'FMAH0_SX389.WAV': {'spk_id': 'FMAH0',
#   'duration': 2.688,
#   'phn': 'sil dh ey ow n ah sil b ih sil g hh aw s ih n dh ih r iy m ow sil k ah n sil t r iy s ay sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/FMAH0/SX389.WAV.wav.pt'},
#  'FMAH0_SI1919.WAV': {'spk_id': 'FMAH0',
#   'duration': 3.34725,
#   'phn': 'sil eh v r iy m uw v m ih sh iy m ey sil s iy m sil d ah n eh s ih s eh r ah l iy n oy z iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/FMAH0/SI1919.WAV.wav.pt'},
#  'FMAH0_SX209.WAV': {'spk_id': 'FMAH0',
#   'duration': 2.7968125,
#   'phn': 'sil m ay sil k l sil k ah l er sil dh ih sil b eh sil d r uw m w aa l w ah th sil k r ey aa n z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/FMAH0/SX209.WAV.wav.pt'},
#  'FCAL1_SX143.WAV': {'spk_id': 'FCAL1',
#   'duration': 2.5984375,
#   'phn': 'sil dh ih s aw n d uh v sil jh ih n ih f er z sil b y uw sil g l s sil k eh er sil dh ah ae n l ow sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/FCAL1/SX143.WAV.pt'},
#  'FCAL1_SX413.WAV': {'spk_id': 'FCAL1',
#   'duration': 3.1168125,
#   'phn': 'sil d ae f sil n iy s sil w iy dx ih sh sil n iy dx l sil p oy n sil s sil k aa r f sil m ae sil ch sil jh er s sil k er sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/FCAL1/SX413.WAV.pt'},
#  'FCAL1_SX53.WAV': {'spk_id': 'FCAL1',
#   'duration': 2.848,
#   'phn': 'sil iy v ih n ih s ih m sil p l v ih sil k ae sil b y l eh r iy sil k ih n sil t ey n s ih m sil b l z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/FCAL1/SX53.WAV.wav.pt'},
#  'FCAL1_SI2033.WAV': {'spk_id': 'FCAL1',
#   'duration': 3.3344375,
#   'phn': 'sil ih w uh sil b iy ih sil k l aa s l sh ey m sil d ih th r ow w ey ih s sil t aa r iy l ay sil dh ih s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/FCAL1/SI2033.WAV.wav.pt'},
#  'FCAL1_SI1403.WAV': {'spk_id': 'FCAL1',
#   'duration': 4.8384375,
#   'phn': 'sil ih n w ah w ey z dh eh n sil d ih sil dh ih sil p ey sh ih n sil s ay sil k ih sil k l sil b l ay n ih s sil m ae n ah f eh s sil t ih sil s eh l f sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/FCAL1/SI1403.WAV.wav.pt'},
#  'FCAL1_SI773.WAV': {'spk_id': 'FCAL1',
#   'duration': 2.9184375,
#   'phn': 'sil l eh dx aa l sil p r aa sil jh eh sil k s sil d r ay s l ow l iy f er s eh v r l sil d ey z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/FCAL1/SI773.WAV.pt'},
#  'FCAL1_SX323.WAV': {'spk_id': 'FCAL1',
#   'duration': 2.617625,
#   'phn': 'sil dh ih f aa sil p er v ih n ih sil dh eh m f r m er r ay v ih ng aa n sil t ay m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/FCAL1/SX323.WAV.wav.pt'},
#  'FCAL1_SX233.WAV': {'spk_id': 'FCAL1',
#   'duration': 2.553625,
#   'phn': 'sil hh ay w ey ih n f r iy w ey m iy n dh ih s ey m sil th ih ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/FCAL1/SX233.WAV.wav.pt'},
#  'MRWS1_SX140.WAV': {'spk_id': 'MRWS1',
#   'duration': 3.04,
#   'phn': 'sil ae sil g er sil k ah l sil ch er l sil p r aa dx ih sil s er ah n iy v ih n l iy sil d ih s sil t r ih sil b y uw dx ih sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/MRWS1/SX140.WAV.wav.pt'},
#  'MRWS1_SI500.WAV': {'spk_id': 'MRWS1',
#   'duration': 3.929625,
#   'phn': 'sil dh ih r er m aa r aa sil v iy ih s sil n ih m f ah m ey n iy ae sil k s aa n eh n iy sil p r ay v ih dx ay s ih r ih z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/MRWS1/SI500.WAV.wav.pt'},
#  'MRWS1_SX230.WAV': {'spk_id': 'MRWS1',
#   'duration': 3.2064375,
#   'phn': 'sil ah l aw l iy w ey hh iy er sil b ah r ae sh sil n l ay z aa l eh r er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/MRWS1/SX230.WAV.pt'},
#  'MRWS1_SX320.WAV': {'spk_id': 'MRWS1',
#   'duration': 3.28325,
#   'phn': 'sil dh ih n ih r ih s ih n ih sil g aa sil m ey n aa sil b iy w ih th ih n w aa sil k ih ng sil d ih s sil t ih n sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/MRWS1/SX320.WAV.pt'},
#  'MRWS1_SX410.WAV': {'spk_id': 'MRWS1',
#   'duration': 2.83525,
#   'phn': 'sil g r eh sil b ay z f r eh sh sil m ih l sil k iy sil ch sil w iy sil d ey m aa r n ih ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/MRWS1/SX410.WAV.pt'},
#  'MRWS1_SI1130.WAV': {'spk_id': 'MRWS1',
#   'duration': 3.168,
#   'phn': 'sil sh uh sil dh iy ih sil k s eh l ah r ey dx ih ng g r ow th ah v sil t eh sil n aa l ah sil jh iy dh eh n w aa r n ah s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/MRWS1/SI1130.WAV.pt'},
#  'MRWS1_SI1496.WAV': {'spk_id': 'MRWS1',
#   'duration': 2.809625,
#   'phn': 'sil ae f sil t er dh ae sil v ay l eh n s w ah z ih sil g z ah l sil t ih n t l ih iy z ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/MRWS1/SI1496.WAV.wav.pt'},
#  'MRWS1_SX50.WAV': {'spk_id': 'MRWS1',
#   'duration': 3.232,
#   'phn': 'sil k ae dx ih s sil t r aa f ih sil k iy sil k ih n aa m ih sil k ah sil b ae sil k s sil n ih sil g l eh sil dh ah sil p aa r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR5/MRWS1/SX50.WAV.pt'},
#  'MRTK0_SI1750.WAV': {'spk_id': 'MRTK0',
#   'duration': 4.672,
#   'phn': 'sil k uh sil dh iy ih m sil b ae s ah dx er hh ih m s eh l f sil b iy dh ih m ae n aa n dh ih s ay sil dh ah sil p r ay m ih n ih s sil t er f ih sil er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MRTK0/SI1750.WAV.pt'},
#  'MRTK0_SX103.WAV': {'spk_id': 'MRTK0',
#   'duration': 2.361625,
#   'phn': 'sil k aa l ah n ae m sil y l ih n s f er m eh dx ih sil k l ah s ih s sil t n sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MRTK0/SX103.WAV.wav.pt'},
#  'MRTK0_SX13.WAV': {'spk_id': 'MRTK0',
#   'duration': 2.329625,
#   'phn': 'sil s sil w ih ng y er aa r m ih z hh ay ih z y uw sil k ae n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MRTK0/SX13.WAV.pt'},
#  'MRTK0_SX373.WAV': {'spk_id': 'MRTK0',
#   'duration': 2.6624375,
#   'phn': 'sil ah sil b aa r ih ng n aa v l ih z ey s ih sil p er sil s l iy sil p ih ng sil p ih l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MRTK0/SX373.WAV.pt'},
#  'MRTK0_SI1093.WAV': {'spk_id': 'MRTK0',
#   'duration': 2.8608125,
#   'phn': 'sil w ah dx eh l ah m ah s ah v aw er sil b iy hh ey v y er aa r sil d iy s ay s iy v sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MRTK0/SI1093.WAV.wav.pt'},
#  'MRTK0_SI1723.WAV': {'spk_id': 'MRTK0',
#   'duration': 2.5344375,
#   'phn': 'sil ey n uw ay sil d iy ih sil d r ih f sil t ih sil ih n f er m n ow w eh er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MRTK0/SI1723.WAV.wav.pt'},
#  'MRTK0_SX193.WAV': {'spk_id': 'MRTK0',
#   'duration': 2.2848125,
#   'phn': 'sil w ay sil ay oy l w ah n y uw aa w ey z y uw z m ay n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MRTK0/SX193.WAV.wav.pt'},
#  'MRTK0_SX283.WAV': {'spk_id': 'MRTK0',
#   'duration': 3.1744375,
#   'phn': 'sil p l ae n sil p er ih n hh uh dx aa r sil er n ih z ey sh n z sil p er m ow sil b er th sil k ih n sil t r ow l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MRTK0/SX283.WAV.pt'},
#  'FKMS0_SX140.WAV': {'spk_id': 'FKMS0',
#   'duration': 2.809625,
#   'phn': 'sil ae sil g er sil k l sil ch er l sil p r aa dx ah sil k s aa r ah n iy v ih n l iy sil d ih s sil t r ih sil b ih dx ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/FKMS0/SX140.WAV.wav.pt'},
#  'FKMS0_SX230.WAV': {'spk_id': 'FKMS0',
#   'duration': 3.7568125,
#   'phn': 'sil ah l aw l iy w ey hh ih er sil b ah sil r ae sh sil n ah l ay z sil aa l eh er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/FKMS0/SX230.WAV.pt'},
#  'FKMS0_SI2120.WAV': {'spk_id': 'FKMS0',
#   'duration': 4.1344375,
#   'phn': 'sil hh iy sil p aa z sil d sil dh eh n ih ae dx ih sil d sil eh v r ih th ih ng aa n ah sh ih sil p sil ih z ah w eh sil p ah n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/FKMS0/SI2120.WAV.wav.pt'},
#  'FKMS0_SX320.WAV': {'spk_id': 'FKMS0',
#   'duration': 3.0528125,
#   'phn': 'sil dh ih n ih er s ih n ih sil g aa sil g m ey n aa sil b iy w ih th ih n ah w aa sil k iy ng sil d ih s sil t n sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/FKMS0/SX320.WAV.pt'},
#  'FKMS0_SX410.WAV': {'spk_id': 'FKMS0',
#   'duration': 2.4704375,
#   'phn': 'sil g r eh sil b ay z f r eh sh sil m ih l sil k iy sil ch w iy sil d ey m aa r n ih ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/FKMS0/SX410.WAV.pt'},
#  'FKMS0_SX50.WAV': {'spk_id': 'FKMS0',
#   'duration': 3.001625,
#   'phn': 'sil k ae dx ah s sil t r aa f ih sil k sil eh sil k ah n aa m ih sil k ah sil b ae sil k s sil n ih sil g l eh sil dh ah sil p aa r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/FKMS0/SX50.WAV.pt'},
#  'FKMS0_SI1490.WAV': {'spk_id': 'FKMS0',
#   'duration': 2.6944375,
#   'phn': 'sil p hh ae sil p s ah w ah z r ay sil t sil p hh ae sil p s ih w ih z sil jh ah s sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/FKMS0/SI1490.WAV.wav.pt'},
#  'FKMS0_SI860.WAV': {'spk_id': 'FKMS0',
#   'duration': 4.3648125,
#   'phn': 'sil dh iy z ih n sil k l uw sil d sil l iy v z ih v ae sil s n s ah z sil ih l n ah s ih z sil eh n l ey aa f s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/FKMS0/SI860.WAV.pt'},
#  'MMJR0_SX388.WAV': {'spk_id': 'MMJR0',
#   'duration': 3.776,
#   'phn': 'sil hh er r ay sil hh ae n ey sil k s sil w ah n eh v ih dh ih sil b ae er m eh sil t r ih sil k sil p r eh sh er sil ch ey n sil jh ih z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MMJR0/SX388.WAV.wav.pt'},
#  'MMJR0_SI2166.WAV': {'spk_id': 'MMJR0',
#   'duration': 2.816,
#   'phn': 'sil l uh sil k sil s w iy t hh aa r sil t sil s ah m f uw l w ah z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MMJR0/SI2166.WAV.wav.pt'},
#  'MMJR0_SX28.WAV': {'spk_id': 'MMJR0',
#   'duration': 2.393625,
#   'phn': 'sil b ey sil g dh eh sil g aa r sil f er w ah n sil g eh l ah n ih v sil g ae s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MMJR0/SX28.WAV.pt'},
#  'MMJR0_SX118.WAV': {'spk_id': 'MMJR0',
#   'duration': 2.9568125,
#   'phn': 'sil k ah sil b ay n aa l dh iy ng sil g r iy dx iy ih n sil t s sil ih n eh l aa r sil jh sil b ow l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MMJR0/SX118.WAV.wav.pt'},
#  'MMJR0_SI1648.WAV': {'spk_id': 'MMJR0',
#   'duration': 4.768,
#   'phn': 'sil ih w ih z ih f eh r l iy m aa r sil n m ow sil t eh l sil w ih th sil k w ay dx ih sil b ih dx ah v ah l eh sil t ah sil k l sil d ih s sil p l ey ih n f sil r ah n sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MMJR0/SI1648.WAV.wav.pt'},
#  'MMJR0_SI2278.WAV': {'spk_id': 'MMJR0',
#   'duration': 2.70725,
#   'phn': 'sil v y uw sil t ey sil k s ih n f ay v sil k aw n iy z sil t uw sil b eh sil d r ah m z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MMJR0/SI2278.WAV.pt'},
#  'MMJR0_SX208.WAV': {'spk_id': 'MMJR0',
#   'duration': 3.5008125,
#   'phn': 'sil r aa sil b s ae sil b ay dh ah sil p aa n sil d sil n s sil k eh sil ch sil dh ih sh sil t r ey sil g iy s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MMJR0/SX208.WAV.wav.pt'},
#  'MMJR0_SX298.WAV': {'spk_id': 'MMJR0',
#   'duration': 3.3984375,
#   'phn': 'sil ay sil d r ae dh er n aa sil b ay dh iy sh sil uw z sil dh eh n sil b iy ow v er sil ch aa r sil jh sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MMJR0/SX298.WAV.pt'},
#  'MGJF0_SI1901.WAV': {'spk_id': 'MGJF0',
#   'duration': 3.097625,
#   'phn': 'sil ah w aa r m sil b r iy z sil p l ey dx ih sil k r aa s sil t ih sil m uw v ih ng ih sil l ay sil k w ey v z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MGJF0/SI1901.WAV.wav.pt'},
#  'MGJF0_SX371.WAV': {'spk_id': 'MGJF0',
#   'duration': 3.34725,
#   'phn': 'sil r ay sil n aw m ey n aa sil b iy dh ih sil b eh s sil t ay m f er sil b ih z n ih s sil m er sil jh er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MGJF0/SX371.WAV.wav.pt'},
#  'MGJF0_SX101.WAV': {'spk_id': 'MGJF0',
#   'duration': 3.6608125,
#   'phn': 'sil k ih n er sil aa r sil n sil ch ih l sil d r ih n sil d eh sil k er ey sil dh er sil k l ae s r uw m z f er aa l hh aa l ih dx ey z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MGJF0/SX101.WAV.wav.pt'},
#  'MGJF0_SX11.WAV': {'spk_id': 'MGJF0',
#   'duration': 1.6,
#   'phn': 'sil hh iy w l ah l aw ah r eh r l ay sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MGJF0/SX11.WAV.pt'},
#  'MGJF0_SI776.WAV': {'spk_id': 'MGJF0',
#   'duration': 1.7728125,
#   'phn': 'sil d uw n aa sil d r aa y aa r n sil t uw sil t ay sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MGJF0/SI776.WAV.pt'},
#  'MGJF0_SX191.WAV': {'spk_id': 'MGJF0',
#   'duration': 2.425625,
#   'phn': 'sil w ih th sil d r aa aa l f ow n iy ae sil k uw z ey sh n z ih w ah n s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MGJF0/SX191.WAV.wav.pt'},
#  'MGJF0_SX281.WAV': {'spk_id': 'MGJF0',
#   'duration': 3.4624375,
#   'phn': 'sil k aa r iy ih n sil t r ih sh sil p l ey sil t ae sil g w ih th sil b iy sil ch sil b aa l z f er aw er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MGJF0/SX281.WAV.pt'},
#  'MGJF0_SI641.WAV': {'spk_id': 'MGJF0',
#   'duration': 5.2288125,
#   'phn': 'sil k l eh v er l ay sil s aa ng z sil w er ow v er l iy sil k oy sil t r ae sil jh ih sil s aa ng z ah l ih dx l sil t uw m eh l ih sil jh er m ae dx ih sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MGJF0/SI641.WAV.pt'},
#  'MCSH0_SX379.WAV': {'spk_id': 'MCSH0',
#   'duration': 2.73925,
#   'phn': 'sil p ae m sil g ih v z sil d r ay v iy ng l eh s n z aa n sil th er z sil d iy z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MCSH0/SX379.WAV.pt'},
#  'MCSH0_SX199.WAV': {'spk_id': 'MCSH0',
#   'duration': 4.153625,
#   'phn': 'sil y ah ng sil ch ih l sil r eh n sh uh dx ih v oy dx ih sil k s sil p ow sh er sil t uw sil k ih n sil t ey sil jh uh s sil z ih z iy z ih z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MCSH0/SX199.WAV.wav.pt'},
#  'MCSH0_SI2179.WAV': {'spk_id': 'MCSH0',
#   'duration': 2.2208125,
#   'phn': 'sil m ay m ah dh er n eh v er w aa sil p s sil m iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MCSH0/SI2179.WAV.wav.pt'},
#  'MCSH0_SX109.WAV': {'spk_id': 'MCSH0',
#   'duration': 3.3984375,
#   'phn': 'sil sh iy s l ih sil t ih n s sil p r ey n hh er ae ng sil k l aa n dh ah s sil t iy sil p s l ow sil p sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MCSH0/SX109.WAV.wav.pt'},
#  'MCSH0_SX289.WAV': {'spk_id': 'MCSH0',
#   'duration': 3.5328125,
#   'phn': 'sil w eh dh er sil p r uw f sil g ah l aa sh ih z er v er iy y uw s f l ih n s iy ae dx l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MCSH0/SX289.WAV.pt'},
#  'MCSH0_SI919.WAV': {'spk_id': 'MCSH0',
#   'duration': 4.9984375,
#   'phn': 'sil aa sil v iy ih s l iy dh ih sil b r ay dx l sil p eh er hh ae z sil m ih n iy eh sil jh ah s sil m ah n sil s sil t ih m ey sil t uw dh eh r n uw s ih sil ch uw ey sh n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MCSH0/SI919.WAV.wav.pt'},
#  'MCSH0_SX19.WAV': {'spk_id': 'MCSH0',
#   'duration': 2.976,
#   'phn': 'sil ah l uw m ah n ah m s ih l v er w eh er sil k eh n aa f ah n sil b iy f l ih m z iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MCSH0/SX19.WAV.wav.pt'},
#  'MCSH0_SI1549.WAV': {'spk_id': 'MCSH0',
#   'duration': 2.06725,
#   'phn': 'sil y aa l sh uh dx ih v l eh sil m iy sil d uw ah sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MCSH0/SI1549.WAV.wav.pt'},
#  'MBWM0_SI1934.WAV': {'spk_id': 'MBWM0',
#   'duration': 1.0944375,
#   'phn': 'sil w ey dx ah l ih dx l w ay l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MBWM0/SI1934.WAV.wav.pt'},
#  'MBWM0_SX44.WAV': {'spk_id': 'MBWM0',
#   'duration': 2.7328125,
#   'phn': 'sil b ae s sil k ih sil b aa l sil k n sil b iy ih n ih n er sil t ey n ih ng s sil p aa r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MBWM0/SX44.WAV.pt'},
#  'MBWM0_SX224.WAV': {'spk_id': 'MBWM0',
#   'duration': 1.61925,
#   'phn': 'sil hh aw sil g uh dx ih sh y er ih n sil d er ih n sil t s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MBWM0/SX224.WAV.pt'},
#  'MBWM0_SX314.WAV': {'spk_id': 'MBWM0',
#   'duration': 3.2128125,
#   'phn': 'sil f sil p iy sil p l w er m aa r sil jh eh n er ih s dh er sil b iy n ow n iy sil f er w eh l f eh r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MBWM0/SX314.WAV.wav.pt'},
#  'MBWM0_SI674.WAV': {'spk_id': 'MBWM0',
#   'duration': 4.608,
#   'phn': 'sil dh ih s ih z sil n ow s sil p eh sil t ey dx er sil t ay sil p ih sil s sil p ih r iy eh n sil t s sil eh v r ih w ah n ih z sil t ah sil b iy ah sil p ah sil t ih s sil p ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MBWM0/SI674.WAV.pt'},
#  'MBWM0_SI1304.WAV': {'spk_id': 'MBWM0',
#   'duration': 3.05925,
#   'phn': 'sil ih w ih z ih sil k s sil p ow z sil t uw ah hh ay v ah l aa s ah dx iy sil g ae s sil jh eh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MBWM0/SI1304.WAV.pt'},
#  'MBWM0_SX134.WAV': {'spk_id': 'MBWM0',
#   'duration': 3.2448125,
#   'phn': 'sil d ih s eh m sil b er ih n sil jh ae n y ih w er ih er n ay s sil m ah n t s sil t ah s sil p eh n sil ih n m ay ae m iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MBWM0/SX134.WAV.pt'},
#  'MBWM0_SX404.WAV': {'spk_id': 'MBWM0',
#   'duration': 2.93125,
#   'phn': 'sil b aa r sil b er n sil p ey sil p er n l iy v z ih n ah sil b ih sil b aa n f ay er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MBWM0/SX404.WAV.pt'},
#  'FCMH0_SX104.WAV': {'spk_id': 'FCMH0',
#   'duration': 1.977625,
#   'phn': 'sil hh iy s sil t ow l ah sil d ay m sil f r ah m ah sil b ey sil g er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/FCMH0/SX104.WAV.pt'},
#  'FCMH0_SI824.WAV': {'spk_id': 'FCMH0',
#   'duration': 4.832,
#   'phn': 'sil s eh v l f er m z er m er sil ch ih n sil d ay z ih ng eh n z ay m sil p r eh sil p er ey sh ih n th r uw f iy sil m ae n y ih f ae sil k sh er ih z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/FCMH0/SI824.WAV.pt'},
#  'FCMH0_SX284.WAV': {'spk_id': 'FCMH0',
#   'duration': 3.21925,
#   'phn': 'sil jh eh f th aa y uw aa r sil g y uw sil d ih n f ey v er ah v ih s ih n sil t er f y uw sil jh sil p er sil ch ih s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/FCMH0/SX284.WAV.pt'},
#  'FCMH0_SX374.WAV': {'spk_id': 'FCMH0',
#   'duration': 2.1824375,
#   'phn': 'sil jh aa n sil k l iy n z sil sh eh l f ih sh f aa r ah l ih v ih ng sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/FCMH0/SX374.WAV.wav.pt'},
#  'FCMH0_SI1454.WAV': {'spk_id': 'FCMH0',
#   'duration': 5.1264375,
#   'phn': 'sil ah r ih sil jh n ah l iy sil dh ih m ey n sil t ay sil p sh y uw z sil t sil w er v eh r iy ih s sil k ah m sil p ah z ih sh ih n z ah v sil p aa l iy eh s sil t er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/FCMH0/SI1454.WAV.wav.pt'},
#  'FCMH0_SX14.WAV': {'spk_id': 'FCMH0',
#   'duration': 3.001625,
#   'phn': 'sil b iy f aa r th er z sil d ih z ih sil z ae m sil r iy v y uw eh v r iy f aa r m y ih l ah sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/FCMH0/SX14.WAV.wav.pt'},
#  'FCMH0_SI2084.WAV': {'spk_id': 'FCMH0',
#   'duration': 1.52325,
#   'phn': 'sil w ah dx ah sil b aw dx ih sil t iy r uw m dh eh n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/FCMH0/SI2084.WAV.wav.pt'},
#  'FCMH0_SX194.WAV': {'spk_id': 'FCMH0',
#   'duration': 1.8368125,
#   'phn': 'sil dh ey ih n sil jh oy ih w ih n ay aa sil d ih sh ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/FCMH0/SX194.WAV.pt'},
#  'MBDG0_SX383.WAV': {'spk_id': 'MBDG0',
#   'duration': 2.5344375,
#   'phn': 'sil dh ih sil k aa r sil p ih sil k l iy n er sh ae m sil p uw dx aa r aa r iy eh n l r ah sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MBDG0/SX383.WAV.wav.pt'},
#  'MBDG0_SI833.WAV': {'spk_id': 'MBDG0',
#   'duration': 2.4704375,
#   'phn': 'sil l eh s sil p er s ah n l s ey l z sil m ih n sh ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MBDG0/SI833.WAV.wav.pt'},
#  'MBDG0_SX203.WAV': {'spk_id': 'MBDG0',
#   'duration': 2.1504375,
#   'phn': 'sil dh ih sil k aa z w ey eh n sil d ih dx ih sil b r ah sil p l iy ih sil dh ih sh aa r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MBDG0/SX203.WAV.pt'},
#  'MBDG0_SI2093.WAV': {'spk_id': 'MBDG0',
#   'duration': 3.82725,
#   'phn': 'sil hh iy dh eh n aa f er sil hh ih z ow n eh s sil t ih m ih dx ah dh ah w eh dh er sil w ih sil ch w ih z ah n ih n th uw z iy ae s sil t ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MBDG0/SI2093.WAV.pt'},
#  'MBDG0_SX113.WAV': {'spk_id': 'MBDG0',
#   'duration': 2.2464375,
#   'phn': 'sil ah m ah s sil k ih l er ae sil d ih m ih n ih z sil g uh sil d f er y er sil b ae sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MBDG0/SX113.WAV.wav.pt'},
#  'MBDG0_SI1463.WAV': {'spk_id': 'MBDG0',
#   'duration': 2.8224375,
#   'phn': 'sil w iy sil k ae n hh aw eh v er m ae sil k s ih m ay z ih sil s ih sil k s sil p eh sil t ih sil v ae l y uw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MBDG0/SI1463.WAV.wav.pt'},
#  'MBDG0_SX23.WAV': {'spk_id': 'MBDG0',
#   'duration': 2.521625,
#   'phn': 'sil dh ow z sil m uw z ih sh ih n z hh aa r m ah n ay z sil m aa r v ah l ah s l iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MBDG0/SX23.WAV.wav.pt'},
#  'MBDG0_SX293.WAV': {'spk_id': 'MBDG0',
#   'duration': 3.4048125,
#   'phn': 'sil p l iy z sil t ey sil k dh ih s sil d er dx iy sil t ey sil b l sil k l aa th sil t ah dh ih sil k l iy n er sh f er m iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MBDG0/SX293.WAV.wav.pt'},
#  'MWJG0_SX44.WAV': {'spk_id': 'MWJG0',
#   'duration': 2.361625,
#   'phn': 'sil b ae s sil k ih sil b aa l sil k ih n sil b iy ih n ih n er sil t ey n ih ng s sil p aa r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MWJG0/SX44.WAV.pt'},
#  'MWJG0_SX224.WAV': {'spk_id': 'MWJG0',
#   'duration': 1.81125,
#   'phn': 'sil hh aw sil g uh sil d ih ih z y er ih n sil d uh r ih n s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MWJG0/SX224.WAV.pt'},
#  'MWJG0_SI494.WAV': {'spk_id': 'MWJG0',
#   'duration': 2.25925,
#   'phn': 'sil b ey sil k s l ow l iy ih l iy s sil t w ah n hh ae f aw er l aa ng sil g er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MWJG0/SI494.WAV.wav.pt'},
#  'MWJG0_SX314.WAV': {'spk_id': 'MWJG0',
#   'duration': 3.3088125,
#   'phn': 'sil ih f sil p iy sil p l w er m aa r sil jh eh n er ah s sil dh eh r w uh sil b iy n ow n iy sil d f er w eh l f eh r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MWJG0/SX314.WAV.wav.pt'},
#  'MWJG0_SX134.WAV': {'spk_id': 'MWJG0',
#   'duration': 3.129625,
#   'phn': 'sil d iy s eh m sil b er ih n sil jh ae n y uw w eh r ih aa r n ay s m ah n th s sil t ih s sil p eh n sil d ih n m ay ae m ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MWJG0/SX134.WAV.pt'},
#  'MWJG0_SI1754.WAV': {'spk_id': 'MWJG0',
#   'duration': 2.64325,
#   'phn': 'sil hh iy s eh sil dh ih sil k r ey z iy f uw l sil hh ae f ah l aw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MWJG0/SI1754.WAV.pt'},
#  'MWJG0_SI1124.WAV': {'spk_id': 'MWJG0',
#   'duration': 4.6208125,
#   'phn': 'sil l eh sil m iy sil k w ow sil t hh ih m iy v ih n m aa r f uh l iy sil f er hh ih z ih n ae l ah s ih s ih z m sil p aa r n sil t ah m ay th iy m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MWJG0/SI1124.WAV.wav.pt'},
#  'MWJG0_SX404.WAV': {'spk_id': 'MWJG0',
#   'duration': 3.328,
#   'phn': 'sil b aa r sil b sil b er n sil d sil p ey sil p er ih n sil l iy v z ih n ih sil b ih sil b aa n f ay er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MWJG0/SX404.WAV.pt'},
#  'MTDT0_SX4.WAV': {'spk_id': 'MTDT0',
#   'duration': 2.8928125,
#   'phn': 'sil jh ey n m ey er n ih m aa r m ah n iy sil b ay w er sil k iy ng hh aa r sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTDT0/SX4.WAV.pt'},
#  'MTDT0_SX364.WAV': {'spk_id': 'MTDT0',
#   'duration': 4.97925,
#   'phn': 'sil iy sil ch ah n sil t ay m l iy ih n sil k ah m l aa s sil k ow ih n s ay dx ih sil w ih th ah sil b r ey sil d aw n ah v ih hh iy dx iy ng s ih s sil t ih m sil p aa r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTDT0/SX364.WAV.pt'},
#  'MTDT0_SX94.WAV': {'spk_id': 'MTDT0',
#   'duration': 2.64325,
#   'phn': 'sil y ah ng s sil t er z l ah v sil k aa m ih n sil k ae n sil d iy ih z sil t r iy sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTDT0/SX94.WAV.wav.pt'},
#  'MTDT0_SI2254.WAV': {'spk_id': 'MTDT0',
#   'duration': 2.169625,
#   'phn': 'sil k w ay ah l iy hh iy sil d ih sil t er m ih n d ah f oy l hh er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTDT0/SI2254.WAV.pt'},
#  'MTDT0_SI994.WAV': {'spk_id': 'MTDT0',
#   'duration': 3.289625,
#   'phn': 'sil hh er s sil t ah dx iy ih v hh ih s sil t er r iy w ah z sil p er s ih s sil t ah n l iy sil p er s uw sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTDT0/SI994.WAV.wav.pt'},
#  'MTDT0_SX274.WAV': {'spk_id': 'MTDT0',
#   'duration': 3.2064375,
#   'phn': 'sil k l ih f w ah s uw dh sil b ay dh ah l ah sil g sh y er iy ih s sil m ah s aa sil jh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTDT0/SX274.WAV.pt'},
#  'MTDT0_SX184.WAV': {'spk_id': 'MTDT0',
#   'duration': 2.6624375,
#   'phn': 'sil dh ih sil k ae sil s sil m iy aw aa eh z hh er sil s sil m ay ih er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTDT0/SX184.WAV.wav.pt'},
#  'MTDT0_SI1994.WAV': {'spk_id': 'MTDT0',
#   'duration': 4.4608125,
#   'phn': 'sil s ow ah f aa l iy z sil b ih er z w ah z sil t ih sil g eh sil m iy ih m sil b eh sil m ae n y uw sil jh uh s sil p eh n ah l aa dx ah m ah n iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTDT0/SI1994.WAV.pt'},
#  'MTHC0_SI1015.WAV': {'spk_id': 'MTHC0',
#   'duration': 3.36,
#   'phn': 'sil hh ey eh n sil p ae sh er aa r dh iy ah dh er sil ch iy s aa r s ah z ah v l ay v s sil t aa sil k f iy sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTHC0/SI1015.WAV.wav.pt'},
#  'MTHC0_SX25.WAV': {'spk_id': 'MTHC0',
#   'duration': 2.0288125,
#   'phn': 'sil ow n l iy l oy er z l ah v m ih l y ih n eh r z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTHC0/SX25.WAV.pt'},
#  'MTHC0_SX385.WAV': {'spk_id': 'MTHC0',
#   'duration': 2.25925,
#   'phn': 'sil hh ih sh ow l sil d er f eh l sil t eh z ih f ih sil w er sil b r ow sil k ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTHC0/SX385.WAV.pt'},
#  'MTHC0_SX205.WAV': {'spk_id': 'MTHC0',
#   'duration': 3.481625,
#   'phn': 'sil m ih l ih sil t eh r ih sil p er s n eh l aa r ih sil k s sil p eh sil t ih sil t uw ow sil b ey sil g ah v er m ah n sil t aa r dx er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTHC0/SX205.WAV.pt'},
#  'MTHC0_SI2275.WAV': {'spk_id': 'MTHC0',
#   'duration': 2.297625,
#   'phn': 'sil ih dx aa l sil d ih sil d l uh sil k v eh r iy f ih sh n sil d eh n sh ih sil p sh ey sil p sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTHC0/SI2275.WAV.wav.pt'},
#  'MTHC0_SI1645.WAV': {'spk_id': 'MTHC0',
#   'duration': 2.8288125,
#   'phn': 'sil s ah sil ch sil hh aa sil t m ih z ah m w ah z sil k m sil p l iy sil l iy ah n sil jh ah s sil t ah f ay sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTHC0/SI1645.WAV.wav.pt'},
#  'MTHC0_SX295.WAV': {'spk_id': 'MTHC0',
#   'duration': 3.04,
#   'phn': 'sil ih f sil k eh r l sil k ah m z sil t m aa r ow sil hh ae v hh er ih r ey n jh f er m iy dx ih ng ae sil t uw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTHC0/SX295.WAV.wav.pt'},
#  'MTHC0_SX115.WAV': {'spk_id': 'MTHC0',
#   'duration': 2.8224375,
#   'phn': 'sil dh iy eh m sil b l eh m sil d iy sil p ih sil k s sil dh iy eh sil k r aa sil p l uh s aa l ih sil g l ow sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTHC0/SX115.WAV.wav.pt'},
#  'MGLB0_SI904.WAV': {'spk_id': 'MGLB0',
#   'duration': 3.7248125,
#   'phn': 'sil hh iy sil p iy r sil d ih hh eh sil d ih ng sil g r ae n sil d ih z ih r eh r ow sil t r ae sil k s sil k ih m ih n sil t ih v y uw ah sil g eh n sil b ah l ow sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MGLB0/SI904.WAV.pt'},
#  'MGLB0_SI1534.WAV': {'spk_id': 'MGLB0',
#   'duration': 3.9104375,
#   'phn': 'sil ih z ih sil b ih sil k ah z ah v m ay s l aa v ah n l ih n ih s dh ih sil hh eh r sil g r ow z ah n m ay f ey s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MGLB0/SI1534.WAV.pt'},
#  'MGLB0_SX4.WAV': {'spk_id': 'MGLB0',
#   'duration': 2.425625,
#   'phn': 'sil jh ey n m ey er n m aa r m ah n iy sil b ay w er sil k ih ng hh aa r sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MGLB0/SX4.WAV.pt'},
#  'MGLB0_SX364.WAV': {'spk_id': 'MGLB0',
#   'duration': 4.025625,
#   'phn': 'sil iy sil ch ah n sil t ay m l iy ih n sil k ah m l aa s sil k ow ih n s ay dx ih sil w ih th ah sil b r ey sil d aw n ah v ih hh iy dx iy ng s ih s sil t m sil p aa r sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MGLB0/SX364.WAV.pt'},
#  'MGLB0_SX94.WAV': {'spk_id': 'MGLB0',
#   'duration': 2.432,
#   'phn': 'sil y ah ng s sil t er z l ah v sil k aa m ah n sil k ae n sil d iy ih z sil t r iy sil t s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MGLB0/SX94.WAV.wav.pt'},
#  'MGLB0_SI2164.WAV': {'spk_id': 'MGLB0',
#   'duration': 1.3248125,
#   'phn': 'sil t ey sil k eh er v y ih s eh l f dh eh n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MGLB0/SI2164.WAV.pt'},
#  'MGLB0_SX274.WAV': {'spk_id': 'MGLB0',
#   'duration': 2.5344375,
#   'phn': 'sil k l ih f w uh s uw dh sil b ay dh ah l ah sil sh er iy ih s sil m ah s aa sh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MGLB0/SX274.WAV.pt'},
#  'MGLB0_SX184.WAV': {'spk_id': 'MGLB0',
#   'duration': 2.2784375,
#   'phn': 'sil dh ih sil k ae sil t s sil m iy aw aa l w ih z hh er sil t s sil m ay ih r z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MGLB0/SX184.WAV.wav.pt'},
#  'MMWH0_SX9.WAV': {'spk_id': 'MMWH0',
#   'duration': 1.785625,
#   'phn': 'sil w eh r w er y uw w aa l w iy w er ah w ey sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MMWH0/SX9.WAV.pt'},
#  'MMWH0_SX369.WAV': {'spk_id': 'MMWH0',
#   'duration': 2.4704375,
#   'phn': 'sil b aa sil p ey sil p er sil d ow v er dh l l ih v ih ng r uw m y er r ah l s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MMWH0/SX369.WAV.pt'},
#  'MMWH0_SX279.WAV': {'spk_id': 'MMWH0',
#   'duration': 3.7504375,
#   'phn': 'sil ae l ah s ih z ah sil b ih l ah sil t iy sil t ah w er sil w ih dh aw sil s uw sil p er v ih sh n ih z sil n ow w er dh ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MMWH0/SX279.WAV.wav.pt'},
#  'MMWH0_SI1089.WAV': {'spk_id': 'MMWH0',
#   'duration': 2.1888125,
#   'phn': 'sil p er hh ae sil s th ih ng z sil w er iy v ih n w er s dh eh n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MMWH0/SI1089.WAV.pt'},
#  'MMWH0_SX99.WAV': {'spk_id': 'MMWH0',
#   'duration': 3.168,
#   'phn': 'sil m eh sil d iy v l s ah s ay ih dx iy w ah z sil b ey s sil t aa n hh ay er aa r sil k ih s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MMWH0/SX99.WAV.pt'},
#  'MMWH0_SX189.WAV': {'spk_id': 'MMWH0',
#   'duration': 2.617625,
#   'phn': 'sil d ih s sil t r oy eh v r iy f ay l r ih l ey dx ih sil t ah m ay aa dx ih sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MMWH0/SX189.WAV.pt'},
#  'MMWH0_SI1301.WAV': {'spk_id': 'MMWH0',
#   'duration': 3.8144375,
#   'phn': 'sil d iy n z sil k ih n f aa r m ih n ih m sil p aa r sil n sil b r ih sil jh sil b ih sil t w iy n dh ih sil p r eh z sil ih n sil ih n ah f ae sil k l sil t iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MMWH0/SI1301.WAV.wav.pt'},
#  'MMWH0_SI459.WAV': {'spk_id': 'MMWH0',
#   'duration': 5.10725,
#   'phn': 'sil hh iy f er dh er sil p er sil p ow z sil g r ae n sil s ah v ah n ah n s sil p eh s ih f ay sil s ah m f er sil k s sil p er m eh n sil t l hh aa s sil p ih dx l s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MMWH0/SI459.WAV.wav.pt'},
#  'MTAA0_SI596.WAV': {'spk_id': 'MTAA0',
#   'duration': 2.048,
#   'phn': 'sil aa n dh iy z dh ey f iy l dh ey sil k ih n r ah l ay sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTAA0/SI596.WAV.wav.pt'},
#  'MTAA0_SX25.WAV': {'spk_id': 'MTAA0',
#   'duration': 2.03525,
#   'phn': 'sil ow n l iy l oy er s l ah v m ih l y ih n eh er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTAA0/SX25.WAV.pt'},
#  'MTAA0_SX385.WAV': {'spk_id': 'MTAA0',
#   'duration': 2.297625,
#   'phn': 'sil hh ih sh ow l dx er f eh l sil eh z ih f ih w er sil b r ow sil k ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTAA0/SX385.WAV.pt'},
#  'MTAA0_SX205.WAV': {'spk_id': 'MTAA0',
#   'duration': 3.34725,
#   'phn': 'sil m ih l ah sil t er iy sil p er s n eh l er ih sil s sil p eh sil t ih sil t uw sil b ey sil g ah v er m ih n aa dx er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTAA0/SX205.WAV.pt'},
#  'MTAA0_SI1915.WAV': {'spk_id': 'MTAA0',
#   'duration': 5.0048125,
#   'phn': 'sil ih w ih z dh eh er dh ih sil sh iy w uh sil d hh ae f sil t uw ih n ae sil t hh er r iy n ah n s iy ey sh n sil b eh sil g f er sil g ih v n ih s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTAA0/SI1915.WAV.pt'},
#  'MTAA0_SX295.WAV': {'spk_id': 'MTAA0',
#   'duration': 3.4368125,
#   'phn': 'sil ih f sil k eh r l sil k ah m z sil t ah m aa r ow sil hh ae v er r ey n sil jh f er ah m iy dx iy n eh sil t uw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTAA0/SX295.WAV.wav.pt'},
#  'MTAA0_SX115.WAV': {'spk_id': 'MTAA0',
#   'duration': 2.9824375,
#   'phn': 'sil dh ah eh l ah m sil d ih sil p ih sil k s dh ah sil k r aa sil p l ih s aa l ah sil g l ow sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTAA0/SX115.WAV.wav.pt'},
#  'MTAA0_SI1285.WAV': {'spk_id': 'MTAA0',
#   'duration': 2.6048125,
#   'phn': 'sil f ae m l iy r ae sh sil n iy n sil p r aa sil l iy w uh l sil b iy n eh s ah s er ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR3/MTAA0/SI1285.WAV.pt'},
#  'FJSJ0_SI854.WAV': {'spk_id': 'FJSJ0',
#   'duration': 2.56,
#   'phn': 'sil ih n sil k er ih sil jh eh m sil t ih eh sil s er s ay z dh eh r sil b eh n ih f ih sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR8/FJSJ0/SI854.WAV.pt'},
#  'FJSJ0_SX44.WAV': {'spk_id': 'FJSJ0',
#   'duration': 2.83525,
#   'phn': 'sil b ae s sil k ah sil b aa l sil k m sil b iy n ih n er sil t ey n iy ng g s sil p aa r sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR8/FJSJ0/SX44.WAV.pt'},
#  'FJSJ0_SI1484.WAV': {'spk_id': 'FJSJ0',
#   'duration': 2.784,
#   'phn': 'sil dh eh er aa s ow aa n ih s sil s iy sil k er z ae f sil t er sil t r uw th sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR8/FJSJ0/SI1484.WAV.wav.pt'},
#  'FJSJ0_SX224.WAV': {'spk_id': 'FJSJ0',
#   'duration': 1.856,
#   'phn': 'sil hh ah sil g uh sil sh er ih n sil d er ih n sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR8/FJSJ0/SX224.WAV.pt'},
#  'FJSJ0_SX314.WAV': {'spk_id': 'FJSJ0',
#   'duration': 3.2,
#   'phn': 'sil ih f sil p iy sil p l w er m aa r sil jh eh n er ah s dh eh r w uh sil b iy n ow n iy sil d f aa r w eh l f eh er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR8/FJSJ0/SX314.WAV.wav.pt'},
#  'FJSJ0_SX134.WAV': {'spk_id': 'FJSJ0',
#   'duration': 2.809625,
#   'phn': 'sil d ih s eh m sil b er ih n sil jh ae n y uw er iy er n ay s sil m ah n th s sil t ih s sil p eh n sil d ih n m ay ae m iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR8/FJSJ0/SX134.WAV.pt'},
#  'FJSJ0_SI2114.WAV': {'spk_id': 'FJSJ0',
#   'duration': 2.56,
#   'phn': 'sil s sil t ey sil m iy sil sh ih s eh sil n l eh m iy ae sil dh ow z sil d ay s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR8/FJSJ0/SI2114.WAV.pt'},
#  'FJSJ0_SX404.WAV': {'spk_id': 'FJSJ0',
#   'duration': 2.4128125,
#   'phn': 'sil b aa r sil b er n sil p ey sil p er n l iy v z ih n ah sil b ih sil b aa n f ay er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR8/FJSJ0/SX404.WAV.pt'},
#  'MAJC0_SI1946.WAV': {'spk_id': 'MAJC0',
#   'duration': 2.6048125,
#   'phn': 'sil dh er r ah s l ih ng sil p r aa sil b l ah m w ah z sil b ay n ow m iy n s aa l v sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR8/MAJC0/SI1946.WAV.pt'},
#  'MAJC0_SX25.WAV': {'spk_id': 'MAJC0',
#   'duration': 1.945625,
#   'phn': 'sil ow n l ih l oy er z l ah v m ih l y ih n eh er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR8/MAJC0/SX25.WAV.pt'},
#  'MAJC0_SX385.WAV': {'spk_id': 'MAJC0',
#   'duration': 2.2528125,
#   'phn': 'sil hh ih sh ow l sil d er f eh l sil t ae z ih f ih w er sil b r ow sil k ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR8/MAJC0/SX385.WAV.pt'},
#  'MAJC0_SX205.WAV': {'spk_id': 'MAJC0',
#   'duration': 3.4368125,
#   'phn': 'sil m ih l ih sil t eh r iy sil p er s n eh l aa er sil k s sil p eh sil t ih sil t uw ow sil b ey sil g ah v m ah n aa r dx er s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR8/MAJC0/SX205.WAV.pt'},
#  'MAJC0_SI835.WAV': {'spk_id': 'MAJC0',
#   'duration': 4.3008125,
#   'phn': 'sil s ey l z sil m ah n sh ih sil p ih s sil t ih l n eh s ih s eh r iy sil b ah dx ih sil s ah sil d ih f er n sil b r ae n sil d ah v s ey l z m n sh ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR8/MAJC0/SI835.WAV.wav.pt'},
#  'MAJC0_SI2095.WAV': {'spk_id': 'MAJC0',
#   'duration': 2.4768125,
#   'phn': 'sil m ay sil d ae sil d ih dx ih sil n hh iy l ih v sil t uw ah sil g r ey dx ey sil jh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR8/MAJC0/SI2095.WAV.pt'},
#  'MAJC0_SX295.WAV': {'spk_id': 'MAJC0',
#   'duration': 3.4944375,
#   'phn': 'sil ih f sil k ae r ah l sil k ah m z sil t ih m aa r ow sil hh ae v er er r ey n jh f er m iy dx iy ng ih sil t uw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR8/MAJC0/SX295.WAV.wav.pt'},
#  'MAJC0_SX115.WAV': {'spk_id': 'MAJC0',
#   'duration': 2.9184375,
#   'phn': 'sil dh iy eh m sil b l ah m sil d ih sil p ih sil s iy ih sil k r aa sil p l ih s sil aa l ah sil g l ow sil',
# ...
#  'MERS0_SX209.WAV': {'spk_id': 'MERS0',
#   'duration': 2.83525,
#   'phn': 'sil m ay sil k l sil k ah l er sil dh ah sil b eh sil d r uw m w aa l sil w ah th sil k r ey aa n sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR7/MERS0/SX209.WAV.wav.pt'},
#  'MJFC0_SI1663.WAV': {'spk_id': 'MJFC0',
#   'duration': 2.393625,
#   'phn': 'sil hh iy th aa sil t hh iy s aa ah sil p ey l f ey s ae dx ah w ih n sil d ow sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/MJFC0/SI1663.WAV.wav.pt'},
#  'MJFC0_SX133.WAV': {'spk_id': 'MJFC0',
#   'duration': 2.5664375,
#   'phn': 'sil p iy sil s er r iy ih z aa r sil k ah n v iy n ih sil f er sil k w ih sil k l ah n sil ch sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/MJFC0/SX133.WAV.wav.pt'},
#  'MJFC0_SX403.WAV': {'spk_id': 'MJFC0',
#   'duration': 2.86725,
#   'phn': 'sil hh er w aa r sil d r ow sil k n sil s ih s ih v ow n l iy s sil k er sil s ih n sil b l aw s ah z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/MJFC0/SX403.WAV.wav.pt'},
#  'MJFC0_SI1033.WAV': {'spk_id': 'MJFC0',
#   'duration': 1.84325,
#   'phn': 'sil ih f sil d aa r sil k ey m dh ey w uh sil d l uw z hh er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/MJFC0/SI1033.WAV.wav.pt'},
#  'MJFC0_SI2293.WAV': {'spk_id': 'MJFC0',
#   'duration': 3.616,
#   'phn': 'sil dh ow z w er ih s sil p eh sh sil l iy dh ah w ah n z eh sil t aa l ah dh ih r sil g r ow n ah sil s sil l ae f sil t eh sil t l aw dx ih s sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/MJFC0/SI2293.WAV.pt'},
#  'MJFC0_SX43.WAV': {'spk_id': 'MJFC0',
#   'duration': 1.9968125,
#   'phn': 'sil eh l sil d uh l iy sil p iy sil p l aa r aa f ih n ih sil s sil k l uw dx ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/MJFC0/SX43.WAV.pt'},
#  'MJFC0_SX313.WAV': {'spk_id': 'MJFC0',
#   'duration': 2.656,
#   'phn': 'sil d r aa sil f ay v f aa r m z ih n dh ih sil b aa sil s sil b ah f aa r iy sil g ow aw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/MJFC0/SX313.WAV.pt'},
#  'MJFC0_SX223.WAV': {'spk_id': 'MJFC0',
#   'duration': 2.16325,
#   'phn': 'sil p uh sil dh ih sil b uh sil ch er sil b l aa sil t ey sil b l ih n ih sil g er aa sil jh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/MJFC0/SX223.WAV.pt'},
#  'FDRW0_SX383.WAV': {'spk_id': 'FDRW0',
#   'duration': 2.784,
#   'phn': 'sil dh ih sil k aa sil p ih sil k l iy n ih sh ae m sil p uw dx aa aa r iy eh n ah l r ah sil g sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/FDRW0/SX383.WAV.wav.pt'},
#  'FDRW0_SI1423.WAV': {'spk_id': 'FDRW0',
#   'duration': 2.4,
#   'phn': 'sil ah sil b aw sil d aa n hh iy sil g aa dx ah sil t ih sil b l ow sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/FDRW0/SI1423.WAV.pt'},
#  'FDRW0_SX203.WAV': {'spk_id': 'FDRW0',
#   'duration': 3.225625,
#   'phn': 'sil dh ih sil k aa z w ey eh n d ih sil d ih sil b r ah sil p l iy sil ae sil dh ih sh ow ah sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/FDRW0/SX203.WAV.pt'},
#  'FDRW0_SX113.WAV': {'spk_id': 'FDRW0',
#   'duration': 4.0704375,
#   'phn': 'sil ey m ah s sil k y ih l ah ae sil d ih m ih n sil ih z sil g uh sil d f er y er sil b ae sil k sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/FDRW0/SX113.WAV.wav.pt'},
#  'FDRW0_SX23.WAV': {'spk_id': 'FDRW0',
#   'duration': 2.9824375,
#   'phn': 'sil dh ow z m uw z ih sh ih n z hh aa m ih n ay z m aa v ah l ih s l iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/FDRW0/SX23.WAV.wav.pt'},
#  'FDRW0_SI653.WAV': {'spk_id': 'FDRW0',
#   'duration': 2.9888125,
#   'phn': 'sil sh uh l iy dh ih s ih z ih r iy ae l ih dx iy w iy aa l ih sil n aa l ih sil jh sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/FDRW0/SI653.WAV.pt'},
#  'FDRW0_SI1283.WAV': {'spk_id': 'FDRW0',
#   'duration': 5.024,
#   'phn': 'sil l ih v ih ng ih n ih sh eh l sil t uh dh uh r ey dx iy ow ae sil t ih v ih dx iy ah v f aa l aw sil d ih sil k ey z r ae sil p ih sil l iy ae sil f er s sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/FDRW0/SI1283.WAV.wav.pt'},
#  'FDRW0_SX293.WAV': {'spk_id': 'FDRW0',
#   'duration': 2.9504375,
#   'phn': 'sil p l iy z sil t ey sil dh ih s sil d er dx iy sil t ey sil b ah sil k l aa sil t ih dh ih sil k l iy n ih z f er m iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/FDRW0/SX293.WAV.wav.pt'},
#  'MRJR0_SI1812.WAV': {'spk_id': 'MRJR0',
#   'duration': 2.969625,
#   'phn': 'sil iy sil t er n ih dx iy ih z sil n ow sil t ay m sil f aa r ih sil k r ih m ih n ey sh n sil s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/MRJR0/SI1812.WAV.wav.pt'},
#  'MRJR0_SX102.WAV': {'spk_id': 'MRJR0',
#   'duration': 3.673625,
#   'phn': 'sil s sil p eh sh l sil t ae s sil k f aa r s ih z r eh s sil k y uw hh aa s sil ah sil jh ih z f er m sil k ih sil n ae sil p er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/MRJR0/SX102.WAV.wav.pt'},
#  'MRJR0_SX282.WAV': {'spk_id': 'MRJR0',
#   'duration': 3.34725,
#   'phn': 'sil dh ah sil t uw th f eh r iy f er sil g aa sil t ih sil k ah m w eh n r aa sil jh er z sil t uw th f eh l aw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/MRJR0/SX282.WAV.pt'},
#  'MRJR0_SX372.WAV': {'spk_id': 'MRJR0',
#   'duration': 3.136,
#   'phn': 'sil dh ae sil ay sil g r ae m ey sil k s eh n s ow n l iy ae f sil t er m ah sil ch s sil t ah dx iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/MRJR0/SX372.WAV.wav.pt'},
#  'MRJR0_SX192.WAV': {'spk_id': 'MRJR0',
#   'duration': 2.8224375,
#   'phn': 'sil s sil t r aa hh ae sil t s aa r aw dx ah f ae sh n dh ih s y ih r sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/MRJR0/SX192.WAV.pt'},
#  'MRJR0_SI1182.WAV': {'spk_id': 'MRJR0',
#   'duration': 2.745625,
#   'phn': 'sil l eh dx ah s sil d ih f er eh n sh iy ey dx ah f y uw ah v dh iy z ay sil d iy ah z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/MRJR0/SI1182.WAV.wav.pt'},
#  'MRJR0_SX12.WAV': {'spk_id': 'MRJR0',
#   'duration': 2.137625,
#   'phn': 'sil w ih l r aa sil b ih n w eh er ey y eh l ow l ih l iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/MRJR0/SX12.WAV.pt'},
#  'MRJR0_SI2313.WAV': {'spk_id': 'MRJR0',
#   'duration': 5.5744375,
#   'phn': 'sil w eh l sil jh uw n y er sil d ih sil n hh iy y iy sil ow n l iy w ah n sil ah n m ih s sil t er hh eh n r iy sil d ih sil n iy v ih n sil d uw dh ae sil w eh l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR6/MRJR0/SI2313.WAV.wav.pt'},
#  'MPDF0_SX102.WAV': {'spk_id': 'MPDF0',
#   'duration': 3.8784375,
#   'phn': 'sil s sil p eh sh l sil t ae s sil k f aa r s ih z sil r eh s sil k y uw hh aa s sil t ih sil jh ih z f r ah m sil k ih sil n ae sil p er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MPDF0/SX102.WAV.wav.pt'},
#  'MPDF0_SX282.WAV': {'spk_id': 'MPDF0',
#   'duration': 3.001625,
#   'phn': 'sil dh ih sil t uw th f er ih f er sil aa sil t ih sil k ah m w ah n r aa sil jh er z sil t uw th f eh l aw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MPDF0/SX282.WAV.pt'},
#  'MPDF0_SI1542.WAV': {'spk_id': 'MPDF0',
#   'duration': 3.008,
#   'phn': 'sil d ih f iy sil t w aa r aa r m iy sh uw z sil ih n aa sil v iy ih s sil d ih s r ih sil p eh er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MPDF0/SI1542.WAV.pt'},
#  'MPDF0_SX372.WAV': {'spk_id': 'MPDF0',
#   'duration': 2.8224375,
#   'phn': 'sil dh ae sil d ay eh sil g r ae m ey sil k s eh n s ow n l iy eh f sil t er m ah sil ch s sil t ah dx iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MPDF0/SX372.WAV.wav.pt'},
#  'MPDF0_SI912.WAV': {'spk_id': 'MPDF0',
#   'duration': 2.7584375,
#   'phn': 'sil y uw m ey ih m ey z y er s eh l f ih n ih sil k w ay er r ih l n ae sil k f aa r ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MPDF0/SI912.WAV.pt'},
#  'MPDF0_SX192.WAV': {'spk_id': 'MPDF0',
#   'duration': 2.297625,
#   'phn': 'sil s sil t r aa hh ae sil t s er aa dx ah f ae sh n ih s y ih er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MPDF0/SX192.WAV.pt'},
#  'MPDF0_SX12.WAV': {'spk_id': 'MPDF0',
#   'duration': 2.2144375,
#   'phn': 'sil w ih l r aa sil b ih n sil w eh er ah y eh l ow l ih l iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MPDF0/SX12.WAV.pt'},
#  'MPDF0_SI2172.WAV': {'spk_id': 'MPDF0',
#   'duration': 3.1104375,
#   'phn': 'sil s sil t r eh ng sil th sil b iy sil g ae n sil t ih z ih sil p ah sil p ih n sil d aw n hh ih z sil ch eh s sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MPDF0/SI2172.WAV.pt'},
#  'MMDB1_SX185.WAV': {'spk_id': 'MMDB1',
#   'duration': 2.336,
#   'phn': 'sil d ih sil jh uw sil b ay eh n iy sil k aa r dx er oy ow v er aa l z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MMDB1/SX185.WAV.wav.pt'},
#  'MMDB1_SX275.WAV': {'spk_id': 'MMDB1',
#   'duration': 2.7008125,
#   'phn': 'sil s sil t iy v w aa r ah sil b r ay sil r eh sil d sil k ae sh sil m ih r s sil w eh dx er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MMDB1/SX275.WAV.pt'},
#  'MMDB1_SI995.WAV': {'spk_id': 'MMDB1',
#   'duration': 4.2688125,
#   'phn': 'sil ae sil d ih f er n sil t ay m z iy s er v sil d eh z sil g l iy sil k l ah v ah n sil k w eh er l iy dx er sil ae n ih z aa r sil g ih n ih s sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MMDB1/SI995.WAV.wav.pt'},
#  'MMDB1_SX95.WAV': {'spk_id': 'MMDB1',
#   'duration': 2.93125,
#   'phn': 'sil iy sil g w aa n ih z ih n ae l ih sil g ey dx er z ah r sil t r aa sil p ih sil k l r eh sil t ay l z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MMDB1/SX95.WAV.wav.pt'},
#  'MMDB1_SI1625.WAV': {'spk_id': 'MMDB1',
#   'duration': 1.561625,
#   'phn': 'sil hh iy m ey sil k s sil m iy ah ng sil k ah m f er dx ah sil b l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MMDB1/SI1625.WAV.wav.pt'},
#  'MMDB1_SI2255.WAV': {'spk_id': 'MMDB1',
#   'duration': 3.488,
#   'phn': 'sil hh iy s w ah ng er aw n sil d ay z sil t w aa r sil dh ih sil b eh sil d r uw m sil s ah m f ih f sil t iy n f iy dx ah w ey sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MMDB1/SI2255.WAV.pt'},
#  'MMDB1_SX5.WAV': {'spk_id': 'MMDB1',
#   'duration': 1.657625,
#   'phn': 'sil sh iy ih z th ih n er dh eh n ay ae m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MMDB1/SX5.WAV.wav.pt'},
#  'MMDB1_SX365.WAV': {'spk_id': 'MMDB1',
#   'duration': 3.63525,
#   'phn': 'sil dh ih sil g ah n m ih n sil k eh sil t ih z v ih sil t m sil k aa r n er dx ae sil g ah n sil p oy n sil f er th r iy aw er z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MMDB1/SX365.WAV.pt'},
#  'MJAR0_SI1988.WAV': {'spk_id': 'MJAR0',
#   'duration': 2.5024375,
#   'phn': 'sil hh aw z ih s sil t r ay sil k y uw uw f aa l er f eh er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MJAR0/SI1988.WAV.pt'},
#  'MJAR0_SX8.WAV': {'spk_id': 'MJAR0',
#   'duration': 2.4768125,
#   'phn': 'sil w ay y eh l er w er iy ow v er s ih l iy ay dx ah m s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MJAR0/SX8.WAV.wav.pt'},
#  'MJAR0_SI728.WAV': {'spk_id': 'MJAR0',
#   'duration': 4.97925,
#   'phn': 'sil p ow sil sh dh iy ae sil p l z ah n dh ih s er ah sil p f er sil t w eh l v m ih n ih sil t s sil d r ey n dh eh m hh ih n sil k uw l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MJAR0/SI728.WAV.pt'},
#  'MJAR0_SX188.WAV': {'spk_id': 'MJAR0',
#   'duration': 2.51525,
#   'phn': 'sil hh uw aa th er r ay z dh iy ah n l ih m ih dx ih sil ih sil k s sil p eh n sil s ah sil k aw n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MJAR0/SX188.WAV.pt'},
#  'MJAR0_SX368.WAV': {'spk_id': 'MJAR0',
#   'duration': 3.36,
#   'phn': 'sil l aa r iy z sil k aa s sil t ah m n iy dx ih sil b l ae sil g l ah v z sil t ih sil b iy sil k ah m sil p l iy l iy eh l ih sil g ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MJAR0/SX368.WAV.pt'},
#  'MJAR0_SI2247.WAV': {'spk_id': 'MJAR0',
#   'duration': 1.3568125,
#   'phn': 'sil w iy sil k n ih s ah n l iy dx er sh ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MJAR0/SI2247.WAV.pt'},
#  'MJAR0_SX278.WAV': {'spk_id': 'MJAR0',
#   'duration': 3.6608125,
#   'phn': 'sil t ih f er dh er hh ih z sil p r ih s sil t iy sil jh sil hh iy ih sil k ey sh n l iy r iy sil z ah w aa l s sil t r iy sil jh er n l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MJAR0/SX278.WAV.wav.pt'},
#  'MJAR0_SX98.WAV': {'spk_id': 'MJAR0',
#   'duration': 1.9328125,
#   'phn': 'sil g eh s dh ah sil k w eh sh ih n f ah m dh iy ae n s er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MJAR0/SX98.WAV.pt'},
#  'MGWT0_SI909.WAV': {'spk_id': 'MGWT0',
#   'duration': 5.504,
#   'phn': 'sil k ih m sil p ah l s er iy r iy sil t ay er m eh n sil t eh sil t s ih sil k s sil t iy f ay v l uw m z aa n aa r hh er r ay z ih n sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MGWT0/SI909.WAV.pt'},
#  'MGWT0_SX9.WAV': {'spk_id': 'MGWT0',
#   'duration': 3.513625,
#   'phn': 'sil uw hh w eh r w er y uw hh w ay l w iy w er ah w ey sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MGWT0/SX9.WAV.pt'},
#  'MGWT0_SX369.WAV': {'spk_id': 'MGWT0',
#   'duration': 3.481625,
#   'phn': 'sil b aa sil p ey sil p er sil d ow v ah dh ah l ih v ih ng r uw m y er l z sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MGWT0/SX369.WAV.pt'},
#  'MGWT0_SI2169.WAV': {'spk_id': 'MGWT0',
#   'duration': 5.26725,
#   'phn': 'sil ah sil p s sil t eh er z sil b ih z ih f iy sil t sh aw er ih ng l ay sil k r ey n sil d r aa sil p s sil p ae dx er sil d er r aw n sil d hh er r uw m sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MGWT0/SI2169.WAV.pt'},
#  'MGWT0_SX279.WAV': {'spk_id': 'MGWT0',
#   'duration': 4.576,
#   'phn': 'sil ae l ah s ih z ah sil b ih l ih sil t iy sil t uw w er sil w ih th aw sil s uw sil p er v ih sh ih n sil ih z n ow sil t w er dh ih sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MGWT0/SX279.WAV.wav.pt'},
#  'MGWT0_SX99.WAV': {'spk_id': 'MGWT0',
#   'duration': 3.6864375,
#   'phn': 'sil m iy dx iy ih v l s ah s ay eh dx iy w ah z sil b ey s sil t aa n ah hh ay er r aa r sil k iy s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MGWT0/SX99.WAV.pt'},
#  'MGWT0_SX189.WAV': {'spk_id': 'MGWT0',
#   'duration': 3.296,
#   'phn': 'sil d ih s sil t r oy eh v r iy f ay l r ih l ey dx ih sil t ah m ay aa dx ih sil t s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MGWT0/SX189.WAV.pt'},
#  'MGWT0_SI1539.WAV': {'spk_id': 'MGWT0',
#   'duration': 3.424,
#   'phn': 'sil f ih s sil s sil p ah m l sil d hh ih m ae z iy s sil t ae sil g er sil d f aa r er sil t sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MGWT0/SI1539.WAV.wav.pt'},
#  'MMDM2_SX102.WAV': {'spk_id': 'MMDM2',
#   'duration': 3.136,
#   'phn': 'sil s sil p eh sh l sil t ae s sil k f aa r s ih z r eh s sil k y uw hh aa s sil ih sil jh ih z f m sil k ih sil n ae sil p er s sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MMDM2/SX102.WAV.wav.pt'},
#  'MMDM2_SX282.WAV': {'spk_id': 'MMDM2',
#   'duration': 2.72,
#   'phn': 'sil dh ih sil t uw th f eh r iy f er sil g aa sil t sil k ah m w ah n r aa sil jh er z sil t uw th f eh l aw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MMDM2/SX282.WAV.pt'},
#  'MMDM2_SX372.WAV': {'spk_id': 'MMDM2',
#   'duration': 2.649625,
#   'phn': 'sil dh ae sil d ay ih sil g r ae m ey sil k s eh n s sil ow n l iy ae f sil t er m ah sil s sil t ah dx iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MMDM2/SX372.WAV.wav.pt'},
#  'MMDM2_SI2082.WAV': {'spk_id': 'MMDM2',
#   'duration': 1.8624375,
#   'phn': 'sil y er sil b oy l ih ng m ih l sil k ey n y uw sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MMDM2/SI2082.WAV.wav.pt'},
#  'MMDM2_SX192.WAV': {'spk_id': 'MMDM2',
#   'duration': 2.19525,
#   'phn': 'sil s sil t r aa hh ae sil s er aw dx ah v f ae sh n dh ih s y ih er sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MMDM2/SX192.WAV.pt'},
#  'MMDM2_SI1555.WAV': {'spk_id': 'MMDM2',
#   'duration': 2.19525,
#   'phn': 'sil ah s l iy sil p iy v oy s ae n s er sil d sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MMDM2/SI1555.WAV.wav.pt'},
#  'MMDM2_SI1452.WAV': {'spk_id': 'MMDM2',
#   'duration': 4.377625,
#   'phn': 'sil p ow l sil t r iy sil r iy z ah l sil s ah v ih r ey dx iy ey sh n sil t eh s sil w ah th sil p ow l sil t r iy hh ah sil b ih n sil k w ay sil s ih sil k s eh s f l sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MMDM2/SI1452.WAV.wav.pt'},
#  'MMDM2_SX12.WAV': {'spk_id': 'MMDM2',
#   'duration': 1.97125,
#   'phn': 'sil w l r aa sil ih n w er ih y eh l ow l ih l iy sil',
#   'fbank': 'D:/SR_dataset/data/fbank/dev/DR2/MMDM2/SX12.WAV.pt'}}

# %% [markdown]
# # Features

# %% [markdown]
# ## Use `dataloader` to get an utterance

# %%
from dataloader import get_dataloader
import torch
import numpy as np

# %%
loader = get_dataloader('train_fbank.json', 1, False)
data_iter = iter(loader)

# %%
fbank, lens, trans, dur = next(data_iter)

# %%
print('The utterance has {} seconds.'.format(dur[0]))
print('Filter bank feature has {} frames and {} dimensions.'.format(
    fbank.shape[0], fbank.shape[2]))
print('The correspoinding transcription is: {}.'.format(trans[0]))
# Out:
# The utterance has 3.79525 seconds.
# Filter bank feature has 378 frames and 23 dimensions.
# The correspoinding transcription is: sil dh ah z ae n sil s er z l sil b ih s sil t r ey f aa r w er sil d ih f y uw sil th ih ng sil dh ah m sil th r uw sil k eh r f ah l ih f er s sil t sil.

# %% [markdown]
# ## Plot FBANK

# %%
import matplotlib.pyplot as plt
import numpy as np

feature = np.transpose(fbank[:, 0, :].numpy())
plt.clf()
plt.figure(figsize=(10,2))
plt.imshow(feature, aspect='auto', origin='lower')
plt.colorbar()
plt.show()

# %% [markdown]
# # CTC model for ASR

# %% [markdown]
# ## Obtain phoneme output units

# %%
# First find the unique phones in train.json, and then
# create a file named vocab.txt, each line in this 
# file is a unique phone, in total there should be 
# 40 lines

vocab = {}
phonemes = []
with open("vocab_39.txt") as f:
    for id, text in enumerate(f):
        vocab[text.strip()] = id
        phonemes.append(text)
phonemes = phonemes[1:]

# %%
vocab
# Out:
# {'_': 0,
#  'aa': 1,
#  'ae': 2,
#  'ah': 3,
#  'aw': 4,
#  'ay': 5,
#  'b': 6,
#  'ch': 7,
#  'd': 8,
#  'dh': 9,
#  'dx': 10,
#  'eh': 11,
#  'er': 12,
#  'ey': 13,
#  'f': 14,
#  'g': 15,
#  'hh': 16,
#  'ih': 17,
#  'iy': 18,
#  'jh': 19,
#  'k': 20,
#  'l': 21,
#  'm': 22,
#  'n': 23,
#  'ng': 24,
#  'ow': 25,
#  'oy': 26,
#  'p': 27,
#  'r': 28,
#  's': 29,
#  'sh': 30,
#  'sil': 31,
#  't': 32,
#  'th': 33,
#  'uh': 34,
#  'uw': 35,
#  'v': 36,
#  'w': 37,
#  'y': 38,
#  'z': 39}

# %%
# # Count the number of times each phone appear in the training set
# # and save the numbers correcponding to each phone in vocab.txt 
# # into counts.txt

# counts = []
# with open("counts.txt") as f:
#     for i in f:
#         counts.append(int(i))

# %% [markdown]
# ## Plot frequencies of graphemes

# %%
# plt.clf()
# plt.figure(figsize=(10,2))
# freq = np.array(counts) / np.sum(counts) * 100
# plt.bar(phonemes, freq)
# plt.show()

# %% [markdown]
# ## Model & training configurations

# %%
from collections import namedtuple
if torch.cuda.is_available():
    device = "cuda:0"
else:
    device = "cpu"

args = {'seed': 123,
        'train_json': 'train_fbank.json',
        'val_json': 'dev_fbank.json',
        'test_json': 'test_fbank.json',
        'batch_size': 4,
        'num_layers': 1,
        'fbank_dims': 23,
        'model_dims': 128,
        'concat': 1,
        'lr': 0.5,
        'vocab': vocab,
        'report_interval': 50,
        'num_epochs': 25,
        'device': device,
        'clip':0.5,
       }

args = namedtuple('x', args)(**args)

# %%
import models_regularized
model = models_regularized.BiLSTM(
    args.num_layers, args.fbank_dims * args.concat, args.model_dims, len(args.vocab))
num_params = sum(p.numel() for p in model.parameters())
print('Total number of model parameters is {}'.format(num_params))
# Out:
# Total number of model parameters is 166952

# %% [markdown]
# ## Training

# %%
# from datetime import datetime
# from trainer_SGD_Optim import train
# start = datetime.now()
# model.to(args.device)
# model_path,history = train(model, args)
# end = datetime.now()
# duration = (end - start).total_seconds()
# print('Training finished in {} minutes.'.format(divmod(duration, 60)[0]))
# print('Model saved to {}'.format(model_path))

# %%
# import matplotlib.pyplot as plt
# temp = [1]*len(history['loss'])
# plt.plot(history['loss'],label='Training Loss')
# plt.plot(history['val_loss'],label='Val Loss')
# plt.plot(temp,'--')
# plt.legend()
# plt.show()

# %% [markdown]
# ## Decoding

# %%
### You can uncomment the following line and change model path to the model you want to decode
model_path="checkpoints/20230123_003821/model_22"

# %%
import torch
model.to(args.device)

print('Loading model from {}'.format(model_path))
model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()
# Out:
# Loading model from checkpoints/20230123_003821/model_22
# BiLSTM(
#   (lstm): LSTM(23, 128, bidirectional=True)
#   (dropout): Dropout(p=0.05, inplace=False)
#   (proj): Linear(in_features=256, out_features=40, bias=True)
# )

# %%
from decoder_penalty import decode
factors = np.arange(0,1,0.01)
DEL=[]
SUB=[]
INS=[]
COR=[]
PER=[]
best_result=None
best_f =0
min_per=float('inf')
for f in factors:
    results = decode(model, args, args.test_json,factor=f)
    if results[4]<min_per:
        best_result=results
        min_per=results[4]
        best_f  = f
    SUB.append(results[0])
    DEL.append(results[1])
    INS.append(results[2])
    COR.append(results[3])
    PER.append(results[4])
    
print(best_result)
print("SUB: {:.2f}%, DEL: {:.2f}%, INS: {:.2f}%, COR: {:.2f}%, PER: {:.2f}%".format(*best_result))
print(best_f)
x=factors
plt.scatter(x,SUB,label='Substitution')
plt.legend()
plt.show()

plt.scatter(x,DEL,label='Deletion',color='red')
plt.legend()
plt.show()
plt.scatter(x,INS,label='Insertion',color='green')
plt.legend()
plt.show()
plt.scatter(x,COR,label='Hits',color='orange')
plt.legend()
plt.show()
plt.scatter(x,PER,label='PER',color='purple')
plt.legend()
plt.show()
# Out:
# (17.572640066731545, 7.660225218962881, 4.4626720422633115, 74.76713471430557, 29.695537327957737)
# SUB: 17.57%, DEL: 7.66%, INS: 4.46%, COR: 74.77%, PER: 29.70%
# 0.37

# %%
from decoder_no_penalty import decode2
results2 = decode2(model, args, args.test_json)
print(results2)
print("SUB: {:.2f}%, DEL: {:.2f}%, INS: {:.2f}%, COR: {:.2f}%, PER: {:.2f}%".format(*results2))
# Out:
# (16.6828861393021, 11.552898651466704, 2.2660920339218684, 71.7642152092312, 30.501876824690672)
# SUB: 16.68%, DEL: 11.55%, INS: 2.27%, COR: 71.76%, PER: 30.50%

# %%
from dataloader import get_dataloader

new_loader = get_dataloader('test_fbank.json',1,True)

# %%
data_iter = iter(new_loader)
fbank, lens, trans, dur = next(data_iter)

print(lens,trans,dur)
# Out:
# tensor([309]) ['sil dh eh sil d ay ih sil g r ae m ey sil k s eh n s sil ow n l iy sil ae f sil t er m ah sil sh sil t ah dx iy sil'] [3.1104375]

# %%
from utils import concat_inputs


inputs, in_lens = concat_inputs(fbank, lens, factor=1)

# %%
from torch.nn.functional import log_softmax

# %%
inputs=inputs.to(device)
# outputs = log_softmax(model(inputs), dim=-1)
# inputs, in_lens = concat_inputs(inputs, in_lens, factor=args.concat)
idx2grapheme = {y: x for x, y in vocab.items()}

with torch.no_grad():
    outputs = torch.nn.functional.softmax(model(inputs), dim=-1)
#     outputs = torch.argmax(outputs, dim=-1).transpose(0, 1)
# outputs = [[idx2grapheme[i] for i in j] for j in outputs.tolist()]
# outputs = [[v for i, v in enumerate(j) if i == 0 or v != j[i - 1]] for j in outputs]
# outputs = [list(filter(lambda elem: elem != "_", i)) for i in outputs]
# outputs = [" ".join(i) for i in outputs]

# %%
outputs.shape
# Out:
# torch.Size([309, 1, 40])

# %%
vocab_reverse_mapping = {vocab[idx]:idx for idx in vocab}

# %%
vocab_reverse_mapping
# Out:
# {0: '_',
#  1: 'aa',
#  2: 'ae',
#  3: 'ah',
#  4: 'aw',
#  5: 'ay',
#  6: 'b',
#  7: 'ch',
#  8: 'd',
#  9: 'dh',
#  10: 'dx',
#  11: 'eh',
#  12: 'er',
#  13: 'ey',
#  14: 'f',
#  15: 'g',
#  16: 'hh',
#  17: 'ih',
#  18: 'iy',
#  19: 'jh',
#  20: 'k',
#  21: 'l',
#  22: 'm',
#  23: 'n',
#  24: 'ng',
#  25: 'ow',
#  26: 'oy',
#  27: 'p',
#  28: 'r',
#  29: 's',
#  30: 'sh',
#  31: 'sil',
#  32: 't',
#  33: 'th',
#  34: 'uh',
#  35: 'uw',
#  36: 'v',
#  37: 'w',
#  38: 'y',
#  39: 'z'}

# %%
df = []


for i in range(len(outputs[:50])):
    for j in range(len(outputs[0][0])):
        df.append({'frame':i,'word':vocab_reverse_mapping[j],'value':outputs[i][0][j].item()})

# %%
print(df)
# Out:
# [{'frame': 0, 'word': '_', 'value': 0.9999655485153198}, {'frame': 0, 'word': 'aa', 'value': 1.4427740779865417e-07}, {'frame': 0, 'word': 'ae', 'value': 4.3746871369876317e-07}, {'frame': 0, 'word': 'ah', 'value': 8.054830686887726e-06}, {'frame': 0, 'word': 'aw', 'value': 1.9057409872402786e-07}, {'frame': 0, 'word': 'ay', 'value': 1.240230034227352e-07}, {'frame': 0, 'word': 'b', 'value': 5.44079403752562e-09}, {'frame': 0, 'word': 'ch', 'value': 1.1738348959511313e-08}, {'frame': 0, 'word': 'd', 'value': 1.3385422903411381e-07}, {'frame': 0, 'word': 'dh', 'value': 1.064079015122843e-06}, {'frame': 0, 'word': 'dx', 'value': 1.5048877344270295e-07}, {'frame': 0, 'word': 'eh', 'value': 1.321219997407752e-06}, {'frame': 0, 'word': 'er', 'value': 4.2629761765056173e-07}, {'frame': 0, 'word': 'ey', 'value': 2.2871924443279568e-07}, {'frame': 0, 'word': 'f', 'value': 4.820299750463164e-07}, {'frame': 0, 'word': 'g', 'value': 7.947337898883688e-09}, {'frame': 0, 'word': 'hh', 'value': 8.303791076968992e-08}, {'frame': 0, 'word': 'ih', 'value': 3.846093932224903e-06}, {'frame': 0, 'word': 'iy', 'value': 2.851048179763893e-07}, {'frame': 0, 'word': 'jh', 'value': 6.544209618652985e-10}, {'frame': 0, 'word': 'k', 'value': 4.667662878432566e-08}, {'frame': 0, 'word': 'l', 'value': 1.2887223874713527e-06}, {'frame': 0, 'word': 'm', 'value': 5.491677939062356e-07}, {'frame': 0, 'word': 'n', 'value': 1.5285345398297068e-06}, {'frame': 0, 'word': 'ng', 'value': 8.696479198988527e-07}, {'frame': 0, 'word': 'ow', 'value': 1.285955733010269e-07}, {'frame': 0, 'word': 'oy', 'value': 1.1709077263333256e-08}, {'frame': 0, 'word': 'p', 'value': 1.9983863808192837e-07}, {'frame': 0, 'word': 'r', 'value': 2.072784432982644e-08}, {'frame': 0, 'word': 's', 'value': 1.3023394274114253e-07}, {'frame': 0, 'word': 'sh', 'value': 7.0252959005756566e-09}, {'frame': 0, 'word': 'sil', 'value': 8.061069820541888e-06}, {'frame': 0, 'word': 't', 'value': 4.857355406784336e-07}, {'frame': 0, 'word': 'th', 'value': 9.793924391487963e-07}, {'frame': 0, 'word': 'uh', 'value': 2.185579660363146e-06}, {'frame': 0, 'word': 'uw', 'value': 5.223179755375895e-08}, {'frame': 0, 'word': 'v', 'value': 8.326530291924428e-07}, {'frame': 0, 'word': 'w', 'value': 2.6618520720944616e-09}, {'frame': 0, 'word': 'y', 'value': 4.868211167519121e-09}, {'frame': 0, 'word': 'z', 'value': 3.5587007118920155e-08}, {'frame': 1, 'word': '_', 'value': 0.9999523162841797}, {'frame': 1, 'word': 'aa', 'value': 9.664368150197333e-08}, {'frame': 1, 'word': 'ae', 'value': 2.5883647936097987e-07}, {'frame': 1, 'word': 'ah', 'value': 1.5063618548083468e-06}, {'frame': 1, 'word': 'aw', 'value': 1.2185442699319537e-07}, {'frame': 1, 'word': 'ay', 'value': 8.32548678886269e-08}, {'frame': 1, 'word': 'b', 'value': 2.5701389461119106e-08}, {'frame': 1, 'word': 'ch', 'value': 1.1716741354916849e-08}, {'frame': 1, 'word': 'd', 'value': 3.395553278551233e-07}, {'frame': 1, 'word': 'dh', 'value': 1.677509089859086e-06}, {'frame': 1, 'word': 'dx', 'value': 1.2422709971815493e-07}, {'frame': 1, 'word': 'eh', 'value': 7.041072649371927e-07}, {'frame': 1, 'word': 'er', 'value': 1.0481632273240393e-07}, {'frame': 1, 'word': 'ey', 'value': 1.3644027774262213e-07}, {'frame': 1, 'word': 'f', 'value': 3.3494490025987034e-07}, {'frame': 1, 'word': 'g', 'value': 1.0532107630467635e-08}, {'frame': 1, 'word': 'hh', 'value': 5.4319936992897055e-08}, {'frame': 1, 'word': 'ih', 'value': 4.4394826659299724e-07}, {'frame': 1, 'word': 'iy', 'value': 9.936025691104078e-08}, {'frame': 1, 'word': 'jh', 'value': 5.636557331989422e-10}, {'frame': 1, 'word': 'k', 'value': 1.1473132133232866e-07}, {'frame': 1, 'word': 'l', 'value': 4.864216407440836e-07}, {'frame': 1, 'word': 'm', 'value': 2.927674813690828e-07}, {'frame': 1, 'word': 'n', 'value': 3.860758681639709e-07}, {'frame': 1, 'word': 'ng', 'value': 1.3603076354229415e-07}, {'frame': 1, 'word': 'ow', 'value': 4.6531567932106555e-08}, {'frame': 1, 'word': 'oy', 'value': 7.847 ...

# %%
import pandas as pd

df = pd.DataFrame(df)
df.reset_index(drop=True)
# Out:
#       frame word         value
# 0         0    _  9.999655e-01
# 1         0   aa  1.442774e-07
# 2         0   ae  4.374687e-07
# 3         0   ah  8.054831e-06
# 4         0   aw  1.905741e-07
# ...     ...  ...           ...
# 1995     49   uw  5.045052e-07
# 1996     49    v  2.202544e-06
# 1997     49    w  6.929433e-06
# 1998     49    y  1.771213e-05
# 1999     49    z  2.619581e-07
#
# [2000 rows x 3 columns]

# %%
heatmap_pt = pd.pivot_table(df,values ='value', index=['word'], columns='frame')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date, timedelta
import random

fig, ax = plt.subplots(figsize=(16,20))
sns.set()
sns.heatmap(heatmap_pt, cmap='YlGnBu')
plt.xticks(rotation=15)



plt.show()

# %%
inputs=inputs.to(device)
idx2grapheme = {y: x for x, y in vocab.items()}

with torch.no_grad():
    outputs = torch.nn.functional.softmax(model(inputs), dim=-1)
#     outputs = torch.argmax(outputs, dim=-1).transpose(0, 1)

df = []


for i in range(len(outputs[:50])):
    for j in range(len(outputs[0][0])):
        if j!=0:
            df.append({'frame':i,'word':vocab_reverse_mapping[j],'value':outputs[i][0][j].item()})
        else:
            df.append({'frame':i,'word':vocab_reverse_mapping[j],'value':outputs[i][0][j].item()-0.37})
            
import pandas as pd

df = pd.DataFrame(df)
df.reset_index(drop=True)
heatmap_pt = pd.pivot_table(df,values ='value', index=['word'], columns='frame')

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date, timedelta
import random

fig, ax = plt.subplots(figsize=(16,20))
sns.set()
sns.heatmap(heatmap_pt, cmap='YlGnBu')
plt.xticks(rotation=15)
plt.show()

# %%
trans
from datetime import datetime
from pathlib import Path

import torch
from torch.nn import CTCLoss
from torch.nn.utils.rnn import pad_sequence
from torch.nn.functional import log_softmax
from torch.optim import SGD
from decoder import decode
from utils import concat_inputs
from models import BiLSTM
from dataloader import get_dataloader
from collections import namedtuple,defaultdict

# %%
targets = [torch.tensor(list(map(lambda x: vocab[x], target.split())),
                                    dtype=torch.long)
                       for target in trans]
out_lens = torch.tensor(
    [len(target) for target in targets], dtype=torch.long)
targets = pad_sequence(targets, batch_first=True)

# %%
targets.shape
# Out:
# torch.Size([1, 40])
